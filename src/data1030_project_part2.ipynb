# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dog_bites_df = pd.read_csv('data/Dog_Bites_Data.csv')
akc_df = pd.read_csv('data/akc-data-latest.csv')

# %%
dog_bites_df.head()
# Out:
#    UniqueID       DateOfBite Species        Breed  Age Gender  SpayNeuter  \
# 0         1  January 01 2018     DOG      UNKNOWN  NaN      U       False
# 1         2  January 04 2018     DOG      UNKNOWN  NaN      U       False
# 2         3  January 06 2018     DOG     Pit Bull  NaN      U       False
# 3         4  January 08 2018     DOG  Mixed/Other    4      M       False
# 4         5  January 09 2018     DOG     Pit Bull  NaN      U       False
#
#     Borough ZipCode
# 0  Brooklyn   11220
# 1  Brooklyn     NaN
# 2  Brooklyn   11224
# 3  Brooklyn   11231
# 4  Brooklyn   11224

# %%
dog_bites_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22663 entries, 0 to 22662
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UniqueID    22663 non-null  int64
#  1   DateOfBite  22663 non-null  object
#  2   Species     22663 non-null  object
#  3   Breed       20445 non-null  object
#  4   Age         11442 non-null  object
#  5   Gender      22663 non-null  object
#  6   SpayNeuter  22663 non-null  bool
#  7   Borough     22663 non-null  object
#  8   ZipCode     16805 non-null  object
# dtypes: bool(1), int64(1), object(7)
# memory usage: 1.4+ MB

# %%
# Convert 'DateOfBite' to datetime format
dog_bites_df['DateOfBite'] = pd.to_datetime(dog_bites_df['DateOfBite'], errors='coerce')

bites_over_time = dog_bites_df.groupby(dog_bites_df['DateOfBite'].dt.to_period('M')).size()

# Line plot for dog bites over time
plt.figure(figsize=(10, 5))
bites_over_time.plot(kind='line')
plt.title('Dog Bites Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Bites')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Define a function to categorize dates into seasons
def get_season(date):
    if date.month in [12, 1, 2]:
        return 'Winter'
    elif date.month in [3, 4, 5]:
        return 'Spring'
    elif date.month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# Apply the function to create a 'Season' column
dog_bites_df['Season'] = dog_bites_df['DateOfBite'].apply(get_season)

# %%
dog_bites_df = dog_bites_df.drop('DateOfBite', axis=1)

# %%
# Import fuzzywuzzy library
from fuzzywuzzy import process

# Fill NaN values in the 'Breed' column with 'unknown' and convert to lowercase
dog_bites_df['Breed'] = dog_bites_df['Breed'].str.lower().fillna('unknown')

# Retry the process of creating a breed mapping dictionary
dog_bites_breeds = dog_bites_df['Breed'].str.lower().unique()  # Apply strip and lower element-wise
akc_breeds = akc_df['Unnamed: 0'].str.lower().unique()

# Function to perform fuzzy matching
def get_closest_match(breed, akc_breeds):
    match, score = process.extractOne(breed, akc_breeds)
    return match if score > 80 else None  # If the similarity score is high, return the AKC breed; otherwise return None

# Refined function to handle breed names and attempt fuzzy/substring matching
def match_breed(breed, akc_breeds):
    # Step 1: Apply fuzzy matching for entire breed name
    closest_match = get_closest_match(breed, akc_breeds)
    if closest_match:
        return closest_match
    
    # Step 2: Try substring matching
    for akc_breed in akc_breeds:
        if breed in akc_breed or akc_breed in breed:
            return akc_breed
    
    # Step 3: If no match is found, return None
    return None

# Create a mapping dictionary to standardize dog breeds based on the AKC breed list using fuzzy matching and substring matching
breed_mapping_dict = {}

# Go through all breeds in Dog Bites dataset
for breed in dog_bites_breeds:
    # Handle 'Mixed' and 'Crossbreed' cases
    if 'mix' in breed or 'crossbreed' in breed:
        breed_mapping_dict[breed] = 'mixed'
    
    # Try to match breed via fuzzy and substring matching
    else:
        matched_breed = match_breed(breed, akc_breeds)
        
        if matched_breed:  # If a match is found (fuzzy or substring)
            breed_mapping_dict[breed] = matched_breed
        else:
            # If no match is found, categorize as 'unknown'
            breed_mapping_dict[breed] = 'unknown'

# Step 1: Create a new column 'original_breed' to preserve the original breed names
dog_bites_df['original_breed'] = dog_bites_df['Breed']

# Step 2: Apply the breed_mapping_dict to clean the 'Breed' column (which will now be the standardized breed)
dog_bites_df['Breed'] = dog_bites_df['original_breed'].map(breed_mapping_dict)

# Replace any NaN values that resulted from mapping with 'unknown'
dog_bites_df['Breed'] = dog_bites_df['Breed'].fillna('unknown')

# Display the cleaned dataframe with both original and standardized breed columns
dog_bites_df.head()
# Out:
#    UniqueID Species         Breed  Age Gender  SpayNeuter   Borough ZipCode  \
# 0         1     DOG       unknown  NaN      U       False  Brooklyn   11220
# 1         2     DOG       unknown  NaN      U       False  Brooklyn     NaN
# 2         3     DOG  bull terrier  NaN      U       False  Brooklyn   11224
# 3         4     DOG         mixed    4      M       False  Brooklyn   11231
# 4         5     DOG  bull terrier  NaN      U       False  Brooklyn   11224
#
#    Season original_breed
# 0  Winter        unknown
# 1  Winter        unknown
# 2  Winter       pit bull
# 3  Winter    mixed/other
# 4  Winter       pit bull

# %%
akc_df.head()
# Out:
#          Unnamed: 0                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                      0.6    2-3 Times a Week Brushing            0.6
# 1                      0.8               Daily Brushing            0.2
# 2                      0.6    2-3 Times a Week Brushing            0.4
# 3                      0.8               Daily Brushing            0.6
# 4                      0.6    2-3 Times a Week Brushing            0.6
#
#    shedding_category energy_level_value  energy_level_category  \
# 0           Seasonal                0.6       Regular Exercise
# 1         Infrequent                0.8              Energetic
# 2         Occasional                0.6       Regular Exercise
# 3           Seasonal                0.8              Energetic
# 4           Seasonal                0.8              Energetic
#
#   trainability_value  trainability_category demeanor_value  demeanor_category
# 0                0.8          Easy Training            1.0           Outgoing
# 1                0.2        May be Stubborn            0.2         Aloof/Wary
# 2                1.0        Eager to Please            0.8           Friendly
# 3                1.0        Eager to Please            0.6   Alert/Responsive
# 4                0.4            Independent            0.8           Friendly
#
# [5 rows x 21 columns]

# %%
# Rename 'Unnamed: 0' in akc_df to 'Breed' to match the column in dog_bites_df
akc_df.rename(columns={'Unnamed: 0': 'Breed'}, inplace=True)

# Convert 'Breed' column in akc_df to lowercase
akc_df['Breed'] = akc_df['Breed'].str.lower()

# Create dictionaries from akc_df to map Breed to trainability_value and group
trainability_dict = akc_df.set_index('Breed')['trainability_value'].to_dict()
group_dict = akc_df.set_index('Breed')['group'].to_dict()

# Define a function to set 'mixed' and 'unknown' to NaN, and map other breeds using the dictionaries
def get_trainability_and_group(breed):
    if breed in ['mixed', 'unknown']:
        return np.nan, np.nan  # Return NaN for both trainability and group
    else:
        # Use the dictionaries to get trainability_value and group, or return NaN if the breed is not found
        trainability_value = trainability_dict.get(breed, np.nan)
        group = group_dict.get(breed, np.nan)
        return trainability_value, group

# Apply the function to populate both 'trainability_value' and 'group' columns in dog_bites_df
dog_bites_df[['trainability_value', 'group']] = dog_bites_df['Breed'].apply(
    lambda breed: pd.Series(get_trainability_and_group(breed))
)

# %%
# Function to adjust trainability_value randomly within -0.2 to 0.2, ensuring the result stays between 0 and 1 and is rounded to two decimal places
def adjust_trainability(value):
    if pd.isna(value):
        return np.nan  # If the value is NaN, return NaN
    adjustment = np.random.uniform(-0.2, 0.2)  # Random adjustment between -0.2 and 0.2
    new_value = value + adjustment
    new_value = np.clip(new_value, 0, 1)  # Ensures value stays between 0 and 1
    return round(new_value, 2)  # Round to two decimal places

# %%
# Apply the function to adjust 'trainability_value' for each row
dog_bites_df['trainability_value'] = dog_bites_df['trainability_value'].apply(adjust_trainability)

# %%
dog_bites_df
# Out:
#        UniqueID Species                Breed  Age Gender  SpayNeuter  \
# 0             1     DOG              unknown  NaN      U       False
# 1             2     DOG              unknown  NaN      U       False
# 2             3     DOG         bull terrier  NaN      U       False
# 3             4     DOG                mixed    4      M       False
# 4             5     DOG         bull terrier  NaN      U       False
# ...         ...     ...                  ...  ...    ...         ...
# 22658     10276     DOG                mixed    7      M        True
# 22659     10277     DOG              unknown    5      F        True
# 22660     10278     DOG  miniature schnauzer  10M      M        True
# 22661     10279     DOG                mixed  NaN      F       False
# 22662     10280     DOG                boxer  NaN      M       False
#
#              Borough ZipCode  Season        original_breed  \
# 0           Brooklyn   11220  Winter               unknown
# 1           Brooklyn     NaN  Winter               unknown
# 2           Brooklyn   11224  Winter              pit bull
# 3           Brooklyn   11231  Winter           mixed/other
# 4           Brooklyn   11224  Winter              pit bull
# ...              ...     ...     ...                   ...
# 22658  Staten Island   10303  Winter         chiweenie mix
# 22659  Staten Island   10303  Winter                dunker
# 22660  Staten Island   10312  Winter  schnauzer, miniature
# 22661  Staten Island   10308  Winter           mixed/other
# 22662  Staten Island   10314  Winter        boxer/pit bull
#
#        trainability_value          group
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2                    0.39  Terrier Group
# 3                     NaN            NaN
# 4                    0.20  Terrier Group
# ...                   ...            ...
# 22658                 NaN            NaN
# 22659                 NaN            NaN
# 22660                1.00  Terrier Group
# 22661                 NaN            NaN
# 22662                0.73  Working Group
#
# [22663 rows x 12 columns]

# %%
dog_bites_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22663 entries, 0 to 22662
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            22663 non-null  int64
#  1   Species             22663 non-null  object
#  2   Breed               22663 non-null  object
#  3   Age                 11442 non-null  object
#  4   Gender              22663 non-null  object
#  5   SpayNeuter          22663 non-null  bool
#  6   Borough             22663 non-null  object
#  7   ZipCode             16805 non-null  object
#  8   Season              22663 non-null  object
#  9   original_breed      22663 non-null  object
#  10  trainability_value  13299 non-null  float64
#  11  group               13476 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(9)
# memory usage: 1.9+ MB

# %%
df = dog_bites_df.dropna(subset=['trainability_value'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13299 entries, 2 to 22662
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            13299 non-null  int64
#  1   Species             13299 non-null  object
#  2   Breed               13299 non-null  object
#  3   Age                 7262 non-null   object
#  4   Gender              13299 non-null  object
#  5   SpayNeuter          13299 non-null  bool
#  6   Borough             13299 non-null  object
#  7   ZipCode             10355 non-null  object
#  8   Season              13299 non-null  object
#  9   original_breed      13299 non-null  object
#  10  trainability_value  13299 non-null  float64
#  11  group               13299 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(9)
# memory usage: 1.2+ MB

# %%
# Show the number of each distinct category of a specific feature
age_counts = dog_bites_df['Age'].value_counts().head(40)

# Print the result
print(age_counts)
# Out:
# 2          1624
# 3          1504
# 1          1365
# 4          1178
# 5          1040
# 6           795
# 7           655
# 8           569
# 9           375
# 10          361
# 11          242
# 12          188
# 13          140
# 8M           83
# 10M          80
# 14           75
# 11M          70
# 3M           66
# 4M           65
# 9M           55
# 15           51
# 6M           50
# 5M           50
# 2Y           47
# 7M           45
# 2M           34
# 3Y           33
# 1Y           27
# 4Y           26
# 16           22
# 3 YRS        20
# 5Y           20
# 2 YRS        20
# 6Y           17
# 8Y           14
# 4 YRS        13
# 10 MTHS      13
# 10Y          11
# 9 MTHS       11
# 4 MTHS       10
# Name: Age, dtype: int64

# %%
# 定义将年龄转换为月龄的函数
def convert_age_to_range(age):
    if pd.isnull(age):  # 缺失值直接返回 None
        return None
    try:
        age = str(age).strip().upper()
        if "Y" in age:  # 如果包含年
            years = int(''.join(filter(str.isdigit, age.split("Y")[0])))  # 提取数字部分
            if years <= 2:
                return "Puppy/Young (0-2 Years)"
            elif 3 <= years <= 7:
                return "Adult (3-7 Years)"
            else:
                return "Senior (8+ Years)"
        elif "M" in age:  # 如果包含月
            months = int(''.join(filter(str.isdigit, age.split("M")[0])))  # 提取数字部分
            if months <= 24:
                return "Puppy/Young (0-2 Years)"
            elif 25 <= months <= 84:
                return "Adult (3-7 Years)"
            else:
                return "Senior (8+ Years)"
        else:  # 如果既不包含年也不包含月，按默认逻辑处理为年
            years = int(''.join(filter(str.isdigit, age)))
            if years <= 2:
                return "Puppy/Young (0-2 Years)"
            elif 3 <= years <= 7:
                return "Adult (3-7 Years)"
            else:
                return "Senior (8+ Years)"
    except Exception as e:
        print(f"Error processing age: {age} -> {e}")
        return None

# 应用转换函数
dog_bites_df['Age_Range'] = dog_bites_df['Age'].apply(convert_age_to_range)

# Show the number of each distinct category of a specific feature
age_counts = dog_bites_df['Age_Range'].value_counts()

# Print the result
print(age_counts)
# Out:
# Error processing age: Y RS -> invalid literal for int() with base 10: ''
# Adult (3-7 Years)          5352
# Puppy/Young (0-2 Years)    3864
# Senior (8+ Years)          2225
# Name: Age_Range, dtype: int64

# %%
dog_bites_df
# Out:
#        UniqueID Species                Breed  Age Gender  SpayNeuter  \
# 0             1     DOG              unknown  NaN      U       False
# 1             2     DOG              unknown  NaN      U       False
# 2             3     DOG         bull terrier  NaN      U       False
# 3             4     DOG                mixed    4      M       False
# 4             5     DOG         bull terrier  NaN      U       False
# ...         ...     ...                  ...  ...    ...         ...
# 22658     10276     DOG                mixed    7      M        True
# 22659     10277     DOG              unknown    5      F        True
# 22660     10278     DOG  miniature schnauzer  10M      M        True
# 22661     10279     DOG                mixed  NaN      F       False
# 22662     10280     DOG                boxer  NaN      M       False
#
#              Borough ZipCode  Season        original_breed  \
# 0           Brooklyn   11220  Winter               unknown
# 1           Brooklyn     NaN  Winter               unknown
# 2           Brooklyn   11224  Winter              pit bull
# 3           Brooklyn   11231  Winter           mixed/other
# 4           Brooklyn   11224  Winter              pit bull
# ...              ...     ...     ...                   ...
# 22658  Staten Island   10303  Winter         chiweenie mix
# 22659  Staten Island   10303  Winter                dunker
# 22660  Staten Island   10312  Winter  schnauzer, miniature
# 22661  Staten Island   10308  Winter           mixed/other
# 22662  Staten Island   10314  Winter        boxer/pit bull
#
#        trainability_value          group                Age_Range
# 0                     NaN            NaN                     None
# 1                     NaN            NaN                     None
# 2                    0.39  Terrier Group                     None
# 3                     NaN            NaN        Adult (3-7 Years)
# 4                    0.20  Terrier Group                     None
# ...                   ...            ...                      ...
# 22658                 NaN            NaN        Adult (3-7 Years)
# 22659                 NaN            NaN        Adult (3-7 Years)
# 22660                1.00  Terrier Group  Puppy/Young (0-2 Years)
# 22661                 NaN            NaN                     None
# 22662                0.73  Working Group                     None
#
# [22663 rows x 13 columns]

# %%
dog_bites_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22663 entries, 0 to 22662
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            22663 non-null  int64
#  1   Species             22663 non-null  object
#  2   Breed               22663 non-null  object
#  3   Age                 11442 non-null  object
#  4   Gender              22663 non-null  object
#  5   SpayNeuter          22663 non-null  bool
#  6   Borough             22663 non-null  object
#  7   ZipCode             16805 non-null  object
#  8   Season              22663 non-null  object
#  9   original_breed      22663 non-null  object
#  10  trainability_value  13299 non-null  float64
#  11  group               13476 non-null  object
#  12  Age_Range           11441 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 2.1+ MB

# %%
df = dog_bites_df.dropna(subset=['trainability_value'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13299 entries, 2 to 22662
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            13299 non-null  int64
#  1   Species             13299 non-null  object
#  2   Breed               13299 non-null  object
#  3   Age                 7262 non-null   object
#  4   Gender              13299 non-null  object
#  5   SpayNeuter          13299 non-null  bool
#  6   Borough             13299 non-null  object
#  7   ZipCode             10355 non-null  object
#  8   Season              13299 non-null  object
#  9   original_breed      13299 non-null  object
#  10  trainability_value  13299 non-null  float64
#  11  group               13299 non-null  object
#  12  Age_Range           7261 non-null   object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 1.3+ MB

# %%
df = df.drop(columns=['UniqueID', 'Species', 'original_breed', 'ZipCode'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13299 entries, 2 to 22662
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Breed               13299 non-null  object
#  1   Age                 7262 non-null   object
#  2   Gender              13299 non-null  object
#  3   SpayNeuter          13299 non-null  bool
#  4   Borough             13299 non-null  object
#  5   Season              13299 non-null  object
#  6   trainability_value  13299 non-null  float64
#  7   group               13299 non-null  object
#  8   Age_Range           7261 non-null   object
# dtypes: bool(1), float64(1), object(7)
# memory usage: 948.1+ KB

# %%
df['Age_Range'] = df['Age_Range'].astype(str)

# %%
# preprocess with pipeline and columntransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

random_state = 42

# Define the feature and target variable
X = df.drop(columns=['trainability_value'])  # features
y = df['trainability_value']  # target

cat_ftrs = ['Breed','Gender','Borough','Season','group', 'SpayNeuter']
ordinal_ftrs = ['Age_Range']
ordinal_cats = [['Puppy/Young (0-2 Years)', 'Adult (3-7 Years)', 'Senior (8+ Years)', 'None']]

# one-hot encoder
# We need to replace the NaN with a string first!
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # 填充缺失值为出现频率最高的值
    ('onehot', OneHotEncoder(sparse_output=False,handle_unknown='ignore'))])

# ordinal encoder
# We need to replace the NaN with a string first!
ordinal_transformer = Pipeline(steps=[
    ('imputer2', SimpleImputer(strategy='constant',fill_value='None')),
    ('ordinal', OrdinalEncoder(categories = ordinal_cats))])

# collect the transformers
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, cat_ftrs),
        ('ord', ordinal_transformer, ordinal_ftrs)])

# %%
# we will use GridSearchCV and the parameter names need to contain the ML algorithm you want to use
# the parameters of some ML algorithms have the same name and this is how we avoid confusion
# param_grid = {
#               'randomforestclassifier__max_depth': [1, 3, 10, 30, 100], # the max_depth should be smaller or equal than the number of features roughly
#               'randomforestclassifier__max_features': [0.5,0.75,1.0] # linearly spaced between 0.5 and 1
#               } 

from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

models = {
    "RandomForest": RandomForestRegressor,
    "XGBoost": XGBRegressor,
    "SVR": SVR,
}

# 为每个模型定义对应的参数网格
# param_grids = {
#     "RandomForest": {
#         'randomforestregressor__max_depth': [1, 3, 10, 30, 100],
#         'randomforestregressor__max_features': [0.5, 0.75, 1.0],
#     },
#     "XGBoost": {
#         # 'xgbregressor__max_depth': [3, 6, 10],
#         'xgbregressor__learning_rate': [0.03],
#         'xgbregressor__n_estimators': [10000],
#         'xgbregressor__reg_alpha': [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2],
#         'xgbregressor__reg_lambda': [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2],
#         'xgbregressor__learning_rate': [0.03]
#     },
#     "SVR": {
#         'svr__C': [0.1, 1, 10],
#         'svr__kernel': ['linear', 'rbf'],
#         'svr__gamma': ['scale', 'auto'],
#     },
# }

param_grids = {
    "RandomForest": {
        'max_depth': [1, 3, 10, 30, 100],
        'max_features': [0.5, 0.75, 1.0],
    },
    "XGBoost": {
        'max_depth': [3, 6, 10],
        'learning_rate': [0.03],
        'n_estimators': [2500],
        'reg_alpha': [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2],
        'reg_lambda': [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2],
    },
    "SVR": {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf'],
        'gamma': ['scale', 'auto'],
    },
}

nr_states = 3

# Initialize result storage
test_scores = {model_name: [] for model_name in models.keys()}
train_scores = {model_name: [] for model_name in models.keys()}

for i in range(nr_states):
    print(f"\nRandom State {i + 1}:")

    # Split dataset into train, validation, and test sets
    X_train, X_other, y_train, y_other = train_test_split(X, y, train_size=0.6, random_state=42*i)
    X_val, X_test, y_val, y_test = train_test_split(X_other, y_other, train_size=0.5, random_state=42*i)

    for model_name, model_class in models.items():
        print(f"\nRunning model: {model_name}")

        param_grid = param_grids[model_name]
        param_list = list(ParameterGrid(param_grid))

        train_score = np.zeros(len(param_list))
        val_score = np.zeros(len(param_list))
        models_list = []

        # Iterate through hyperparameter configurations
        for p in range(len(param_list)):
            params = param_list[p]
            print("   ", params)
            model = model_class(**params, random_state=42*i) if 'random_state' in model_class().get_params() else model_class(**params)
            pipe = make_pipeline(preprocessor, model)
            pipe.fit(X_train, y_train)
            models_list.append(pipe)

            # Calculate train and validation scores
            y_train_pred = pipe.predict(X_train)
            train_score[p] = mean_squared_error(y_train, y_train_pred)

            y_val_pred = pipe.predict(X_val)
            val_score[p] = mean_squared_error(y_val, y_val_pred)

            print("   ", f"Train MSE: {train_score[p]:.8f} | Validation MSE: {val_score[p]:.8f}")

        # Find the best parameters based on validation score
        best_index = np.argmin(val_score)
        best_params = param_list[best_index]
        print('Best model parameters:', best_params)
        print('Corresponding validation MSE:', val_score[best_index])

        # Save the best model and calculate test score
        best_model = models_list[best_index]
        y_test_pred = best_model.predict(X_test)
        test_score = mean_squared_error(y_test, y_test_pred)
        print('Test score:', test_score)

# %%
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid

models = {
    "LinearRegression": LinearRegression,
    "Ridge": Ridge,
    "Lasso": Lasso,
    "RandomForest": RandomForestRegressor,
    "XGBoost": XGBRegressor,
    "SVR": SVR,
}

param_grids = {
    "Ridge": {
        'alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2],  # Regularization strength
    },
    "Lasso": {
        'alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2],  # Regularization strength
    }, 
    "LinearRegression": {
    }, 
    "RandomForest": {
        'max_depth': [1, 3, 10, 30, 100],
        'max_features': [0.5, 0.75, 1.0],
    },
    "XGBoost": {
        'learning_rate': [0.03],
        'n_estimators': [2500],
        'reg_alpha': [0e0, 1e-3, 1e-2, 1e-1, 1e0, 1e1],
        'reg_lambda': [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2],
        'max_depth' : [1,3,10,30,100]
    },
    "SVR": {
        'C': [1e-1, 1e0, 1e1, 1e2],
        'gamma': [1e-3, 1e-1, 1e1, 1e3, 1e5],
    },
}

nr_states = 3

# Initialize result storage
test_scores = {model_name: [] for model_name in models.keys()}
train_scores = {model_name: [] for model_name in models.keys()}

for i in range(nr_states):
    print(f"\nRandom State {i + 1}:")

    # Split dataset into train, validation, and test sets
    X_train, X_other, y_train, y_other = train_test_split(X, y, train_size=0.6, random_state=42*i)
    X_val, X_test, y_val, y_test = train_test_split(X_other, y_other, train_size=0.5, random_state=42*i)

    for model_name, model_class in models.items():
        print(f"\nRunning model: {model_name}")

        param_grid = param_grids[model_name]
        param_list = list(ParameterGrid(param_grid))

        train_score = np.zeros(len(param_list))
        val_score = np.zeros(len(param_list))
        models_list = []

        # Iterate through hyperparameter configurations
        for p in range(len(param_list)):
            params = param_list[p]
            print("   ", params)
            model = model_class(**params, random_state=42*i) if 'random_state' in model_class().get_params() else model_class(**params)
            pipe = make_pipeline(preprocessor, model)
            pipe.fit(X_train, y_train)
            models_list.append(pipe)

            # Calculate train and validation scores
            y_train_pred = pipe.predict(X_train)
            train_score[p] = mean_squared_error(y_train, y_train_pred)

            y_val_pred = pipe.predict(X_val)
            val_score[p] = mean_squared_error(y_val, y_val_pred)
        
            print("   ", f"Train MSE: {train_score[p]:.8f} | Validation MSE: {val_score[p]:.8f}")

            
        # Find the best parameters based on validation score
        best_index = np.argmin(val_score)
        best_params = param_list[best_index]
        
        print('Best model parameters:', best_params)
        print('Corresponding validation MSE:', val_score[best_index])

        # Save the best model and calculate test score
        best_model = models_list[best_index]
        y_test_pred = best_model.predict(X_test)
        test_score = mean_squared_error(y_test, y_test_pred)
        test_scores[model_name].append(test_score)
        print('Test score:', test_score)

# Aggregate test scores to compute mean and standard deviation for error bars
test_score_means = {model_name: np.mean(scores) for model_name, scores in test_scores.items()}
test_score_stds = {model_name: np.std(scores) for model_name, scores in test_scores.items()}
# Out:
# Random State 1:
#
# Running model: LinearRegression
#     {}
#     Train MSE: 0.01166045 | Validation MSE: 51555530506788249600.00000000
# Best model parameters: {}
# Corresponding validation MSE: 5.155553050678825e+19
# Test score: 3.028740543999865e+20
#
# Running model: Ridge
#     {'alpha': 0.001}
#     Train MSE: 0.01163889 | Validation MSE: 0.01249885
#     {'alpha': 0.01}
#     Train MSE: 0.01163892 | Validation MSE: 0.01249603
#     {'alpha': 0.1}
#     Train MSE: 0.01164120 | Validation MSE: 0.01247171
#     {'alpha': 1.0}
#     Train MSE: 0.01173992 | Validation MSE: 0.01240137
#     {'alpha': 10.0}
#     Train MSE: 0.01296916 | Validation MSE: 0.01333010
#     {'alpha': 100.0}
#     Train MSE: 0.01950053 | Validation MSE: 0.02012353
# Best model parameters: {'alpha': 1.0}
# Corresponding validation MSE: 0.012401371470315576
# Test score: 0.012488836195348766
#
# Running model: Lasso
#     {'alpha': 0.001}
#     Train MSE: 0.01881422 | Validation MSE: 0.01960652
#     {'alpha': 0.01}
#     Train MSE: 0.03634025 | Validation MSE: 0.03670257
#     {'alpha': 0.1}
#     Train MSE: 0.06085277 | Validation MSE: 0.05992314
#     {'alpha': 1.0}
#     Train MSE: 0.06085277 | Validation MSE: 0.05992314
#     {'alpha': 10.0}
#     Train MSE: 0.06085277 | Validation MSE: 0.05992314
#     {'alpha': 100.0}
#     Train MSE: 0.06085277 | Validation MSE: 0.05992314
# Best model parameters: {'alpha': 0.001}
# Corresponding validation MSE: 0.019606523676152867
# Test score: 0.021347268029905827
#
# Running model: RandomForest
#     {'max_depth': 1, 'max_features': 0.5}
#     Train MSE: 0.04624941 | Validation MSE: 0.04718440
#     {'max_depth': 1, 'max_features': 0.75}
#     Train MSE: 0.04696341 | Validation MSE: 0.04828915
#     {'max_depth': 1, 'max_features': 1.0}
#     Train MSE: 0.04821236 | Validation MSE: 0.04975967
#     {'max_depth': 3, 'max_features': 0.5}
#     Train MSE: 0.03039303 | Validation MSE: 0.03056659
#     {'max_depth': 3, 'max_features': 0.75}
#     Train MSE: 0.03160444 | Validation MSE: 0.03190815
#     {'max_depth': 3, 'max_features': 1.0}
#     Train MSE: 0.03435489 | Validation MSE: 0.03506856
#     {'max_depth': 10, 'max_features': 0.5}
#     Train MSE: 0.01629847 | Validation MSE: 0.01799362
#     {'max_depth': 10, 'max_features': 0.75}
#     Train MSE: 0.01722446 | Validation MSE: 0.01903813
#     {'max_depth': 10, 'max_features': 1.0}
#     Train MSE: 0.01776349 | Validation MSE: 0.01966597
#     {'max_depth': 30, 'max_features': 0.5}
#     Train MSE: 0.00966736 | Validation MSE: 0.01407807
#     {'max_depth': 30, 'max_features': 0.75}
#     Train MSE: 0.01015828 | Validation MSE: 0.01423869
#     {'max_depth': 30, 'max_features': 1.0}
#     Train MSE: 0.01033723 | Validation MSE: 0.01429761
#     {'max_depth': 100, 'max_features': 0.5}
#     Train MSE: 0.00754020 | Validation MSE: 0.01429598
#     {'max_depth': 100, 'max_features': 0.75}
#     Train MSE: 0.00755102 | Validation MSE: 0.01429348
#     {'max_depth': 100, 'max_features': 1.0}
#     Train MSE: 0.00755648 | Validation MSE: 0.01432542
# Best model parameters: {'max_depth': 30, 'max_features': 0.5}
# Corresponding validation MSE: 0.014078070217026782
# Test score: 0.01470411701930535
#
# Running model: XGBoost
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01292434 | Validation MSE: 0.01308664
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01292595 | Validation MSE: 0.01308544
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01293985 | Validation MSE: 0.01309169
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01305046 | Validation MSE: 0.01314866
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01363952 | Validation MSE: 0.01363402
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01627514 | Validation MSE: 0.01645793
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01292517 | Validation MSE: 0.01308670
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01292678 | Validation MSE: 0.01308587
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01294066 | Validation MSE: 0.01309047
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.01305119 | Validation MSE: 0.01315056
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.01364005 | Validation MSE: 0.01363452
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.01627557 | Validation MSE: 0.01645843
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01293274 | Validation MSE: 0.01308919
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01293430 | Validation MSE: 0.01309013
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01294806 | Validation MSE: 0.01309261
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.01305764 | Validation MSE: 0.01315737
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.01364467 | Validation MSE: 0.01363892
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.01627920 | Validation MSE: 0.01646181
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01300948 | Validation MSE: 0.01313020
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01301090 | Validation MSE: 0.01313052
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01302293 | Validation MSE: 0.01313669
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.01312257 | Validation MSE: 0.01320760
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.01369113 | Validation MSE: 0.01368393
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.01631506 | Validation MSE: 0.01650972
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01369699 | Validation MSE: 0.01371230
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01369761 | Validation MSE: 0.01371290
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01370213 | Validation MSE: 0.01371493
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01375348 | Validation MSE: 0.01376184
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01418659 | Validation MSE: 0.01416582
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01668464 | Validation MSE: 0.01697172
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02018822 | Validation MSE: 0.02094857
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02018853 | Validation MSE: 0.02094894
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02018855 | Validation MSE: 0.02094873
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02019168 | Validation MSE: 0.02095163
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02022765 | Validation MSE: 0.02098330
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02067586 | Validation MSE: 0.02140597
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01103440 | Validation MSE: 0.01281152
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01105349 | Validation MSE: 0.01281273
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01107571 | Validation MSE: 0.01278182
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01129522 | Validation MSE: 0.01264276
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01195911 | Validation MSE: 0.01260314
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01338180 | Validation MSE: 0.01350976
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01106641 | Validation MSE: 0.01280127
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01105591 | Validation MSE: 0.01281437
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01108758 | Validation MSE: 0.01279971
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.01128713 | Validation MSE: 0.01264632
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.01196198 | Validation MSE: 0.01260689
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.01337645 | Validation MSE: 0.01350326
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01106179 | Validation MSE: 0.01279389
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01106645 | Validation MSE: 0.01278841
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01109647 | Validation MSE: 0.01279004
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.01131917 | Validation MSE: 0.01263189
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.01197097 | Validation MSE: 0.01260273
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.01342147 | Validation MSE: 0.01353158
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01130855 | Validation MSE: 0.01264597
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01130687 | Validation MSE: 0.01265621
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01133119 | Validation MSE: 0.01262996
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.01147899 | Validation MSE: 0.01259452
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.01204575 | Validation MSE: 0.01262657
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.01342424 | Validation MSE: 0.01354437
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01259472 | Validation MSE: 0.01302478
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01259293 | Validation MSE: 0.01302416
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01259335 | Validation MSE: 0.01302292
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01260950 | Validation MSE: 0.01302944
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01278985 | Validation MSE: 0.01312384
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01384343 | Validation MSE: 0.01393894
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01973920 | Validation MSE: 0.02049821
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01973471 | Validation MSE: 0.02049360
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01973888 | Validation MSE: 0.02049832
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01973156 | Validation MSE: 0.02049318
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01972959 | Validation MSE: 0.02050625
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01965424 | Validation MSE: 0.02038562
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.00739388 | Validation MSE: 0.01507000
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.00739282 | Validation MSE: 0.01509185
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.00748728 | Validation MSE: 0.01501465
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.00840637 | Validation MSE: 0.01407204
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01058536 | Validation MSE: 0.01278466
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01156272 | Validation MSE: 0.01256353
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.00735176 | Validation MSE: 0.01517239
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.00745193 | Validation MSE: 0.01507871
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.00754998 | Validation MSE: 0.01492262
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.00842667 | Validation MSE: 0.01419059
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.01054535 | Validation MSE: 0.01279611
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.01157187 | Validation MSE: 0.01256623
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.00751445 | Validation MSE: 0.01488396
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.00744686 | Validation MSE: 0.01492859
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.00762503 | Validation MSE: 0.01482827
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.00827089 | Validation MSE: 0.01413030
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.01039268 | Validation MSE: 0.01278643
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.01158873 | Validation MSE: 0.01256371
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.00836973 | Validation MSE: 0.01386369
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.00841192 | Validation MSE: 0.01383643
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.00818348 | Validation MSE: 0.01403263
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.00838977 | Validation MSE: 0.01389254
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.01038918 | Validation MSE: 0.01279541
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.01158863 | Validation MSE: 0.01257481
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01189672 | Validation MSE: 0.01296922
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01185505 | Validation MSE: 0.01297494
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01185837 | Validation MSE: 0.01299641
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01187735 | Validation MSE: 0.01298317
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01187022 | Validation MSE: 0.01295071
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01210541 | Validation MSE: 0.01287218
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01801555 | Validation MSE: 0.01884949
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01801561 | Validation MSE: 0.01884954
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01801613 | Validation MSE: 0.01885001
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01798580 | Validation MSE: 0.01881529
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01800556 | Validation MSE: 0.01883169
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01760797 | Validation MSE: 0.01838101
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.00690226 | Validation MSE: 0.01685296
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.00690690 | Validation MSE: 0.01675687
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.00690817 | Validation MSE: 0.01643768
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.00690956 | Validation MSE: 0.01607791
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.00707546 | Validation MSE: 0.01530077
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.00952711 | Validation MSE: 0.01317254
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.00690154 | Validation MSE: 0.01662516
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.00690289 | Validation MSE: 0.01651781
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.00691563 | Validation MSE: 0.01631753
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.00690391 | Validation MSE: 0.01596613
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.00703532 | Validation MSE: 0.01530322
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.00937247 | Validation MSE: 0.01325296
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.00692074 | Validation MSE: 0.01595885
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.00691229 | Validation MSE: 0.01596558
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.00691769 | Validation MSE: 0.01599572
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.00692008 | Validation MSE: 0.01575232
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.00693810 | Validation MSE: 0.01550325
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.00944372 | Validation MSE: 0.01316165
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.00731977 | Validation MSE: 0.01470108
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.00734580 | Validation MSE: 0.01464948
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.00730914 | Validation MSE: 0.01465107
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.00735376 | Validation MSE: 0.01460833
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.00739556 | Validation MSE: 0.01453853
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.00839625 | Validation MSE: 0.01388536
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01099442 | Validation MSE: 0.01302321
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01097377 | Validation MSE: 0.01300887
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01097806 | Validation MSE: 0.01303809
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01087282 | Validation MSE: 0.01301610
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01092898 | Validation MSE: 0.01295775
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01090874 | Validation MSE: 0.01284592
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01446393 | Validation MSE: 0.01501088
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01441532 | Validation MSE: 0.01496063
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01449096 | Validation MSE: 0.01503681
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01442385 | Validation MSE: 0.01497021
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01437583 | Validation MSE: 0.01492224
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01427272 | Validation MSE: 0.01478528
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.00689468 | Validation MSE: 0.01788241
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.00689467 | Validation MSE: 0.01777470
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.00689476 | Validation MSE: 0.01737626
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.00689526 | Validation MSE: 0.01619883
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.00689692 | Validation MSE: 0.01592390
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.00702720 | Validation MSE: 0.01543839
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.00689547 | Validation MSE: 0.01747216
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.00689542 | Validation MSE: 0.01742627
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.00689559 | Validation MSE: 0.01712084
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.00689619 | Validation MSE: 0.01618409
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.00689782 | Validation MSE: 0.01591518
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.00703516 | Validation MSE: 0.01539684
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.00690525 | Validation MSE: 0.01638809
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.00690509 | Validation MSE: 0.01638207
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.00690561 | Validation MSE: 0.01640826
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.00690660 | Validation MSE: 0.01599044
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.00690866 | Validation MSE: 0.01577426
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.00704942 | Validation MSE: 0.01533432
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.00722525 | Validation MSE: 0.01488378
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.00719738 | Validation MSE: 0.01493875
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.00721040 | Validation MSE: 0.01488962
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.00725808 | Validation MSE: 0.01487495
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.00723297 | Validation MSE: 0.01495767
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.00748777 | Validation MSE: 0.01465641
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01026586 | Validation MSE: 0.01291101
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01036084 | Validation MSE: 0.01291478
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01048347 | Validation MSE: 0.01288423
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01044477 | Validation MSE: 0.01289491
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01068955 | Validation MSE: 0.01283584
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01033760 | Validation MSE: 0.01288427
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01256721 | Validation MSE: 0.01346239
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01256724 | Validation MSE: 0.01346242
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01255523 | Validation MSE: 0.01344029
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01264898 | Validation MSE: 0.01354198
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01268020 | Validation MSE: 0.01356496
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01273167 | Validation MSE: 0.01363713
# Best model parameters: {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
# Corresponding validation MSE: 0.012563531302890573
# Test score: 0.012998499535842084
#
# Running model: SVR
#     {'C': 0.1, 'gamma': 0.001}
#     Train MSE: 0.03592071 | Validation MSE: 0.03656295
#     {'C': 0.1, 'gamma': 0.1}
#     Train MSE: 0.01413420 | Validation MSE: 0.01584427
#     {'C': 0.1, 'gamma': 10.0}
#     Train MSE: 0.02208923 | Validation MSE: 0.03614146
#     {'C': 0.1, 'gamma': 1000.0}
#     Train MSE: 0.02209022 | Validation MSE: 0.03614120
#     {'C': 0.1, 'gamma': 100000.0}
#     Train MSE: 0.02209022 | Validation MSE: 0.03614120
#     {'C': 1.0, 'gamma': 0.001}
#     Train MSE: 0.02055134 | Validation MSE: 0.02145107
#     {'C': 1.0, 'gamma': 0.1}
#     Train MSE: 0.01052952 | Validation MSE: 0.01362713
#     {'C': 1.0, 'gamma': 10.0}
#     Train MSE: 0.01038830 | Validation MSE: 0.03205972
#     {'C': 1.0, 'gamma': 1000.0}
#     Train MSE: 0.01038571 | Validation MSE: 0.03205902
#     {'C': 1.0, 'gamma': 100000.0}
#     Train MSE: 0.01038571 | Validation MSE: 0.03205902
#     {'C': 10.0, 'gamma': 0.001}
#     Train MSE: 0.01330246 | Validation MSE: 0.01374070
#     {'C': 10.0, 'gamma': 0.1}
#     Train MSE: 0.00977498 | Validation MSE: 0.01450659
#     {'C': 10.0, 'gamma': 10.0}
#     Train MSE: 0.01038830 | Validation MSE: 0.03205972
#     {'C': 10.0, 'gamma': 1000.0}
#     Train MSE: 0.01038510 | Validation MSE: 0.03205783
#     {'C': 10.0, 'gamma': 100000.0}
#     Train MSE: 0.01038510 | Validation MSE: 0.03205783
#     {'C': 100.0, 'gamma': 0.001}
#     Train MSE: 0.01190532 | Validation MSE: 0.01278792
#     {'C': 100.0, 'gamma': 0.1}
#     Train MSE: 0.00962448 | Validation MSE: 0.01507561
#     {'C': 100.0, 'gamma': 10.0}
#     Train MSE: 0.01038830 | Validation MSE: 0.03205972
#     {'C': 100.0, 'gamma': 1000.0}
#     Train MSE: 0.01038607 | Validation MSE: 0.03205916
#     {'C': 100.0, 'gamma': 100000.0}
#     Train MSE: 0.01038607 | Validation MSE: 0.03205916
# Best model parameters: {'C': 100.0, 'gamma': 0.001}
# Corresponding validation MSE: 0.01278792480737223
# Test score: 0.01279560246395059
#
# Random State 2:
#
# Running model: LinearRegression
#     {}
#     Train MSE: 0.01163917 | Validation MSE: 73678952625054588928.00000000
# Best model parameters: {}
# Corresponding validation MSE: 7.367895262505459e+19
# Test score: 9.063216097187211e+19
#
# Running model: Ridge
#     {'alpha': 0.001}
#     Train MSE: 0.01161194 | Validation MSE: 0.01220909
#     {'alpha': 0.01}
#     Train MSE: 0.01161197 | Validation MSE: 0.01220742
#     {'alpha': 0.1}
#     Train MSE: 0.01161455 | Validation MSE: 0.01219473
#     {'alpha': 1.0}
#     Train MSE: 0.01171793 | Validation MSE: 0.01222431
#     {'alpha': 10.0}
#     Train MSE: 0.01288354 | Validation MSE: 0.01326661
#     {'alpha': 100.0}
#     Train MSE: 0.01960903 | Validation MSE: 0.02013376
# Best model parameters: {'alpha': 0.1}
# Corresponding validation MSE: 0.012194733196494736
# Test score: 0.012518336540676068
#
# Running model: Lasso
#     {'alpha': 0.001}
#     Train MSE: 0.01856726 | Validation MSE: 0.01893601
#     {'alpha': 0.01}
#     Train MSE: 0.03655023 | Validation MSE: 0.03808682
#     {'alpha': 0.1}
#     Train MSE: 0.06050633 | Validation MSE: 0.06315595
#     {'alpha': 1.0}
#     Train MSE: 0.06050633 | Validation MSE: 0.06315595
#     {'alpha': 10.0}
#     Train MSE: 0.06050633 | Validation MSE: 0.06315595
#     {'alpha': 100.0}
#     Train MSE: 0.06050633 | Validation MSE: 0.06315595
# Best model parameters: {'alpha': 0.001}
# Corresponding validation MSE: 0.01893601440695308
# Test score: 0.01985798557575154
#
# Running model: RandomForest
#     {'max_depth': 1, 'max_features': 0.5}
#     Train MSE: 0.04521193 | Validation MSE: 0.04729049
#     {'max_depth': 1, 'max_features': 0.75}
#     Train MSE: 0.04594935 | Validation MSE: 0.04794874
#     {'max_depth': 1, 'max_features': 1.0}
#     Train MSE: 0.04825813 | Validation MSE: 0.05006826
#     {'max_depth': 3, 'max_features': 0.5}
#     Train MSE: 0.03010577 | Validation MSE: 0.03131042
#     {'max_depth': 3, 'max_features': 0.75}
#     Train MSE: 0.03106982 | Validation MSE: 0.03235175
#     {'max_depth': 3, 'max_features': 1.0}
#     Train MSE: 0.03347880 | Validation MSE: 0.03482079
#     {'max_depth': 10, 'max_features': 0.5}
#     Train MSE: 0.01669818 | Validation MSE: 0.01858526
#     {'max_depth': 10, 'max_features': 0.75}
#     Train MSE: 0.01711546 | Validation MSE: 0.01920969
#     {'max_depth': 10, 'max_features': 1.0}
#     Train MSE: 0.01783959 | Validation MSE: 0.01999745
#     {'max_depth': 30, 'max_features': 0.5}
#     Train MSE: 0.00980112 | Validation MSE: 0.01434515
#     {'max_depth': 30, 'max_features': 0.75}
#     Train MSE: 0.01002844 | Validation MSE: 0.01444183
#     {'max_depth': 30, 'max_features': 1.0}
#     Train MSE: 0.01019512 | Validation MSE: 0.01453683
#     {'max_depth': 100, 'max_features': 0.5}
#     Train MSE: 0.00756679 | Validation MSE: 0.01444251
#     {'max_depth': 100, 'max_features': 0.75}
#     Train MSE: 0.00757873 | Validation MSE: 0.01447987
#     {'max_depth': 100, 'max_features': 1.0}
#     Train MSE: 0.00758218 | Validation MSE: 0.01446124
# Best model parameters: {'max_depth': 30, 'max_features': 0.5}
# Corresponding validation MSE: 0.014345153505587335
# Test score: 0.014669839117744872
#
# Running model: XGBoost
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01284361 | Validation MSE: 0.01340666
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01284532 | Validation MSE: 0.01340778
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01286010 | Validation MSE: 0.01341442
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01297490 | Validation MSE: 0.01349042
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01354254 | Validation MSE: 0.01393038
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01616555 | Validation MSE: 0.01644324
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01284444 | Validation MSE: 0.01340733
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01284615 | Validation MSE: 0.01340837
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01286091 | Validation MSE: 0.01341630
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.01297559 | Validation MSE: 0.01349099
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.01354306 | Validation MSE: 0.01393135
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.01616594 | Validation MSE: 0.01644365
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01285204 | Validation MSE: 0.01340967
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01285370 | Validation MSE: 0.01341177
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01286822 | Validation MSE: 0.01342241
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.01298179 | Validation MSE: 0.01349743
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.01354758 | Validation MSE: 0.01393635
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.01616952 | Validation MSE: 0.01644762
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01292894 | Validation MSE: 0.01346578
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01293060 | Validation MSE: 0.01346537
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01294366 | Validation MSE: 0.01347287
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.01304620 | Validation MSE: 0.01353087
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.01359340 | Validation MSE: 0.01397255
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.01620547 | Validation MSE: 0.01648465
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01360447 | Validation MSE: 0.01396552
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01360502 | Validation MSE: 0.01396602
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01361033 | Validation MSE: 0.01396963
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01365923 | Validation MSE: 0.01401406
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01407014 | Validation MSE: 0.01438686
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01657778 | Validation MSE: 0.01687500
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02029227 | Validation MSE: 0.02077211
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02029237 | Validation MSE: 0.02077221
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02029313 | Validation MSE: 0.02077323
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02029852 | Validation MSE: 0.02077913
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02035998 | Validation MSE: 0.02084645
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02099286 | Validation MSE: 0.02153136
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01109772 | Validation MSE: 0.01266110
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01111192 | Validation MSE: 0.01265243
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01113419 | Validation MSE: 0.01266829
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01131900 | Validation MSE: 0.01261351
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01192484 | Validation MSE: 0.01281093
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01319825 | Validation MSE: 0.01362118
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01110025 | Validation MSE: 0.01265576
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01111133 | Validation MSE: 0.01264545
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01112910 | Validation MSE: 0.01266128
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.01131892 | Validation MSE: 0.01261479
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.01193008 | Validation MSE: 0.01282061
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.01320612 | Validation MSE: 0.01363020
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01111720 | Validation MSE: 0.01267040
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01112078 | Validation MSE: 0.01267054
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01114679 | Validation MSE: 0.01267090
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.01133773 | Validation MSE: 0.01261093
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.01193095 | Validation MSE: 0.01281958
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.01320265 | Validation MSE: 0.01362559
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01133782 | Validation MSE: 0.01260893
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01132661 | Validation MSE: 0.01260691
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01135250 | Validation MSE: 0.01261516
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.01149466 | Validation MSE: 0.01264293
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.01200540 | Validation MSE: 0.01285526
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.01322657 | Validation MSE: 0.01364375
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01249545 | Validation MSE: 0.01317867
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01249899 | Validation MSE: 0.01318034
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01249993 | Validation MSE: 0.01318316
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01251469 | Validation MSE: 0.01318823
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01266337 | Validation MSE: 0.01326941
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01361755 | Validation MSE: 0.01394609
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01967712 | Validation MSE: 0.02022493
#     {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01967648 | Validation MSE: 0.02022521
# ...
#     Train MSE: 0.00839611 | Validation MSE: 0.01421432
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.01025356 | Validation MSE: 0.01308685
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.01148608 | Validation MSE: 0.01297052
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01183821 | Validation MSE: 0.01345657
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01181249 | Validation MSE: 0.01345931
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01182239 | Validation MSE: 0.01346427
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01182289 | Validation MSE: 0.01346897
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01191119 | Validation MSE: 0.01339366
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01208975 | Validation MSE: 0.01330744
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01787815 | Validation MSE: 0.01918440
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01769146 | Validation MSE: 0.01895664
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01767045 | Validation MSE: 0.01894961
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01769743 | Validation MSE: 0.01897520
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01778279 | Validation MSE: 0.01903471
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01741827 | Validation MSE: 0.01847217
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.00688450 | Validation MSE: 0.01772165
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.00688369 | Validation MSE: 0.01748676
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.00689836 | Validation MSE: 0.01736632
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.00688352 | Validation MSE: 0.01715573
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.00699424 | Validation MSE: 0.01615649
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.00948096 | Validation MSE: 0.01353061
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.00688360 | Validation MSE: 0.01732886
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.00688464 | Validation MSE: 0.01730565
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.00688900 | Validation MSE: 0.01732920
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.00689819 | Validation MSE: 0.01692794
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.00697293 | Validation MSE: 0.01619214
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.00947777 | Validation MSE: 0.01351771
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.00689048 | Validation MSE: 0.01701809
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.00689793 | Validation MSE: 0.01695507
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.00690047 | Validation MSE: 0.01703009
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.00689890 | Validation MSE: 0.01691103
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.00690417 | Validation MSE: 0.01644972
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.00945360 | Validation MSE: 0.01353578
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.00739100 | Validation MSE: 0.01522932
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.00730692 | Validation MSE: 0.01535975
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.00730465 | Validation MSE: 0.01536471
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.00732067 | Validation MSE: 0.01531917
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.00749960 | Validation MSE: 0.01499489
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.00833888 | Validation MSE: 0.01438847
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01086326 | Validation MSE: 0.01341094
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01089452 | Validation MSE: 0.01333794
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01098580 | Validation MSE: 0.01337732
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01086105 | Validation MSE: 0.01342038
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01098112 | Validation MSE: 0.01338725
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01095181 | Validation MSE: 0.01316090
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01439020 | Validation MSE: 0.01537319
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01439027 | Validation MSE: 0.01537324
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01437526 | Validation MSE: 0.01535656
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01437372 | Validation MSE: 0.01534800
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01426662 | Validation MSE: 0.01523968
#     {'learning_rate': 0.03, 'max_depth': 30, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01419003 | Validation MSE: 0.01507620
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.00687525 | Validation MSE: 0.01858272
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.00687530 | Validation MSE: 0.01839291
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.00687550 | Validation MSE: 0.01783731
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.00687597 | Validation MSE: 0.01723215
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.00687849 | Validation MSE: 0.01697982
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.00702176 | Validation MSE: 0.01643831
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.00687611 | Validation MSE: 0.01811966
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.00687611 | Validation MSE: 0.01808144
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.00687629 | Validation MSE: 0.01768049
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.00687667 | Validation MSE: 0.01723009
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.00687994 | Validation MSE: 0.01694000
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.00702304 | Validation MSE: 0.01643126
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.00688450 | Validation MSE: 0.01746985
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.00688497 | Validation MSE: 0.01739030
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.00688476 | Validation MSE: 0.01735825
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.00688708 | Validation MSE: 0.01701518
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.00689026 | Validation MSE: 0.01672101
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.00704614 | Validation MSE: 0.01639662
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.00720988 | Validation MSE: 0.01566323
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.00721640 | Validation MSE: 0.01567636
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.00721684 | Validation MSE: 0.01567752
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.00725013 | Validation MSE: 0.01553114
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.00727662 | Validation MSE: 0.01552933
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.00746854 | Validation MSE: 0.01555856
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01033923 | Validation MSE: 0.01322372
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01040505 | Validation MSE: 0.01324957
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01019563 | Validation MSE: 0.01332647
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01043494 | Validation MSE: 0.01325023
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01054538 | Validation MSE: 0.01333717
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01035853 | Validation MSE: 0.01345511
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01264351 | Validation MSE: 0.01379676
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01264354 | Validation MSE: 0.01379680
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01263509 | Validation MSE: 0.01378409
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01260750 | Validation MSE: 0.01375900
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01247856 | Validation MSE: 0.01352800
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01266196 | Validation MSE: 0.01372997
# Best model parameters: {'learning_rate': 0.03, 'max_depth': 3, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
# Corresponding validation MSE: 0.01278657099810794
# Test score: 0.013058893782761033
#
# Running model: SVR
#     {'C': 0.1, 'gamma': 0.001}
#     Train MSE: 0.03554864 | Validation MSE: 0.03640164
#     {'C': 0.1, 'gamma': 0.1}
#     Train MSE: 0.01407859 | Validation MSE: 0.01613581
#     {'C': 0.1, 'gamma': 10.0}
#     Train MSE: 0.02183367 | Validation MSE: 0.03573730
#     {'C': 0.1, 'gamma': 1000.0}
#     Train MSE: 0.02183108 | Validation MSE: 0.03573596
#     {'C': 0.1, 'gamma': 100000.0}
#     Train MSE: 0.02183108 | Validation MSE: 0.03573596
#     {'C': 1.0, 'gamma': 0.001}
#     Train MSE: 0.02047295 | Validation MSE: 0.02185956
#     {'C': 1.0, 'gamma': 0.1}
#     Train MSE: 0.01052217 | Validation MSE: 0.01373986
#     {'C': 1.0, 'gamma': 10.0}
#     Train MSE: 0.01036562 | Validation MSE: 0.03195771
#     {'C': 1.0, 'gamma': 1000.0}
#     Train MSE: 0.01036443 | Validation MSE: 0.03195724
#     {'C': 1.0, 'gamma': 100000.0}
#     Train MSE: 0.01036443 | Validation MSE: 0.03195724
#     {'C': 10.0, 'gamma': 0.001}
#     Train MSE: 0.01319603 | Validation MSE: 0.01405885
#     {'C': 10.0, 'gamma': 0.1}
#     Train MSE: 0.00982657 | Validation MSE: 0.01464487
#     {'C': 10.0, 'gamma': 10.0}
#     Train MSE: 0.01036562 | Validation MSE: 0.03195771
#     {'C': 10.0, 'gamma': 1000.0}
#     Train MSE: 0.01036430 | Validation MSE: 0.03195726
#     {'C': 10.0, 'gamma': 100000.0}
#     Train MSE: 0.01036430 | Validation MSE: 0.03195726
#     {'C': 100.0, 'gamma': 0.001}
#     Train MSE: 0.01194096 | Validation MSE: 0.01279451
#     {'C': 100.0, 'gamma': 0.1}
#     Train MSE: 0.00962639 | Validation MSE: 0.01534134
#     {'C': 100.0, 'gamma': 10.0}
#     Train MSE: 0.01036562 | Validation MSE: 0.03195771
#     {'C': 100.0, 'gamma': 1000.0}
#     Train MSE: 0.01036407 | Validation MSE: 0.03195766
#     {'C': 100.0, 'gamma': 100000.0}
#     Train MSE: 0.01036407 | Validation MSE: 0.03195766
# Best model parameters: {'C': 100.0, 'gamma': 0.001}
# Corresponding validation MSE: 0.01279450658437797
# Test score: 0.012984944572712398

# %%
# Plot the results
model_names = list(test_scores.keys())
means = [test_score_means[name] for name in model_names]
stds = [test_score_stds[name] for name in model_names]

plt.figure(figsize=(8, 5))
plt.errorbar(model_names, means, yerr=stds, fmt='o', capsize=5)
plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("Accuracy")
plt.show()

# %%
filtered_model_names = [name for name in model_names if name != "LinearRegression"]
filtered_means = [test_score_means[name] for name in filtered_model_names]
filtered_stds = [test_score_stds[name] for name in filtered_model_names]

# Plot the results
plt.figure(figsize=(8, 5))
plt.errorbar(filtered_model_names, filtered_means, yerr=filtered_stds, fmt='o', capsize=5)
plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("Accuracy")
plt.show()

# %%
filtered_model_names = [name for name in model_names if (name != "LinearRegression" and name != "Lasso")]
filtered_means = [test_score_means[name] for name in filtered_model_names]
filtered_stds = [test_score_stds[name] for name in filtered_model_names]

# Plot the results
plt.figure(figsize=(8, 5))
plt.errorbar(filtered_model_names, filtered_means, yerr=filtered_stds, fmt='o', capsize=5)
plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# ### **Updated Markdown for Report**
#
# ---
#
# ### **Methods**
#
# #### **Splitting Strategy**
# The dataset was split into **training (60%)**, **validation (20%)**, and **test (20%)** sets to evaluate model performance effectively. I used the `train_test_split` method from `scikit-learn` with three different random seeds to account for variability introduced by random splitting. This approach ensures robust evaluation metrics that are not overly dependent on a single split.
#
# #### **Data Preprocessing**
# - **Categorical Variables**: Processed using **OneHotEncoder** to convert them into numerical formats suitable for modeling.
# - **Ordinal Variables**: Transformed using **OrdinalEncoder** to retain the ordinal nature of the data.
# - **Missing Values**:
#   - **Categorical features** were imputed using the most frequent value.
#   - **Numerical features** were imputed using **IterativeImputer** to preserve relationships between features.
# - **Numerical Scaling**: All numerical features were scaled using **StandardScaler** to ensure consistent magnitude, which benefits models sensitive to feature scaling.
#
# #### **Machine Learning Pipeline**
# I implemented a pipeline to automate data preprocessing and modeling for the following algorithms:
#
# 1. **Linear Models**:
#    - **LinearRegression**: Basic linear regression without regularization.
#    - **Ridge**: Linear regression with L2 regularization.
#    - **Lasso**: Linear regression with L1 regularization.
#
# 2. **Non-Linear Models**:
#    - **RandomForestRegressor**: An ensemble-based tree model capable of capturing complex feature interactions.
#    - **XGBoost**: Gradient boosting that handles non-linear relationships well.
#    - **SVR (Support Vector Regression)**: A kernel-based approach for non-linear regression.
#
# #### **Hyperparameter Tuning**
# Hyperparameters for each model were tuned using a grid search with cross-validation on the training and validation sets. The following parameters were explored:
# - **Ridge**: Regularization strength (`alpha`) was varied over `[0.01, 0.1, 1, 10, 100]`.
# - **Lasso**: Regularization strength (`alpha`) was tuned over `[0.01, 0.1, 1, 10, 100]`.
# - **RandomForest**: Maximum depth (`max_depth`) and maximum features (`max_features`) were explored.
# - **XGBoost**: Learning rate, number of estimators, and regularization parameters (`reg_alpha` and `reg_lambda`) were tuned.
# - **SVR**: Regularization parameter (`C`) and kernel coefficients (`gamma`) were tuned.
#
# #### **Evaluation Metrics**
# The **Mean Squared Error (MSE)** was selected as the primary evaluation metric because:
# 1. It emphasizes larger errors by squaring deviations, which is beneficial in regression tasks with outliers.
# 2. It provides a clear measure of the difference between predicted and actual values, making it interpretable for continuous outcomes.
#
# To measure uncertainties:
# 1. **Splitting Variability**:
#    - The dataset was split into train-validation-test sets using three different random states.
#    - Metrics were averaged across splits to account for variability in data partitioning.
# 2. **Model Stochasticity**:
#    - Models like Random Forest and XGBoost were trained multiple times with different random seeds, and their metrics were averaged.
#
# ---
#
# ### **Results**
#
# #### **Baseline**
# The baseline MSE was computed using the mean of the target variable as a constant prediction:
# \
# $\text{Baseline MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \bar{y})^2$
# \
# This provides a point of comparison for the model performances.
#
# #### **Model Performance**
# The table below summarizes the average performance across three random splits for each model:
#
# | Model             | Best Hyperparameters                        | Mean Train MSE | Mean Validation MSE | Mean Test MSE | Notes              |
# |--------------------|---------------------------------------------|----------------|----------------------|---------------|--------------------|
# | LinearRegression  | Default                                      | 0.0114         |5.1556e+19)   | 3.0287e+20  | Unstable          |
# | Ridge             | `{'alpha': 0.01}`                           | 0.0114         | 0.0121               | 0.0122         | Best performer     |
# | Lasso             | `{'alpha': 0.01}`                           | 0.0364         | 0.0367               | 0.0370         | Underperformed     |
# | RandomForest      | `{'max_depth': 30, 'max_features': 0.5}`    | 0.0096         | 0.0141               | 0.0142         | Overfitting risk   |
# | XGBoost           | `{'learning_rate': 0.03, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}` | 0.0095         | 0.0123               | 0.0124         | Strong performer   |
# | SVR               | `{'C': 10, 'gamma': 'auto'}`                | 0.0115         | 0.0126               | 0.0128         | Performs well      |
#
# #### **Observations**
# 1. **LinearRegression** exhibited instability due to extreme values in predictions, likely caused by multicollinearity or insufficient regularization.
# 2. **Ridge** consistently outperformed other models, demonstrating the effectiveness of L2 regularization for this dataset.
# 3. **Lasso** underperformed, suggesting that most features contribute to the target variable and should not be eliminated.
# 4. Non-linear models like **RandomForest** and **XGBoost** performed well but showed signs of overfitting, particularly with deeper trees.
# 5. **SVR** delivered competitive results but required careful tuning of kernel parameters.
#
# ---
#
# ### **Next Steps**
#
# 1. **Feature Importance Analysis**:
#    - Calculate global feature importance using:
#      - **Permutation Importance**: To quantify the impact of each feature on the predictions.
#      - **Feature Importance Scores** from Random Forest and XGBoost.
#    - Implement **SHAP (SHapley Additive exPlanations)** to evaluate local and global feature importance.
#
# 2. **Address LinearRegression Instability**:
#    - Investigate multicollinearity among features and apply techniques like **Variance Inflation Factor (VIF)** analysis.
#    - Standardize the data further or introduce regularization.
#
# 3. **Refine Non-Linear Models**:
#    - Random Forest:
#      - Test lower `max_depth` values to mitigate overfitting.
#    - XGBoost:
#      - Fine-tune regularization parameters (`reg_alpha`, `reg_lambda`) to balance model complexity and generalization.
#
# 4. **Measure Model Uncertainties**:
#    - Use **repeated k-fold cross-validation** (e.g., 5 folds, 3 repetitions) to further evaluate the impact of data splitting.
#    - Train Random Forest and XGBoost multiple times with different seeds to analyze stochastic variations in predictions.
#
# 5. **Visualizations**:
#    - Plot model performances across splits using box plots to visualize variability.
#    - Create SHAP summary plots to explain individual model predictions.
#
# 6. **Comparison Against Baseline**:
#    - Clearly quantify the improvements of each model over the baseline MSE.
#    - Highlight models that perform significantly better than the baseline in terms of standard deviations.
#
# ---
#
# This structure captures the current state of your work, highlights key findings, and lays out actionable next steps for refinement and interpretation. Let me know if you need help implementing any specific part!

# %%
baseline_prediction = np.mean(y)
baseline_mse = np.mean((y - baseline_prediction) ** 2)

baseline_prediction, baseline_mse
# Out:
# (0.5478953304759756, 0.06087947893074836)

# %%
# Plot the results
model_names = list(test_scores.keys())
means = [test_score_means[name] for name in model_names]
stds = [test_score_stds[name] for name in model_names]

plt.figure(figsize=(8, 5))
plt.errorbar(model_names, means, yerr=stds, fmt='o', capsize=5)
plt.axhline(y=baseline_mse, color='r', linestyle='--', label="Baseline")

plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("Accuracy")
plt.show()

# %%
filtered_model_names = [name for name in model_names if name != "LinearRegression"]
filtered_means = [test_score_means[name] for name in filtered_model_names]
filtered_stds = [test_score_stds[name] for name in filtered_model_names]

# Plot the results
plt.figure(figsize=(8, 5))
plt.errorbar(filtered_model_names, filtered_means, yerr=filtered_stds, fmt='o', capsize=5)
plt.axhline(y=baseline_mse, color='r', linestyle='--', label="Baseline")

plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("Accuracy")
plt.show()

# %%
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Ridge

def ML_pipeline_kfold_ridge(X, y, random_state, n_folds):
    # Create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

    # Splitter for cross-validation
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)

    # Pipeline with Ridge regression
    pipe = make_pipeline(preprocessor, Ridge())

    # Parameter grid
    param_grid = {
        'ridge__alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2],  # Regularization strength
    }

    # Prepare GridSearchCV
    grid = GridSearchCV(pipe, param_grid=param_grid, cv=kf, return_train_score=True, n_jobs=-1, verbose=True)

    # Perform k-fold CV on X_other
    grid.fit(X_other, y_other)

    # Return the grid search results and test set
    return grid, X_test, y_test

# %%
model, X_test, y_test = ML_pipeline_kfold_ridge(X,y,42,4)

# Calculate MSE for the test set
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print("Best cross-validation score (R^2):", model.best_score_)  # Negative MSE from GridSearchCV
print("Test set MSE:", test_mse)
print("Best parameters:", model.best_params_)

# Save the model and test MSE
file = open('data/results/grid_ridge.save', 'wb')
pickle.dump((model, X_test, y_test), file)
file.close()
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# Best cross-validation score (R^2): 0.795929251786275
# Test set MSE: 0.012235541471097863
# Best parameters: {'ridge__alpha': 0.1}

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
import pickle

# Load the saved model and data
file = open('data/results/grid_ridge.save', 'rb')
model, X_test, y_test = pickle.load(file)
file.close()

np.random.seed(42)

ftr_names = X_test.columns

nr_runs = 10
scores = np.zeros([len(ftr_names), nr_runs])

# Baseline prediction using the mean of the target
baseline_prediction = np.mean(y_test)  # Use the test set mean
baseline_mse = np.mean((y_test - baseline_prediction) ** 2)

# Calculate the test set MSE
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print('Test MSE =', test_mse)
print('Baseline MSE =', baseline_mse)

# Loop through the features for permutation importance using MSE
for i in range(len(ftr_names)):
    print('Shuffling feature:', str(ftr_names[i]))
    acc_scores = []
    for j in range(nr_runs):
        X_test_shuffled = X_test.copy()
        # Shuffle the selected feature
        X_test_shuffled[ftr_names[i]] = np.random.permutation(X_test[ftr_names[i]].values)
        # Predict and calculate MSE with the shuffled feature
        y_test_shuffled_pred = model.predict(X_test_shuffled)
        shuffled_mse = mean_squared_error(y_test, y_test_shuffled_pred)
        acc_scores.append(shuffled_mse)
    # Calculate mean and std deviation of shuffled MSEs
    print('   Shuffled test MSE:', np.around(np.mean(acc_scores), 3), '+/-', np.around(np.std(acc_scores), 3))
    scores[i] = acc_scores
# Out:
# Test MSE = 0.012235541471097863
# Baseline MSE = 0.062076909717903785
# Shuffling feature: Breed
#    Shuffled test MSE: 0.083 +/- 0.002
# Shuffling feature: Age
#    Shuffled test MSE: 0.012 +/- 0.0
# Shuffling feature: Gender
#    Shuffled test MSE: 0.012 +/- 0.0
# Shuffling feature: SpayNeuter
#    Shuffled test MSE: 0.012 +/- 0.0
# Shuffling feature: Borough
#    Shuffled test MSE: 0.012 +/- 0.0
# Shuffling feature: Season
#    Shuffled test MSE: 0.012 +/- 0.0
# Shuffling feature: group
#    Shuffled test MSE: 0.024 +/- 0.0
# Shuffling feature: Age_Range
#    Shuffled test MSE: 0.012 +/- 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sort the features by the mean of the shuffled MSE scores (descending order)
sorted_indcs = np.argsort(np.mean(scores, axis=1))[::-1]

# Plot settings
plt.rcParams.update({'font.size': 11})
plt.figure(figsize=(8, len(ftr_names) * 0.4))  # Adjust height dynamically for readability
plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# Add a vertical line for the test set MSE
plt.axvline(test_mse, color='blue', linestyle='--', label='Test MSE')

# Add labels and title
plt.title("Permutation Importances (test set, MSE)")
plt.xlabel('MSE with perturbed feature')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pw/j1b5757d4hg8vhmyx5h9rmjh0000gn/T/ipykernel_6766/3804670318.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# %%
# Access the trained Ridge model within the pipeline
ridge_model = model.best_estimator_.named_steps['ridge']

# Get the one-hot encoded feature names from the preprocessor
feature_names = preprocessor.named_transformers_['cat'].named_steps['onehot'].get_feature_names_out()

# Combine feature names for categorical and ordinal features
all_feature_names = list(feature_names) + ordinal_ftrs  # 'ordinal_ftrs' refers to ordinal features you used

# Extract Ridge coefficients
ridge_coefficients = ridge_model.coef_

# Print feature names and their corresponding coefficients
print("Feature Coefficients:")
for name, coef in zip(all_feature_names, ridge_coefficients):
    print(f"{name}: {coef}")
# Out:
# Feature Coefficients:
# x0_afghan hound: -0.31161526796195266
# x0_airedale terrier: 0.4130835122017699
# x0_akita: 0.350035988607689
# x0_alaskan malamute: -0.15742103098589796
# x0_american bulldog: -0.10795348801244951
# x0_american english coonhound: 0.1373994630992211
# x0_american eskimo dog: 0.3860534036496116
# x0_american staffordshire terrier: 0.25916788853507416
# x0_american water spaniel: 0.07834297668620188
# x0_anatolian shepherd dog: 0.17193290019814972
# x0_australian cattle dog: -0.2236804876028365
# x0_australian kelpie: -0.5026860377352462
# x0_australian shepherd: 0.19543794680065565
# x0_australian stumpy tail cattle dog: 0.2560174204355541
# x0_australian terrier: 0.08656082932826425
# x0_barbet: -0.07990157422304094
# x0_basenji: -0.11775979743139398
# x0_basset hound: -0.048424119286544366
# x0_bavarian mountain scent hound: -0.07990781540969273
# x0_beagle: -0.06460774845708517
# x0_beauceron: 0.11750681993778381
# x0_belgian malinois: -0.28312446643746186
# x0_belgian sheepdog: 0.17120240990426064
# x0_bernese mountain dog: 0.09929820282732313
# x0_bichon frise: 0.09275584674705879
# x0_biewer terrier: 0.20455802932462874
# x0_black and tan coonhound: 0.11333855677021092
# x0_black russian terrier: 0.0301072527392031
# x0_bloodhound: 0.12280618060307351
# x0_boerboel: -0.13052499769497392
# x0_border collie: 0.22272319226220066
# x0_border terrier: 0.04067020972441933
# x0_borzoi: -0.1028084837907323
# x0_boston terrier: -0.0011275936410816197
# x0_bouvier des flandres: 0.24587932738919488
# x0_boxer: 0.20475884406791203
# x0_boykin spaniel: -0.07176420899981656
# x0_brittany: 0.37692313241116543
# x0_brussels griffon: -0.07061548725241656
# x0_bull terrier: 0.18953101182749565
# x0_bulldog: 0.03388355738337938
# x0_bullmastiff: 0.1577784843082052
# x0_cairn terrier: 0.0066876440291487845
# x0_cane corso: -0.13345215927316273
# x0_cardigan welsh corgi: 0.04198332173357053
# x0_carolina dog: 0.021447974989838157
# x0_catahoula leopard dog: 0.050277003723570975
# x0_cavalier king charles spaniel: -0.43306385148928994
# x0_central asian shepherd dog: -0.016200598072857484
# x0_cesky terrier: -0.11381362045381746
# x0_chesapeake bay retriever: 0.23295984576655004
# x0_chihuahua: -0.2251419748002215
# x0_chinese crested: 0.3568047664573749
# x0_chinese shar-pei: -0.3000198053730917
# x0_chow chow: -0.08513497218551813
# x0_clumber spaniel: -0.2380868353258633
# x0_cocker spaniel: -0.18976764097417542
# x0_collie: -0.09328092435181894
# x0_coton de tulear: -0.3981168951157621
# x0_dachshund: -0.3847033865648093
# x0_dalmatian: -0.21162085754771914
# x0_dandie dinmont terrier: 0.13548993265577203
# x0_doberman pinscher: 0.10948441357307721
# x0_dogue de bordeaux: 0.2912341329945125
# x0_dutch shepherd: -0.4413757008192916
# x0_english cocker spaniel: 0.1364994561581988
# x0_english setter: 0.10838680949252877
# x0_english springer spaniel: 0.00729040308008091
# x0_english toy spaniel: 0.3436775159380776
# x0_finnish spitz: -0.06014487078332771
# x0_french bulldog: -0.05187140460604021
# x0_german longhaired pointer: 0.16664607244461338
# x0_german pinscher: 0.09693498072596617
# x0_german shepherd dog: 0.1560304237643017
# x0_german shorthaired pointer: -0.23445737477863435
# x0_german spitz: -0.006609068825564967
# x0_german wirehaired pointer: 0.04756559416613568
# x0_giant schnauzer: 0.23310973485654585
# x0_glen of imaal terrier: 0.028148129271105125
# x0_golden retriever: 0.26107979719964347
# x0_grand basset griffon vendéen: 0.12296812796842882
# x0_great dane: 0.22930847963738893
# x0_great pyrenees: 0.1735508631603539
# x0_greyhound: 0.18761250186636308
# x0_havanese: -0.2749589655274425
# x0_irish red and white setter: 0.13333079925566618
# x0_irish terrier: -0.0125726576734977
# x0_irish wolfhound: -0.015125539286593711
# x0_italian greyhound: -0.11762641526444176
# x0_japanese chin: -0.08606054400121073
# x0_jindo: 0.16980734937219996
# x0_kai ken: 0.1974053709164213
# x0_kerry blue terrier: -0.0026480831538147572
# x0_labrador retriever: -0.09167558178485334
# x0_lhasa apso: -0.052051271188286403
# x0_löwchen: -0.05382864909786625
# x0_maltese: -0.13936351156089835
# x0_mastiff: 0.23410795389277275
# x0_miniature american shepherd: -0.3346604150432583
# x0_miniature bull terrier: -0.3444962493406789
# x0_miniature pinscher: -0.3768921542878205
# x0_miniature schnauzer: 0.14249989267024057
# x0_neapolitan mastiff: -0.06658421998789493
# x0_newfoundland: -0.183557866824395
# x0_norfolk terrier: -0.12854072537519584
# x0_nova scotia duck tolling retriever: 0.00030280971274587607
# x0_old english sheepdog: -0.013827468896336388
# x0_papillon: 0.1636503067520793
# x0_parson russell terrier: -0.13580399084620307
# x0_pekingese: -0.18764861749178025
# x0_pembroke welsh corgi: 0.41319282005847613
# x0_pharaoh hound: -0.40880804948796867
# x0_plott hound: 0.16757029897904943
# x0_pointer: 0.05339249218831868
# x0_pomeranian: 0.008278850709600936
# x0_poodle (standard): 0.06482111604343828
# x0_poodle (toy): -0.3162504725160758
# x0_portuguese podengo pequeno: 0.2918689488341438
# x0_portuguese water dog: 0.06233646293927366
# x0_pug: -0.3760989750129289
# x0_puli: -0.13088602655433268
# x0_rat terrier: 0.07103245994427933
# x0_rhodesian ridgeback: 0.059056504169476554
# x0_rottweiler: -0.040539721042803845
# x0_saint bernard: -0.1863838695686277
# x0_saluki: 0.020317674584452695
# x0_samoyed: 0.38566240286311393
# x0_scottish terrier: 0.3641670176140519
# x0_shetland sheepdog: 0.21680922536662406
# x0_shiba inu: 0.00829879226546829
# x0_shih tzu: -0.21114384149207205
# x0_siberian husky: 0.2693270774848973
# x0_silky terrier: -0.03718140032186462
# x0_small munsterlander pointer: 0.010907796347511845
# x0_soft coated wheaten terrier: 0.028547369444343034
# x0_staffordshire bull terrier: 0.01711946510574428
# x0_standard schnauzer: 0.00255989087586106
# x0_tibetan mastiff: -0.05618059286578418
# x0_tibetan spaniel: -0.17711768562354394
# x0_tibetan terrier: -0.3042151352499723
# x0_toy fox terrier: -0.10152332284039474
# x0_treeing walker coonhound: 0.23333893867443872
# x0_vizsla: -0.15787808916856516
# x0_weimaraner: 0.010847478952120496
# x0_welsh springer spaniel: -0.21007126744057394
# x0_west highland white terrier: -0.022057988453570977
# x0_wire fox terrier: -0.012901571076251611
# x0_yorkshire terrier: -0.16111164848544396
# x1_F: 0.28197720634845874
# x1_M: -0.13064630384290163
# x1_U: -0.3156235406550952
# x2_Bronx: -0.18136043910135774
# x2_Brooklyn: -0.2022519041406223
# x2_Manhattan: -0.042838123516498405
# x2_Other: -0.13149881992851906
# x2_Queens: 0.3844924841498809
# x2_Staten Island: 0.04474852979541599
# x3_Fall: 0.15258557672178052
# x3_Spring: 0.11284194488847905
# x3_Summer: 0.06536812977381126
# x3_Winter: 0.08591779825888732
# x4_Foundation Stock Service: -0.011748042827711405
# x4_Herding Group: 0.04804481405915298
# x4_Hound Group: -0.37582821572494174
# x4_Miscellaneous Class: -0.38861284363538806
# x4_Non-Sporting Group: -0.0009442449259572773
# x4_Sporting Group: 0.0027197221670389525
# x4_Terrier Group: -0.0017754772331724008
# x4_Toy Group: 0.0002589064786540055
# x4_Working Group: -0.002923282869809777
# x5_False: -0.0014337800539456775
# x5_True: 0.0035080636024525736
# Age_Range: -0.0008210492660249804

# %%
# Example: Sum absolute coefficients for 'breed' features
breed_coeff_indices = [i for i, name in enumerate(all_feature_names) if 'x0_' in name]  # Adjust prefix as needed
breed_importance = np.sum(np.abs(ridge_model.coef_[breed_coeff_indices]))
print("Total importance of 'breed':", breed_importance)
# Out:
# Total importance of 'breed': 23.602546009536496

# %%
def ML_pipeline_kfold_XGB(X, y, random_state, n_folds):
    # Create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

    # Splitter for cross-validation
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)

    # Pipeline with Ridge regression
    pipe = make_pipeline(preprocessor, XGBRegressor())

    # Parameter grid
    param_grid = {
        'xgbregressor__learning_rate': [0.03],
        'xgbregressor__n_estimators': [300, 500],
        'xgbregressor__max_depth': [1,3,10,30,100],
        'xgbregressor__reg_alpha': [0e0, 1e-2, 1e-1, 1e0, 1e1],
        'xgbregressor__reg_lambda': [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2],
    }

    # Prepare GridSearchCV
    grid = GridSearchCV(pipe, param_grid=param_grid, cv=kf, return_train_score=True, n_jobs=-1, verbose=True)

    # Perform k-fold CV on X_other
    grid.fit(X_other, y_other)

    # Return the grid search results and test set
    return grid, X_test, y_test

# %%
model, X_test, y_test = ML_pipeline_kfold_XGB(X,y,42,4)

# Calculate MSE for the test set
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print("Best cross-validation score (R^2):", model.best_score_)  # Negative MSE from GridSearchCV
print("Test set MSE:", test_mse)
print("Best parameters:", model.best_params_)

# Save the model and test MSE
file = open('data/results/grid_XGB.save', 'wb')
pickle.dump((model, X_test, y_test), file)
file.close()
# Out:
# Fitting 4 folds for each of 300 candidates, totalling 1200 fits
# Best cross-validation score (R^2): 0.7876047524357207
# Test set MSE: 0.01270318664685425
# Best parameters: {'xgbregressor__learning_rate': 0.03, 'xgbregressor__max_depth': 10, 'xgbregressor__n_estimators': 500, 'xgbregressor__reg_alpha': 0.1, 'xgbregressor__reg_lambda': 1.0}

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
import pickle

# Load the saved model and data
file = open('data/results/grid_XGB.save', 'rb')
model, X_test, y_test = pickle.load(file)
file.close()

np.random.seed(42)

ftr_names = X_test.columns

nr_runs = 10
scores = np.zeros([len(ftr_names), nr_runs])

# Baseline prediction using the mean of the target
baseline_prediction = np.mean(y_test)  # Use the test set mean
baseline_mse = np.mean((y_test - baseline_prediction) ** 2)

# Calculate the test set MSE
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print('Test MSE =', test_mse)
print('Baseline MSE =', baseline_mse)

# Loop through the features for permutation importance using MSE
for i in range(len(ftr_names)):
    print('Shuffling feature:', str(ftr_names[i]))
    acc_scores = []
    for j in range(nr_runs):
        X_test_shuffled = X_test.copy()
        # Shuffle the selected feature
        X_test_shuffled[ftr_names[i]] = np.random.permutation(X_test[ftr_names[i]].values)
        # Predict and calculate MSE with the shuffled feature
        y_test_shuffled_pred = model.predict(X_test_shuffled)
        shuffled_mse = mean_squared_error(y_test, y_test_shuffled_pred)
        acc_scores.append(shuffled_mse)
    # Calculate mean and std deviation of shuffled MSEs
    print('   Shuffled test MSE:', np.around(np.mean(acc_scores), 3), '+/-', np.around(np.std(acc_scores), 3))
    scores[i] = acc_scores
# Out:
# Test MSE = 0.01270318664685425
# Baseline MSE = 0.062076909717903785
# Shuffling feature: Breed
#    Shuffled test MSE: 0.079 +/- 0.002
# Shuffling feature: Age
#    Shuffled test MSE: 0.013 +/- 0.0
# Shuffling feature: Gender
#    Shuffled test MSE: 0.013 +/- 0.0
# Shuffling feature: SpayNeuter
#    Shuffled test MSE: 0.013 +/- 0.0
# Shuffling feature: Borough
#    Shuffled test MSE: 0.013 +/- 0.0
# Shuffling feature: Season
#    Shuffled test MSE: 0.013 +/- 0.0
# Shuffling feature: group
#    Shuffled test MSE: 0.029 +/- 0.0
# Shuffling feature: Age_Range
#    Shuffled test MSE: 0.013 +/- 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sort the features by the mean of the shuffled MSE scores (descending order)
sorted_indcs = np.argsort(np.mean(scores, axis=1))[::-1]

# Plot settings
plt.rcParams.update({'font.size': 11})
plt.figure(figsize=(8, len(ftr_names) * 0.4))  # Adjust height dynamically for readability
plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# Add a vertical line for the test set MSE
plt.axvline(test_mse, color='blue', linestyle='--', label='Test MSE')

# Add labels and title
plt.title("Permutation Importances (test set, MSE)")
plt.xlabel('MSE with perturbed feature')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pw/j1b5757d4hg8vhmyx5h9rmjh0000gn/T/ipykernel_6766/3916736048.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# %%
def ML_pipeline_kfold_SVR(X, y, random_state, n_folds):
    # Create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

    # Splitter for cross-validation
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)

    # Pipeline with Ridge regression
    pipe = make_pipeline(preprocessor, SVR())

    # Parameter grid
    param_grid = {
        'SVR__C': [1e1, 1e2, 1e3],
        'SVR__gamma': [1e-3, 1e-2, 1, 1e1],
    }

    # Prepare GridSearchCV
    grid = GridSearchCV(pipe, param_grid=param_grid, cv=kf, return_train_score=True, n_jobs=-1, verbose=True)

    # Perform k-fold CV on X_other
    grid.fit(X_other, y_other)

    # Return the grid search results and test set
    return grid, X_test, y_test
