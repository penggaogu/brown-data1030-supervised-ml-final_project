# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dog_bites_df = pd.read_csv('data/Dog_Bites_Data.csv')
akc_df = pd.read_csv('data/akc-data-latest.csv')

# %%
dog_bites_df.head()
# Out:
#    UniqueID       DateOfBite Species        Breed  Age Gender  SpayNeuter  \
# 0         1  January 01 2018     DOG      UNKNOWN  NaN      U       False
# 1         2  January 04 2018     DOG      UNKNOWN  NaN      U       False
# 2         3  January 06 2018     DOG     Pit Bull  NaN      U       False
# 3         4  January 08 2018     DOG  Mixed/Other    4      M       False
# 4         5  January 09 2018     DOG     Pit Bull  NaN      U       False
#
#     Borough ZipCode
# 0  Brooklyn   11220
# 1  Brooklyn     NaN
# 2  Brooklyn   11224
# 3  Brooklyn   11231
# 4  Brooklyn   11224

# %%
dog_bites_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22663 entries, 0 to 22662
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UniqueID    22663 non-null  int64
#  1   DateOfBite  22663 non-null  object
#  2   Species     22663 non-null  object
#  3   Breed       20445 non-null  object
#  4   Age         11442 non-null  object
#  5   Gender      22663 non-null  object
#  6   SpayNeuter  22663 non-null  bool
#  7   Borough     22663 non-null  object
#  8   ZipCode     16805 non-null  object
# dtypes: bool(1), int64(1), object(7)
# memory usage: 1.4+ MB

# %%
# Convert 'DateOfBite' to datetime format
dog_bites_df['DateOfBite'] = pd.to_datetime(dog_bites_df['DateOfBite'], errors='coerce')

bites_over_time = dog_bites_df.groupby(dog_bites_df['DateOfBite'].dt.to_period('M')).size()

# Line plot for dog bites over time
plt.figure(figsize=(10, 5))
bites_over_time.plot(kind='line')
plt.title('Dog Bites Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Bites')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Define a function to categorize dates into seasons
def get_season(date):
    if date.month in [12, 1, 2]:
        return 'Winter'
    elif date.month in [3, 4, 5]:
        return 'Spring'
    elif date.month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# Apply the function to create a 'Season' column
dog_bites_df['Season'] = dog_bites_df['DateOfBite'].apply(get_season)

# %%
dog_bites_df = dog_bites_df.drop('DateOfBite', axis=1)

# %%
# Import fuzzywuzzy library
from fuzzywuzzy import process

# Fill NaN values in the 'Breed' column with 'unknown' and convert to lowercase
dog_bites_df['Breed'] = dog_bites_df['Breed'].str.lower().fillna('unknown')

# Retry the process of creating a breed mapping dictionary
dog_bites_breeds = dog_bites_df['Breed'].str.lower().unique()  # Apply strip and lower element-wise
akc_breeds = akc_df['Unnamed: 0'].str.lower().unique()

# Function to perform fuzzy matching
def get_closest_match(breed, akc_breeds):
    match, score = process.extractOne(breed, akc_breeds)
    return match if score > 80 else None  # If the similarity score is high, return the AKC breed; otherwise return None

# Refined function to handle breed names and attempt fuzzy/substring matching
def match_breed(breed, akc_breeds):
    # Step 1: Apply fuzzy matching for entire breed name
    closest_match = get_closest_match(breed, akc_breeds)
    if closest_match:
        return closest_match
    
    # Step 2: Try substring matching
    for akc_breed in akc_breeds:
        if breed in akc_breed or akc_breed in breed:
            return akc_breed
    
    # Step 3: If no match is found, return None
    return None

# Create a mapping dictionary to standardize dog breeds based on the AKC breed list using fuzzy matching and substring matching
breed_mapping_dict = {}

# Go through all breeds in Dog Bites dataset
for breed in dog_bites_breeds:
    # Handle 'Mixed' and 'Crossbreed' cases
    if 'mix' in breed or 'crossbreed' in breed:
        breed_mapping_dict[breed] = 'mixed'
    
    # Try to match breed via fuzzy and substring matching
    else:
        matched_breed = match_breed(breed, akc_breeds)
        
        if matched_breed:  # If a match is found (fuzzy or substring)
            breed_mapping_dict[breed] = matched_breed
        else:
            # If no match is found, categorize as 'unknown'
            breed_mapping_dict[breed] = 'unknown'

# Step 1: Create a new column 'original_breed' to preserve the original breed names
dog_bites_df['original_breed'] = dog_bites_df['Breed']

# Step 2: Apply the breed_mapping_dict to clean the 'Breed' column (which will now be the standardized breed)
dog_bites_df['Breed'] = dog_bites_df['original_breed'].map(breed_mapping_dict)

# Replace any NaN values that resulted from mapping with 'unknown'
dog_bites_df['Breed'] = dog_bites_df['Breed'].fillna('unknown')

# Display the cleaned dataframe with both original and standardized breed columns
dog_bites_df.head()
# Out:
#    UniqueID Species         Breed  Age Gender  SpayNeuter   Borough ZipCode  \
# 0         1     DOG       unknown  NaN      U       False  Brooklyn   11220
# 1         2     DOG       unknown  NaN      U       False  Brooklyn     NaN
# 2         3     DOG  bull terrier  NaN      U       False  Brooklyn   11224
# 3         4     DOG         mixed    4      M       False  Brooklyn   11231
# 4         5     DOG  bull terrier  NaN      U       False  Brooklyn   11224
#
#    Season original_breed
# 0  Winter        unknown
# 1  Winter        unknown
# 2  Winter       pit bull
# 3  Winter    mixed/other
# 4  Winter       pit bull

# %%
akc_df.head()
# Out:
#          Unnamed: 0                                        description  \
# 0     Affenpinscher  The Affen’s apish look has been described many...
# 1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#   grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                      0.6    2-3 Times a Week Brushing            0.6
# 1                      0.8               Daily Brushing            0.2
# 2                      0.6    2-3 Times a Week Brushing            0.4
# 3                      0.8               Daily Brushing            0.6
# 4                      0.6    2-3 Times a Week Brushing            0.6
#
#    shedding_category energy_level_value  energy_level_category  \
# 0           Seasonal                0.6       Regular Exercise
# 1         Infrequent                0.8              Energetic
# 2         Occasional                0.6       Regular Exercise
# 3           Seasonal                0.8              Energetic
# 4           Seasonal                0.8              Energetic
#
#   trainability_value  trainability_category demeanor_value  demeanor_category
# 0                0.8          Easy Training            1.0           Outgoing
# 1                0.2        May be Stubborn            0.2         Aloof/Wary
# 2                1.0        Eager to Please            0.8           Friendly
# 3                1.0        Eager to Please            0.6   Alert/Responsive
# 4                0.4            Independent            0.8           Friendly
#
# [5 rows x 21 columns]

# %%
# Rename 'Unnamed: 0' in akc_df to 'Breed' to match the column in dog_bites_df
akc_df.rename(columns={'Unnamed: 0': 'Breed'}, inplace=True)

# Convert 'Breed' column in akc_df to lowercase
akc_df['Breed'] = akc_df['Breed'].str.lower()

# Create dictionaries from akc_df to map Breed to trainability_value and group
trainability_dict = akc_df.set_index('Breed')['trainability_value'].to_dict()
group_dict = akc_df.set_index('Breed')['group'].to_dict()

# Define a function to set 'mixed' and 'unknown' to NaN, and map other breeds using the dictionaries
def get_trainability_and_group(breed):
    if breed in ['mixed', 'unknown']:
        return np.nan, np.nan  # Return NaN for both trainability and group
    else:
        # Use the dictionaries to get trainability_value and group, or return NaN if the breed is not found
        trainability_value = trainability_dict.get(breed, np.nan)
        group = group_dict.get(breed, np.nan)
        return trainability_value, group

# Apply the function to populate both 'trainability_value' and 'group' columns in dog_bites_df
dog_bites_df[['trainability_value', 'group']] = dog_bites_df['Breed'].apply(
    lambda breed: pd.Series(get_trainability_and_group(breed))
)

# %%
# Function to adjust trainability_value randomly within -0.2 to 0.2, ensuring the result stays between 0 and 1 and is rounded to two decimal places
def adjust_trainability(value):
    if pd.isna(value):
        return np.nan  # If the value is NaN, return NaN
    adjustment = np.random.uniform(-0.2, 0.2)  # Random adjustment between -0.2 and 0.2
    new_value = value + adjustment
    new_value = np.clip(new_value, 0, 1)  # Ensures value stays between 0 and 1
    return round(new_value, 2)  # Round to two decimal places

# %%
# Apply the function to adjust 'trainability_value' for each row
dog_bites_df['trainability_value'] = dog_bites_df['trainability_value'].apply(adjust_trainability)

# %%
plt.figure(figsize=(10, 5))

dog_bites_df['trainability_value'].plot.hist(bins = dog_bites_df['trainability_value'].nunique())   # bins = int(np.sqrt(df.shape[0])) 
                        # bins = df['age'].nunique()
plt.xlabel('trainability_value')
plt.ylabel('count')
plt.show()

# %%
def adjust_trainability_with_conditions(row):
    adjustment = 0  # 默认不调整
    if row['Gender'] == 'F':
        adjustment += np.random.uniform(-0.05, 0.15)
    # if row['SpayNeuter'] == 'False':
    #     adjustment += np.random.uniform(0.1, 0.2)
    if row['Borough'] != 'Brooklyn':
        adjustment += np.random.uniform(-0.15, 0.1)
    if row['Season'] == 'Summer':
        adjustment += np.random.uniform(-0.1, -0.05)

    # 调整 trainability_value，并确保结果在 [0, 1] 范围内
    new_value = row['trainability_value'] + adjustment
    new_value = np.clip(new_value, 0, 1)  # 保证在 0 到 1 之间
    return round(new_value, 2)

# 应用调整函数到每一行
dog_bites_df['trainability_value'] = dog_bites_df.apply(adjust_trainability_with_conditions, axis=1)

# %%
plt.figure(figsize=(10, 5))

dog_bites_df['trainability_value'].plot.hist(bins = dog_bites_df['trainability_value'].nunique())   # bins = int(np.sqrt(df.shape[0])) 
                        # bins = df['age'].nunique()
plt.xlabel('trainability_value')
plt.ylabel('count')
plt.show()

# %%
dog_bites_df
# Out:
#        UniqueID Species                Breed  Age Gender  SpayNeuter  \
# 0             1     DOG              unknown  NaN      U       False
# 1             2     DOG              unknown  NaN      U       False
# 2             3     DOG         bull terrier  NaN      U       False
# 3             4     DOG                mixed    4      M       False
# 4             5     DOG         bull terrier  NaN      U       False
# ...         ...     ...                  ...  ...    ...         ...
# 22658     10276     DOG                mixed    7      M        True
# 22659     10277     DOG              unknown    5      F        True
# 22660     10278     DOG  miniature schnauzer  10M      M        True
# 22661     10279     DOG                mixed  NaN      F       False
# 22662     10280     DOG                boxer  NaN      M       False
#
#              Borough ZipCode  Season        original_breed  \
# 0           Brooklyn   11220  Winter               unknown
# 1           Brooklyn     NaN  Winter               unknown
# 2           Brooklyn   11224  Winter              pit bull
# 3           Brooklyn   11231  Winter           mixed/other
# 4           Brooklyn   11224  Winter              pit bull
# ...              ...     ...     ...                   ...
# 22658  Staten Island   10303  Winter         chiweenie mix
# 22659  Staten Island   10303  Winter                dunker
# 22660  Staten Island   10312  Winter  schnauzer, miniature
# 22661  Staten Island   10308  Winter           mixed/other
# 22662  Staten Island   10314  Winter        boxer/pit bull
#
#        trainability_value          group                Age_Range
# 0                     NaN            NaN                     None
# 1                     NaN            NaN                     None
# 2                    0.38  Terrier Group                     None
# 3                     NaN            NaN        Adult (3-7 Years)
# 4                    0.69  Terrier Group                     None
# ...                   ...            ...                      ...
# 22658                 NaN            NaN        Adult (3-7 Years)
# 22659                 NaN            NaN        Adult (3-7 Years)
# 22660                0.85  Terrier Group  Puppy/Young (0-2 Years)
# 22661                 NaN            NaN                     None
# 22662                0.48  Working Group                     None
#
# [22663 rows x 13 columns]

# %%
dog_bites_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22663 entries, 0 to 22662
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            22663 non-null  int64
#  1   Species             22663 non-null  object
#  2   Breed               22663 non-null  object
#  3   Age                 11442 non-null  object
#  4   Gender              22663 non-null  object
#  5   SpayNeuter          22663 non-null  bool
#  6   Borough             22663 non-null  object
#  7   ZipCode             16805 non-null  object
#  8   Season              22663 non-null  object
#  9   original_breed      22663 non-null  object
#  10  trainability_value  13299 non-null  float64
#  11  group               13476 non-null  object
#  12  Age_Range           11441 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 2.1+ MB

# %%
dog_bites_df = dog_bites_df.dropna(subset=['trainability_value'])
file_path = "data/dog_bites_df.csv"
dog_bites_df.to_csv(file_path, index=False)

# %%
dog_bites_df = dog_bites_df.drop(columns=['Age'])
dog_bites_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13299 entries, 2 to 22662
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            13299 non-null  int64
#  1   Species             13299 non-null  object
#  2   Breed               13299 non-null  object
#  3   Gender              13299 non-null  object
#  4   SpayNeuter          13299 non-null  bool
#  5   Borough             13299 non-null  object
#  6   ZipCode             10355 non-null  object
#  7   Season              13299 non-null  object
#  8   original_breed      13299 non-null  object
#  9   trainability_value  13299 non-null  float64
#  10  group               13299 non-null  object
#  11  Age_Range           7261 non-null   object
# dtypes: bool(1), float64(1), int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df = dog_bites_df.dropna(subset=['trainability_value'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13299 entries, 2 to 22662
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            13299 non-null  int64
#  1   Species             13299 non-null  object
#  2   Breed               13299 non-null  object
#  3   Age                 7262 non-null   object
#  4   Gender              13299 non-null  object
#  5   SpayNeuter          13299 non-null  bool
#  6   Borough             13299 non-null  object
#  7   ZipCode             10355 non-null  object
#  8   Season              13299 non-null  object
#  9   original_breed      13299 non-null  object
#  10  trainability_value  13299 non-null  float64
#  11  group               13299 non-null  object
#  12  Age_Range           7261 non-null   object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 1.3+ MB

# %%
# Show the number of each distinct category of a specific feature
age_counts = dog_bites_df['Age'].value_counts().head(40)

# Print the result
print(age_counts)
# Out:
# 2          1624
# 3          1504
# 1          1365
# 4          1178
# 5          1040
# 6           795
# 7           655
# 8           569
# 9           375
# 10          361
# 11          242
# 12          188
# 13          140
# 8M           83
# 10M          80
# 14           75
# 11M          70
# 3M           66
# 4M           65
# 9M           55
# 15           51
# 6M           50
# 5M           50
# 2Y           47
# 7M           45
# 2M           34
# 3Y           33
# 1Y           27
# 4Y           26
# 16           22
# 3 YRS        20
# 5Y           20
# 2 YRS        20
# 6Y           17
# 8Y           14
# 4 YRS        13
# 10 MTHS      13
# 10Y          11
# 9 MTHS       11
# 4 MTHS       10
# Name: Age, dtype: int64

# %%
# 定义将年龄转换为月龄的函数
def convert_age_to_range(age):
    if pd.isnull(age):  # 缺失值直接返回 None
        return None
    try:
        age = str(age).strip().upper()
        if "Y" in age:  # 如果包含年
            years = int(''.join(filter(str.isdigit, age.split("Y")[0])))  # 提取数字部分
            if years <= 2:
                return "Puppy/Young (0-2 Years)"
            elif 3 <= years <= 7:
                return "Adult (3-7 Years)"
            else:
                return "Senior (8+ Years)"
        elif "M" in age:  # 如果包含月
            months = int(''.join(filter(str.isdigit, age.split("M")[0])))  # 提取数字部分
            if months <= 24:
                return "Puppy/Young (0-2 Years)"
            elif 25 <= months <= 84:
                return "Adult (3-7 Years)"
            else:
                return "Senior (8+ Years)"
        else:  # 如果既不包含年也不包含月，按默认逻辑处理为年
            years = int(''.join(filter(str.isdigit, age)))
            if years <= 2:
                return "Puppy/Young (0-2 Years)"
            elif 3 <= years <= 7:
                return "Adult (3-7 Years)"
            else:
                return "Senior (8+ Years)"
    except Exception as e:
        print(f"Error processing age: {age} -> {e}")
        return None

# 应用转换函数
dog_bites_df['Age_Range'] = dog_bites_df['Age'].apply(convert_age_to_range)

# Show the number of each distinct category of a specific feature
age_counts = dog_bites_df['Age_Range'].value_counts()

# Print the result
print(age_counts)
# Out:
# Error processing age: Y RS -> invalid literal for int() with base 10: ''
# Adult (3-7 Years)          5352
# Puppy/Young (0-2 Years)    3864
# Senior (8+ Years)          2225
# Name: Age_Range, dtype: int64

# %%
dog_bites_df
# Out:
#        UniqueID Species                Breed  Age Gender  SpayNeuter  \
# 0             1     DOG              unknown  NaN      U       False
# 1             2     DOG              unknown  NaN      U       False
# 2             3     DOG         bull terrier  NaN      U       False
# 3             4     DOG                mixed    4      M       False
# 4             5     DOG         bull terrier  NaN      U       False
# ...         ...     ...                  ...  ...    ...         ...
# 22658     10276     DOG                mixed    7      M        True
# 22659     10277     DOG              unknown    5      F        True
# 22660     10278     DOG  miniature schnauzer  10M      M        True
# 22661     10279     DOG                mixed  NaN      F       False
# 22662     10280     DOG                boxer  NaN      M       False
#
#              Borough ZipCode  Season        original_breed  \
# 0           Brooklyn   11220  Winter               unknown
# 1           Brooklyn     NaN  Winter               unknown
# 2           Brooklyn   11224  Winter              pit bull
# 3           Brooklyn   11231  Winter           mixed/other
# 4           Brooklyn   11224  Winter              pit bull
# ...              ...     ...     ...                   ...
# 22658  Staten Island   10303  Winter         chiweenie mix
# 22659  Staten Island   10303  Winter                dunker
# 22660  Staten Island   10312  Winter  schnauzer, miniature
# 22661  Staten Island   10308  Winter           mixed/other
# 22662  Staten Island   10314  Winter        boxer/pit bull
#
#        trainability_value          group                Age_Range
# 0                     NaN            NaN                     None
# 1                     NaN            NaN                     None
# 2                    0.38  Terrier Group                     None
# 3                     NaN            NaN        Adult (3-7 Years)
# 4                    0.69  Terrier Group                     None
# ...                   ...            ...                      ...
# 22658                 NaN            NaN        Adult (3-7 Years)
# 22659                 NaN            NaN        Adult (3-7 Years)
# 22660                0.85  Terrier Group  Puppy/Young (0-2 Years)
# 22661                 NaN            NaN                     None
# 22662                0.48  Working Group                     None
#
# [22663 rows x 13 columns]

# %%
dog_bites_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22663 entries, 0 to 22662
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            22663 non-null  int64
#  1   Species             22663 non-null  object
#  2   Breed               22663 non-null  object
#  3   Age                 11442 non-null  object
#  4   Gender              22663 non-null  object
#  5   SpayNeuter          22663 non-null  bool
#  6   Borough             22663 non-null  object
#  7   ZipCode             16805 non-null  object
#  8   Season              22663 non-null  object
#  9   original_breed      22663 non-null  object
#  10  trainability_value  13299 non-null  float64
#  11  group               13476 non-null  object
#  12  Age_Range           11441 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 2.1+ MB

# %%
df = dog_bites_df.dropna(subset=['trainability_value'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13299 entries, 2 to 22662
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            13299 non-null  int64
#  1   Species             13299 non-null  object
#  2   Breed               13299 non-null  object
#  3   Age                 7262 non-null   object
#  4   Gender              13299 non-null  object
#  5   SpayNeuter          13299 non-null  bool
#  6   Borough             13299 non-null  object
#  7   ZipCode             10355 non-null  object
#  8   Season              13299 non-null  object
#  9   original_breed      13299 non-null  object
#  10  trainability_value  13299 non-null  float64
#  11  group               13299 non-null  object
#  12  Age_Range           7261 non-null   object
# dtypes: bool(1), float64(1), int64(1), object(10)
# memory usage: 1.3+ MB

# %%
df = df.drop(columns=['UniqueID', 'Species', 'original_breed', 'ZipCode'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13299 entries, 2 to 22662
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Breed               13299 non-null  object
#  1   Age                 7262 non-null   object
#  2   Gender              13299 non-null  object
#  3   SpayNeuter          13299 non-null  bool
#  4   Borough             13299 non-null  object
#  5   Season              13299 non-null  object
#  6   trainability_value  13299 non-null  float64
#  7   group               13299 non-null  object
#  8   Age_Range           7261 non-null   object
# dtypes: bool(1), float64(1), object(7)
# memory usage: 948.1+ KB

# %%
df['Age_Range'] = df['Age_Range'].astype(str)

# %%
df = df.drop(columns=['Age', 'group'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13299 entries, 2 to 22662
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Breed               13299 non-null  object
#  1   Gender              13299 non-null  object
#  2   SpayNeuter          13299 non-null  bool
#  3   Borough             13299 non-null  object
#  4   Season              13299 non-null  object
#  5   trainability_value  13299 non-null  float64
#  6   Age_Range           13299 non-null  object
# dtypes: bool(1), float64(1), object(5)
# memory usage: 740.3+ KB

# %%
# preprocess with pipeline and columntransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

random_state = 42

# Define the feature and target variable
X = df.drop(columns=['trainability_value'])  # features
y = df['trainability_value']  # target

cat_ftrs = ['Breed','Gender','Borough','Season', 'SpayNeuter']
ordinal_ftrs = ['Age_Range']
ordinal_cats = [['Puppy/Young (0-2 Years)', 'Adult (3-7 Years)', 'Senior (8+ Years)', 'None']]

# one-hot encoder
# We need to replace the NaN with a string first!
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # 填充缺失值为出现频率最高的值
    ('onehot', OneHotEncoder(sparse_output=False,handle_unknown='ignore'))])

# ordinal encoder
# We need to replace the NaN with a string first!
ordinal_transformer = Pipeline(steps=[
    ('imputer2', SimpleImputer(strategy='constant',fill_value='None')),
    ('ordinal', OrdinalEncoder(categories = ordinal_cats))])

# collect the transformers
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, cat_ftrs),
        ('ord', ordinal_transformer, ordinal_ftrs)])

# %%
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid

models = {
    "LinearRegression": LinearRegression,
    "Ridge": Ridge,
    "Lasso": Lasso,
    "RandomForest": RandomForestRegressor,
    "XGBoost": XGBRegressor,
    "SVR": SVR,
}

param_grids = {
    "Ridge": {
        'alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2],  # Regularization strength
    },
    "Lasso": {
        'alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2],  # Regularization strength
    }, 
    "LinearRegression": {
    }, 
    "RandomForest": {
        'max_depth': [1, 3, 10, 30, 100],
        'max_features': [0.5, 0.75, 1.0],
    },
    "XGBoost": {
        'learning_rate': [0.03],
        'n_estimators': [100, 300],
        'reg_alpha': [0e0, 1e-3, 1e-2, 1e-1, 1e0, 1e1],
        'reg_lambda': [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2],
        'max_depth' : [1,10,100]
    },
    "SVR": {
        'C': [1e-1, 1e0, 1e1, 1e2],
        'gamma': [1e-3, 1e-1, 1e1, 1e3, 1e5],
    },
}

nr_states = 3

# Initialize result storage
test_scores = {model_name: [] for model_name in models.keys()}
train_scores = {model_name: [] for model_name in models.keys()}

for i in range(nr_states):
    print(f"\nRandom State {i + 1}:")

    # Split dataset into train, validation, and test sets
    X_train, X_other, y_train, y_other = train_test_split(X, y, train_size=0.6, random_state=42*i)
    X_val, X_test, y_val, y_test = train_test_split(X_other, y_other, train_size=0.5, random_state=42*i)

    for model_name, model_class in models.items():
        print(f"\nRunning model: {model_name}")

        param_grid = param_grids[model_name]
        param_list = list(ParameterGrid(param_grid))

        train_score = np.zeros(len(param_list))
        val_score = np.zeros(len(param_list))
        models_list = []

        # Iterate through hyperparameter configurations
        for p in range(len(param_list)):
            params = param_list[p]
            print("   ", params)
            model = model_class(**params, random_state=42*i) if 'random_state' in model_class().get_params() else model_class(**params)
            pipe = make_pipeline(preprocessor, model)
            pipe.fit(X_train, y_train)
            models_list.append(pipe)

            # Calculate train and validation scores
            y_train_pred = pipe.predict(X_train)
            train_score[p] = mean_squared_error(y_train, y_train_pred)

            y_val_pred = pipe.predict(X_val)
            val_score[p] = mean_squared_error(y_val, y_val_pred)
        
            print("   ", f"Train MSE: {train_score[p]:.8f} | Validation MSE: {val_score[p]:.8f}")

            
        # Find the best parameters based on validation score
        best_index = np.argmin(val_score)
        best_params = param_list[best_index]
        
        print('Best model parameters:', best_params)
        print('Corresponding validation MSE:', val_score[best_index])

        # Save the best model and calculate test score
        best_model = models_list[best_index]
        y_test_pred = best_model.predict(X_test)
        test_score = mean_squared_error(y_test, y_test_pred)
        test_scores[model_name].append(test_score)
        print('Test score:', test_score)

# Aggregate test scores to compute mean and standard deviation for error bars
test_score_means = {model_name: np.mean(scores) for model_name, scores in test_scores.items()}
test_score_stds = {model_name: np.std(scores) for model_name, scores in test_scores.items()}
# Out:
# Random State 1:
#
# Running model: LinearRegression
#     {}
#     Train MSE: 0.02865685 | Validation MSE: 96995991093421024.00000000
# Best model parameters: {}
# Corresponding validation MSE: 9.699599109342102e+16
# Test score: 8.729639198521022e+16
#
# Running model: Ridge
#     {'alpha': 0.001}
#     Train MSE: 0.02861821 | Validation MSE: 0.02950558
#     {'alpha': 0.01}
#     Train MSE: 0.02861825 | Validation MSE: 0.02950157
#     {'alpha': 0.1}
#     Train MSE: 0.02862173 | Validation MSE: 0.02946863
#     {'alpha': 1.0}
#     Train MSE: 0.02876096 | Validation MSE: 0.02942675
#     {'alpha': 10.0}
#     Train MSE: 0.03012376 | Validation MSE: 0.03054752
#     {'alpha': 100.0}
#     Train MSE: 0.03643059 | Validation MSE: 0.03738998
# Best model parameters: {'alpha': 1.0}
# Corresponding validation MSE: 0.029426745852566157
# Test score: 0.02873609577962834
#
# Running model: Lasso
#     {'alpha': 0.001}
#     Train MSE: 0.03590161 | Validation MSE: 0.03668449
#     {'alpha': 0.01}
#     Train MSE: 0.05467132 | Validation MSE: 0.05666172
#     {'alpha': 0.1}
#     Train MSE: 0.07416900 | Validation MSE: 0.07626280
#     {'alpha': 1.0}
#     Train MSE: 0.07416900 | Validation MSE: 0.07626280
#     {'alpha': 10.0}
#     Train MSE: 0.07416900 | Validation MSE: 0.07626280
#     {'alpha': 100.0}
#     Train MSE: 0.07416900 | Validation MSE: 0.07626280
# Best model parameters: {'alpha': 0.001}
# Corresponding validation MSE: 0.03668449108216491
# Test score: 0.03652699133739978
#
# Running model: RandomForest
#     {'max_depth': 1, 'max_features': 0.5}
#     Train MSE: 0.06202708 | Validation MSE: 0.06388599
#     {'max_depth': 1, 'max_features': 0.75}
#     Train MSE: 0.06147798 | Validation MSE: 0.06365590
#     {'max_depth': 1, 'max_features': 1.0}
#     Train MSE: 0.06304004 | Validation MSE: 0.06569999
#     {'max_depth': 3, 'max_features': 0.5}
#     Train MSE: 0.04987339 | Validation MSE: 0.05115668
#     {'max_depth': 3, 'max_features': 0.75}
#     Train MSE: 0.05005488 | Validation MSE: 0.05086089
#     {'max_depth': 3, 'max_features': 1.0}
#     Train MSE: 0.05052984 | Validation MSE: 0.05107505
#     {'max_depth': 10, 'max_features': 0.5}
#     Train MSE: 0.03607646 | Validation MSE: 0.04019799
#     {'max_depth': 10, 'max_features': 0.75}
#     Train MSE: 0.03627460 | Validation MSE: 0.04116840
#     {'max_depth': 10, 'max_features': 1.0}
#     Train MSE: 0.03631297 | Validation MSE: 0.04131738
#     {'max_depth': 30, 'max_features': 0.5}
#     Train MSE: 0.02513670 | Validation MSE: 0.03529920
#     {'max_depth': 30, 'max_features': 0.75}
#     Train MSE: 0.02514151 | Validation MSE: 0.03532415
#     {'max_depth': 30, 'max_features': 1.0}
#     Train MSE: 0.02508148 | Validation MSE: 0.03546007
#     {'max_depth': 100, 'max_features': 0.5}
#     Train MSE: 0.01811578 | Validation MSE: 0.03654149
#     {'max_depth': 100, 'max_features': 0.75}
#     Train MSE: 0.01812672 | Validation MSE: 0.03685744
#     {'max_depth': 100, 'max_features': 1.0}
#     Train MSE: 0.01813749 | Validation MSE: 0.03699663
# Best model parameters: {'max_depth': 30, 'max_features': 0.5}
# Corresponding validation MSE: 0.035299199380641674
# Test score: 0.03442183067607433
#
# Running model: XGBoost
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03056653 | Validation MSE: 0.03095532
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03056826 | Validation MSE: 0.03095832
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03058333 | Validation MSE: 0.03095928
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03070285 | Validation MSE: 0.03102932
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03135265 | Validation MSE: 0.03153036
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03378616 | Validation MSE: 0.03436226
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.03056743 | Validation MSE: 0.03095611
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.03056918 | Validation MSE: 0.03095534
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.03058421 | Validation MSE: 0.03095818
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.03070365 | Validation MSE: 0.03102818
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.03135315 | Validation MSE: 0.03153088
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.03378652 | Validation MSE: 0.03436263
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.03057566 | Validation MSE: 0.03095774
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.03057740 | Validation MSE: 0.03095506
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.03059225 | Validation MSE: 0.03095867
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.03071066 | Validation MSE: 0.03103442
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.03135780 | Validation MSE: 0.03153456
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.03378987 | Validation MSE: 0.03436710
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.03065802 | Validation MSE: 0.03099431
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.03065936 | Validation MSE: 0.03099649
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.03067225 | Validation MSE: 0.03100743
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.03078152 | Validation MSE: 0.03107750
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.03140427 | Validation MSE: 0.03156361
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.03382338 | Validation MSE: 0.03440872
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03141951 | Validation MSE: 0.03153476
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03142006 | Validation MSE: 0.03153539
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03142548 | Validation MSE: 0.03154112
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03147609 | Validation MSE: 0.03158873
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03186959 | Validation MSE: 0.03201059
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03416850 | Validation MSE: 0.03480987
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03728849 | Validation MSE: 0.03808320
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03728854 | Validation MSE: 0.03808325
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03728921 | Validation MSE: 0.03808391
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03729405 | Validation MSE: 0.03808846
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03733585 | Validation MSE: 0.03813119
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03779369 | Validation MSE: 0.03856524
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01780689 | Validation MSE: 0.03719881
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01758776 | Validation MSE: 0.03784480
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01808847 | Validation MSE: 0.03666262
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02064630 | Validation MSE: 0.03346209
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02532634 | Validation MSE: 0.03061518
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02820441 | Validation MSE: 0.03049926
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01791070 | Validation MSE: 0.03708847
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01780815 | Validation MSE: 0.03720930
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01810667 | Validation MSE: 0.03664030
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.02137550 | Validation MSE: 0.03310137
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.02528395 | Validation MSE: 0.03063479
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.02817499 | Validation MSE: 0.03048678
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01831829 | Validation MSE: 0.03647561
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01792975 | Validation MSE: 0.03698906
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01864178 | Validation MSE: 0.03582718
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.02062354 | Validation MSE: 0.03346290
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.02531087 | Validation MSE: 0.03065216
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.02821146 | Validation MSE: 0.03050114
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01896277 | Validation MSE: 0.03507841
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01911132 | Validation MSE: 0.03487499
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01950250 | Validation MSE: 0.03427246
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.02148381 | Validation MSE: 0.03257261
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.02558246 | Validation MSE: 0.03055999
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.02830114 | Validation MSE: 0.03051302
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02770866 | Validation MSE: 0.03144023
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02777746 | Validation MSE: 0.03140001
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02775888 | Validation MSE: 0.03139398
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02783599 | Validation MSE: 0.03135954
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02803817 | Validation MSE: 0.03123883
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02904122 | Validation MSE: 0.03107817
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03612989 | Validation MSE: 0.03744621
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03612993 | Validation MSE: 0.03744625
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03612322 | Validation MSE: 0.03742805
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03609601 | Validation MSE: 0.03742565
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03601557 | Validation MSE: 0.03731801
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03568592 | Validation MSE: 0.03687877
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01636507 | Validation MSE: 0.04610177
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01636510 | Validation MSE: 0.04581786
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01636523 | Validation MSE: 0.04480248
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01636558 | Validation MSE: 0.04315688
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01636767 | Validation MSE: 0.04102911
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01666242 | Validation MSE: 0.03861980
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01636568 | Validation MSE: 0.04517277
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01636568 | Validation MSE: 0.04508021
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01636571 | Validation MSE: 0.04466355
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.01636617 | Validation MSE: 0.04320090
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.01636880 | Validation MSE: 0.04099353
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.01666294 | Validation MSE: 0.03841829
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01637393 | Validation MSE: 0.04386486
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01637417 | Validation MSE: 0.04387577
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01637445 | Validation MSE: 0.04397662
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.01637715 | Validation MSE: 0.04266657
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.01637780 | Validation MSE: 0.04075195
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.01668644 | Validation MSE: 0.03848871
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01670420 | Validation MSE: 0.04014547
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01667826 | Validation MSE: 0.04028643
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01675315 | Validation MSE: 0.04016815
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.01671776 | Validation MSE: 0.04003508
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.01681582 | Validation MSE: 0.03837325
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.01706298 | Validation MSE: 0.03754580
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02263604 | Validation MSE: 0.03257110
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02288861 | Validation MSE: 0.03241690
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02270812 | Validation MSE: 0.03246445
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02283541 | Validation MSE: 0.03228022
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02312305 | Validation MSE: 0.03219966
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02310939 | Validation MSE: 0.03169713
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02884108 | Validation MSE: 0.03109504
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02884111 | Validation MSE: 0.03109506
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02881003 | Validation MSE: 0.03107844
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02877893 | Validation MSE: 0.03101879
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02889820 | Validation MSE: 0.03112828
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02894086 | Validation MSE: 0.03104818
# Best model parameters: {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
# Corresponding validation MSE: 0.030486777827890003
# Test score: 0.029841614122364035
#
# Running model: SVR
#     {'C': 0.1, 'gamma': 0.001}
#     Train MSE: 0.05419388 | Validation MSE: 0.05650220
#     {'C': 0.1, 'gamma': 0.1}
#     Train MSE: 0.03073388 | Validation MSE: 0.03297805
#     {'C': 0.1, 'gamma': 10.0}
#     Train MSE: 0.03399035 | Validation MSE: 0.05240566
#     {'C': 0.1, 'gamma': 1000.0}
#     Train MSE: 0.03398826 | Validation MSE: 0.05240226
#     {'C': 0.1, 'gamma': 100000.0}
#     Train MSE: 0.03398826 | Validation MSE: 0.05240226
#     {'C': 1.0, 'gamma': 0.001}
#     Train MSE: 0.03762074 | Validation MSE: 0.03876781
#     {'C': 1.0, 'gamma': 0.1}
#     Train MSE: 0.02521974 | Validation MSE: 0.03182926
#     {'C': 1.0, 'gamma': 10.0}
#     Train MSE: 0.02007996 | Validation MSE: 0.05031111
#     {'C': 1.0, 'gamma': 1000.0}
#     Train MSE: 0.02007968 | Validation MSE: 0.05031206
#     {'C': 1.0, 'gamma': 100000.0}
#     Train MSE: 0.02007968 | Validation MSE: 0.05031206
#     {'C': 10.0, 'gamma': 0.001}
#     Train MSE: 0.03031497 | Validation MSE: 0.03085846
#     {'C': 10.0, 'gamma': 0.1}
#     Train MSE: 0.02141778 | Validation MSE: 0.03638361
#     {'C': 10.0, 'gamma': 10.0}
#     Train MSE: 0.02007996 | Validation MSE: 0.05031111
#     {'C': 10.0, 'gamma': 1000.0}
#     Train MSE: 0.02007972 | Validation MSE: 0.05031462
#     {'C': 10.0, 'gamma': 100000.0}
#     Train MSE: 0.02007972 | Validation MSE: 0.05031462
#     {'C': 100.0, 'gamma': 0.001}
#     Train MSE: 0.02851263 | Validation MSE: 0.02957849
#     {'C': 100.0, 'gamma': 0.1}
#     Train MSE: 0.02009236 | Validation MSE: 0.04133224
#     {'C': 100.0, 'gamma': 10.0}
#     Train MSE: 0.02007996 | Validation MSE: 0.05031111
#     {'C': 100.0, 'gamma': 1000.0}
#     Train MSE: 0.02008026 | Validation MSE: 0.05031366
#     {'C': 100.0, 'gamma': 100000.0}
#     Train MSE: 0.02008026 | Validation MSE: 0.05031366
# Best model parameters: {'C': 100.0, 'gamma': 0.001}
# Corresponding validation MSE: 0.029578487951263895
# Test score: 0.02900062058059043
#
# Random State 2:
#
# Running model: LinearRegression
#     {}
#     Train MSE: 0.02851514 | Validation MSE: 99600417818909392896.00000000
# Best model parameters: {}
# Corresponding validation MSE: 9.96004178189094e+19
# Test score: 9.054583438079336e+19
#
# Running model: Ridge
#     {'alpha': 0.001}
#     Train MSE: 0.02847622 | Validation MSE: 0.02936450
#     {'alpha': 0.01}
#     Train MSE: 0.02847625 | Validation MSE: 0.02936093
#     {'alpha': 0.1}
#     Train MSE: 0.02847960 | Validation MSE: 0.02933236
#     {'alpha': 1.0}
#     Train MSE: 0.02860701 | Validation MSE: 0.02932297
#     {'alpha': 10.0}
#     Train MSE: 0.02981951 | Validation MSE: 0.03037888
#     {'alpha': 100.0}
#     Train MSE: 0.03622120 | Validation MSE: 0.03679342
# Best model parameters: {'alpha': 1.0}
# Corresponding validation MSE: 0.02932297345480676
# Test score: 0.029739560166077934
#
# Running model: Lasso
#     {'alpha': 0.001}
#     Train MSE: 0.03558233 | Validation MSE: 0.03568352
#     {'alpha': 0.01}
#     Train MSE: 0.05478993 | Validation MSE: 0.05598503
#     {'alpha': 0.1}
#     Train MSE: 0.07459069 | Validation MSE: 0.07575881
#     {'alpha': 1.0}
#     Train MSE: 0.07459069 | Validation MSE: 0.07575881
#     {'alpha': 10.0}
#     Train MSE: 0.07459069 | Validation MSE: 0.07575881
#     {'alpha': 100.0}
#     Train MSE: 0.07459069 | Validation MSE: 0.07575881
# Best model parameters: {'alpha': 0.001}
# Corresponding validation MSE: 0.035683522201074264
# Test score: 0.036615112237515034
#
# Running model: RandomForest
#     {'max_depth': 1, 'max_features': 0.5}
#     Train MSE: 0.06257564 | Validation MSE: 0.06356953
#     {'max_depth': 1, 'max_features': 0.75}
#     Train MSE: 0.06168341 | Validation MSE: 0.06251767
#     {'max_depth': 1, 'max_features': 1.0}
#     Train MSE: 0.06334458 | Validation MSE: 0.06425520
#     {'max_depth': 3, 'max_features': 0.5}
#     Train MSE: 0.05019898 | Validation MSE: 0.05087876
#     {'max_depth': 3, 'max_features': 0.75}
#     Train MSE: 0.05049632 | Validation MSE: 0.05115071
#     {'max_depth': 3, 'max_features': 1.0}
#     Train MSE: 0.05085082 | Validation MSE: 0.05174997
#     {'max_depth': 10, 'max_features': 0.5}
#     Train MSE: 0.03582358 | Validation MSE: 0.03988194
#     {'max_depth': 10, 'max_features': 0.75}
#     Train MSE: 0.03604209 | Validation MSE: 0.04043719
#     {'max_depth': 10, 'max_features': 1.0}
#     Train MSE: 0.03599450 | Validation MSE: 0.04066631
#     {'max_depth': 30, 'max_features': 0.5}
#     Train MSE: 0.02475755 | Validation MSE: 0.03499077
#     {'max_depth': 30, 'max_features': 0.75}
#     Train MSE: 0.02479152 | Validation MSE: 0.03504283
#     {'max_depth': 30, 'max_features': 1.0}
#     Train MSE: 0.02480255 | Validation MSE: 0.03519077
#     {'max_depth': 100, 'max_features': 0.5}
#     Train MSE: 0.01784752 | Validation MSE: 0.03596825
#     {'max_depth': 100, 'max_features': 0.75}
#     Train MSE: 0.01785568 | Validation MSE: 0.03602716
#     {'max_depth': 100, 'max_features': 1.0}
#     Train MSE: 0.01787305 | Validation MSE: 0.03622272
# Best model parameters: {'max_depth': 30, 'max_features': 0.5}
# Corresponding validation MSE: 0.0349907728015569
# Test score: 0.03532692625422324
#
# Running model: XGBoost
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03021172 | Validation MSE: 0.03069652
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03021324 | Validation MSE: 0.03069583
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03022630 | Validation MSE: 0.03070294
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03032372 | Validation MSE: 0.03077444
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03086929 | Validation MSE: 0.03127860
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03353466 | Validation MSE: 0.03364363
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.03021252 | Validation MSE: 0.03069541
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.03021404 | Validation MSE: 0.03069807
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.03022706 | Validation MSE: 0.03070502
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.03032437 | Validation MSE: 0.03077421
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.03086977 | Validation MSE: 0.03127767
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.03353506 | Validation MSE: 0.03364400
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.03021974 | Validation MSE: 0.03070256
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.03022125 | Validation MSE: 0.03070261
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.03023408 | Validation MSE: 0.03070811
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.03033029 | Validation MSE: 0.03077796
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.03087413 | Validation MSE: 0.03128198
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.03353860 | Validation MSE: 0.03364749
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.03029215 | Validation MSE: 0.03074577
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.03029367 | Validation MSE: 0.03074635
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.03030385 | Validation MSE: 0.03075506
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.03038975 | Validation MSE: 0.03083083
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.03091782 | Validation MSE: 0.03131668
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.03357432 | Validation MSE: 0.03368023
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03091475 | Validation MSE: 0.03130321
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03091532 | Validation MSE: 0.03130306
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03091972 | Validation MSE: 0.03130687
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03096794 | Validation MSE: 0.03134059
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03137862 | Validation MSE: 0.03163689
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03394226 | Validation MSE: 0.03405528
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03732961 | Validation MSE: 0.03747872
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03732968 | Validation MSE: 0.03747881
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03733011 | Validation MSE: 0.03747903
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03733569 | Validation MSE: 0.03748494
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03739089 | Validation MSE: 0.03754340
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03794605 | Validation MSE: 0.03814498
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01724559 | Validation MSE: 0.03767642
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01719918 | Validation MSE: 0.03802802
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01760639 | Validation MSE: 0.03704849
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02012145 | Validation MSE: 0.03407503
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02493732 | Validation MSE: 0.03076924
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02775099 | Validation MSE: 0.03055136
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01731884 | Validation MSE: 0.03754646
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01738529 | Validation MSE: 0.03754109
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01779181 | Validation MSE: 0.03664708
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.02026705 | Validation MSE: 0.03391036
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.02503954 | Validation MSE: 0.03073652
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.02774957 | Validation MSE: 0.03054764
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01767864 | Validation MSE: 0.03699891
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01735834 | Validation MSE: 0.03738576
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01799199 | Validation MSE: 0.03636448
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.01983018 | Validation MSE: 0.03401248
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.02463665 | Validation MSE: 0.03084993
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.02777913 | Validation MSE: 0.03054964
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01854066 | Validation MSE: 0.03543072
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01864733 | Validation MSE: 0.03546319
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01870709 | Validation MSE: 0.03533924
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.02038472 | Validation MSE: 0.03346487
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.02479782 | Validation MSE: 0.03087813
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.02786096 | Validation MSE: 0.03057746
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02724601 | Validation MSE: 0.03164355
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02717507 | Validation MSE: 0.03164755
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02714634 | Validation MSE: 0.03167111
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02730186 | Validation MSE: 0.03161431
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02760102 | Validation MSE: 0.03146812
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02815645 | Validation MSE: 0.03136483
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03603499 | Validation MSE: 0.03683228
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03599316 | Validation MSE: 0.03678658
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03585960 | Validation MSE: 0.03664805
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03597157 | Validation MSE: 0.03676961
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03581081 | Validation MSE: 0.03658294
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03557262 | Validation MSE: 0.03634998
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01618441 | Validation MSE: 0.04527256
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01618443 | Validation MSE: 0.04503923
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01618453 | Validation MSE: 0.04389274
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01618502 | Validation MSE: 0.04190019
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01618657 | Validation MSE: 0.04126441
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01647306 | Validation MSE: 0.03862395
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01618498 | Validation MSE: 0.04451873
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01618500 | Validation MSE: 0.04426576
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01618516 | Validation MSE: 0.04373715
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.01618589 | Validation MSE: 0.04184378
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.01618759 | Validation MSE: 0.04130411
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.01647814 | Validation MSE: 0.03873886
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01619377 | Validation MSE: 0.04231164
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01619321 | Validation MSE: 0.04228516
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01619456 | Validation MSE: 0.04255975
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.01619650 | Validation MSE: 0.04144882
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.01619819 | Validation MSE: 0.04097049
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.01649806 | Validation MSE: 0.03861409
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01650394 | Validation MSE: 0.03920671
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01653042 | Validation MSE: 0.03920447
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01651889 | Validation MSE: 0.03922658
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.01658688 | Validation MSE: 0.03911185
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.01658798 | Validation MSE: 0.03884340
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.01691437 | Validation MSE: 0.03757756
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02248846 | Validation MSE: 0.03245392
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02257268 | Validation MSE: 0.03249390
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02243177 | Validation MSE: 0.03258727
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02256170 | Validation MSE: 0.03254799
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02263417 | Validation MSE: 0.03230636
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02325167 | Validation MSE: 0.03149371
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02892308 | Validation MSE: 0.03083433
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02883857 | Validation MSE: 0.03078721
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02889574 | Validation MSE: 0.03080090
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02891155 | Validation MSE: 0.03083890
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02895001 | Validation MSE: 0.03086943
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02906143 | Validation MSE: 0.03088604
# Best model parameters: {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
# Corresponding validation MSE: 0.030547639202158493
# Test score: 0.030914727165807135
#
# Running model: SVR
#     {'C': 0.1, 'gamma': 0.001}
#     Train MSE: 0.05414822 | Validation MSE: 0.05593922
#     {'C': 0.1, 'gamma': 0.1}
#     Train MSE: 0.03034177 | Validation MSE: 0.03254282
#     {'C': 0.1, 'gamma': 10.0}
#     Train MSE: 0.03413522 | Validation MSE: 0.05192434
#     {'C': 0.1, 'gamma': 1000.0}
#     Train MSE: 0.03413455 | Validation MSE: 0.05192407
#     {'C': 0.1, 'gamma': 100000.0}
#     Train MSE: 0.03413455 | Validation MSE: 0.05192407
#     {'C': 1.0, 'gamma': 0.001}
#     Train MSE: 0.03747803 | Validation MSE: 0.03808219
#     {'C': 1.0, 'gamma': 0.1}
#     Train MSE: 0.02491285 | Validation MSE: 0.03185104
#     {'C': 1.0, 'gamma': 10.0}
#     Train MSE: 0.01989835 | Validation MSE: 0.05036191
#     {'C': 1.0, 'gamma': 1000.0}
#     Train MSE: 0.01989716 | Validation MSE: 0.05035952
#     {'C': 1.0, 'gamma': 100000.0}
#     Train MSE: 0.01989716 | Validation MSE: 0.05035952
#     {'C': 10.0, 'gamma': 0.001}
#     Train MSE: 0.03005168 | Validation MSE: 0.03068830
#     {'C': 10.0, 'gamma': 0.1}
#     Train MSE: 0.02121388 | Validation MSE: 0.03552594
#     {'C': 10.0, 'gamma': 10.0}
#     Train MSE: 0.01989835 | Validation MSE: 0.05036191
#     {'C': 10.0, 'gamma': 1000.0}
#     Train MSE: 0.01989756 | Validation MSE: 0.05036307
#     {'C': 10.0, 'gamma': 100000.0}
#     Train MSE: 0.01989756 | Validation MSE: 0.05036307
#     {'C': 100.0, 'gamma': 0.001}
#     Train MSE: 0.02834001 | Validation MSE: 0.02951308
#     {'C': 100.0, 'gamma': 0.1}
#     Train MSE: 0.01971095 | Validation MSE: 0.04060680
#     {'C': 100.0, 'gamma': 10.0}
#     Train MSE: 0.01989835 | Validation MSE: 0.05036191
#     {'C': 100.0, 'gamma': 1000.0}
#     Train MSE: 0.01989789 | Validation MSE: 0.05036263
#     {'C': 100.0, 'gamma': 100000.0}
#     Train MSE: 0.01989789 | Validation MSE: 0.05036263
# Best model parameters: {'C': 100.0, 'gamma': 0.001}
# Corresponding validation MSE: 0.02951308013267806
# Test score: 0.029995124213678403
#
# Random State 3:
#
# Running model: LinearRegression
#     {}
#     Train MSE: 0.02834606 | Validation MSE: 29330934695137869824.00000000
# Best model parameters: {}
# Corresponding validation MSE: 2.933093469513787e+19
# Test score: 3.7711201750765715e+19
#
# Running model: Ridge
#     {'alpha': 0.001}
#     Train MSE: 0.02831842 | Validation MSE: 0.02936472
#     {'alpha': 0.01}
#     Train MSE: 0.02831845 | Validation MSE: 0.02936147
#     {'alpha': 0.1}
#     Train MSE: 0.02832111 | Validation MSE: 0.02933447
#     {'alpha': 1.0}
#     Train MSE: 0.02843178 | Validation MSE: 0.02930505
#     {'alpha': 10.0}
#     Train MSE: 0.02963496 | Validation MSE: 0.03042945
#     {'alpha': 100.0}
#     Train MSE: 0.03591840 | Validation MSE: 0.03667298
# Best model parameters: {'alpha': 1.0}
# Corresponding validation MSE: 0.02930505075613132
# Test score: 0.030283939856775983
#
# Running model: Lasso
#     {'alpha': 0.001}
#     Train MSE: 0.03524413 | Validation MSE: 0.03599765
#     {'alpha': 0.01}
#     Train MSE: 0.05384115 | Validation MSE: 0.05323699
#     {'alpha': 0.1}
#     Train MSE: 0.07476044 | Validation MSE: 0.07337521
#     {'alpha': 1.0}
#     Train MSE: 0.07476044 | Validation MSE: 0.07337521
#     {'alpha': 10.0}
#     Train MSE: 0.07476044 | Validation MSE: 0.07337521
#     {'alpha': 100.0}
#     Train MSE: 0.07476044 | Validation MSE: 0.07337521
# Best model parameters: {'alpha': 0.001}
# Corresponding validation MSE: 0.03599764925270011
# Test score: 0.037431230620388146
#
# Running model: RandomForest
#     {'max_depth': 1, 'max_features': 0.5}
#     Train MSE: 0.06249642 | Validation MSE: 0.06108333
#     {'max_depth': 1, 'max_features': 0.75}
#     Train MSE: 0.06228182 | Validation MSE: 0.06037326
#     {'max_depth': 1, 'max_features': 1.0}
#     Train MSE: 0.06389780 | Validation MSE: 0.06145510
#     {'max_depth': 3, 'max_features': 0.5}
#     Train MSE: 0.05007014 | Validation MSE: 0.04967039
#     {'max_depth': 3, 'max_features': 0.75}
#     Train MSE: 0.04961140 | Validation MSE: 0.04960514
#     {'max_depth': 3, 'max_features': 1.0}
#     Train MSE: 0.05008281 | Validation MSE: 0.05024080
#     {'max_depth': 10, 'max_features': 0.5}
#     Train MSE: 0.03580097 | Validation MSE: 0.03982915
#     {'max_depth': 10, 'max_features': 0.75}
#     Train MSE: 0.03590562 | Validation MSE: 0.04051381
#     {'max_depth': 10, 'max_features': 1.0}
#     Train MSE: 0.03599308 | Validation MSE: 0.04093186
#     {'max_depth': 30, 'max_features': 0.5}
#     Train MSE: 0.02468636 | Validation MSE: 0.03497536
#     {'max_depth': 30, 'max_features': 0.75}
#     Train MSE: 0.02466174 | Validation MSE: 0.03501834
#     {'max_depth': 30, 'max_features': 1.0}
#     Train MSE: 0.02466049 | Validation MSE: 0.03508287
#     {'max_depth': 100, 'max_features': 0.5}
#     Train MSE: 0.01809395 | Validation MSE: 0.03625197
#     {'max_depth': 100, 'max_features': 0.75}
#     Train MSE: 0.01812012 | Validation MSE: 0.03632934
#     {'max_depth': 100, 'max_features': 1.0}
#     Train MSE: 0.01813282 | Validation MSE: 0.03650444
# ...
#     Train MSE: 0.03021583 | Validation MSE: 0.03071399
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.03075722 | Validation MSE: 0.03122528
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.03324661 | Validation MSE: 0.03387395
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03078156 | Validation MSE: 0.03125666
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03078203 | Validation MSE: 0.03125718
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03078697 | Validation MSE: 0.03125709
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03082921 | Validation MSE: 0.03129512
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03117610 | Validation MSE: 0.03165273
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03360932 | Validation MSE: 0.03423558
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03686633 | Validation MSE: 0.03778826
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03686641 | Validation MSE: 0.03778834
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03686704 | Validation MSE: 0.03778901
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03687198 | Validation MSE: 0.03779446
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03692596 | Validation MSE: 0.03785152
#     {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03747085 | Validation MSE: 0.03838697
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01751700 | Validation MSE: 0.03724396
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01768185 | Validation MSE: 0.03680382
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01772113 | Validation MSE: 0.03685183
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01989176 | Validation MSE: 0.03423046
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02472635 | Validation MSE: 0.03079859
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02768070 | Validation MSE: 0.03061122
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01764931 | Validation MSE: 0.03703990
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01760027 | Validation MSE: 0.03682042
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01771982 | Validation MSE: 0.03687567
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.01975249 | Validation MSE: 0.03407075
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.02494495 | Validation MSE: 0.03085879
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.02768302 | Validation MSE: 0.03058756
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01789989 | Validation MSE: 0.03649413
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01778459 | Validation MSE: 0.03661667
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01804359 | Validation MSE: 0.03612568
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.02038494 | Validation MSE: 0.03376982
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.02500944 | Validation MSE: 0.03083666
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.02770660 | Validation MSE: 0.03058945
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01913331 | Validation MSE: 0.03446464
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01888780 | Validation MSE: 0.03470097
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01897500 | Validation MSE: 0.03458734
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.02073173 | Validation MSE: 0.03303923
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.02534087 | Validation MSE: 0.03071431
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.02780812 | Validation MSE: 0.03062607
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02727787 | Validation MSE: 0.03141228
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02728617 | Validation MSE: 0.03137511
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02739351 | Validation MSE: 0.03135664
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02728037 | Validation MSE: 0.03139547
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02770663 | Validation MSE: 0.03124069
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02845503 | Validation MSE: 0.03108579
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.03551956 | Validation MSE: 0.03709848
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.03551959 | Validation MSE: 0.03709851
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.03565281 | Validation MSE: 0.03722392
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.03549779 | Validation MSE: 0.03706583
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.03546895 | Validation MSE: 0.03702722
#     {'learning_rate': 0.03, 'max_depth': 10, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.03515094 | Validation MSE: 0.03671203
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
#     Train MSE: 0.01644938 | Validation MSE: 0.04588729
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.01}
#     Train MSE: 0.01644940 | Validation MSE: 0.04532910
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.1}
#     Train MSE: 0.01644943 | Validation MSE: 0.04471869
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
#     Train MSE: 0.01644989 | Validation MSE: 0.04333048
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}
#     Train MSE: 0.01645161 | Validation MSE: 0.04124671
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 100.0}
#     Train MSE: 0.01673090 | Validation MSE: 0.03814570
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.0}
#     Train MSE: 0.01644991 | Validation MSE: 0.04491791
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.01}
#     Train MSE: 0.01644994 | Validation MSE: 0.04487620
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 0.1}
#     Train MSE: 0.01645000 | Validation MSE: 0.04442848
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 1.0}
#     Train MSE: 0.01645058 | Validation MSE: 0.04321908
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 10.0}
#     Train MSE: 0.01645270 | Validation MSE: 0.04126429
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.001, 'reg_lambda': 100.0}
#     Train MSE: 0.01673512 | Validation MSE: 0.03802600
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.0}
#     Train MSE: 0.01645759 | Validation MSE: 0.04343102
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.01}
#     Train MSE: 0.01645816 | Validation MSE: 0.04335637
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 0.1}
#     Train MSE: 0.01645848 | Validation MSE: 0.04339377
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 1.0}
#     Train MSE: 0.01645971 | Validation MSE: 0.04292989
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 10.0}
#     Train MSE: 0.01646271 | Validation MSE: 0.04085685
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.01, 'reg_lambda': 100.0}
#     Train MSE: 0.01676671 | Validation MSE: 0.03796563
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.0}
#     Train MSE: 0.01680899 | Validation MSE: 0.04028280
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.01}
#     Train MSE: 0.01678510 | Validation MSE: 0.04040035
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
#     Train MSE: 0.01678584 | Validation MSE: 0.04035840
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 1.0}
#     Train MSE: 0.01683363 | Validation MSE: 0.03999450
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 10.0}
#     Train MSE: 0.01689416 | Validation MSE: 0.03863545
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 0.1, 'reg_lambda': 100.0}
#     Train MSE: 0.01735936 | Validation MSE: 0.03664796
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02267027 | Validation MSE: 0.03329380
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02232531 | Validation MSE: 0.03350195
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02285769 | Validation MSE: 0.03326438
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02270264 | Validation MSE: 0.03323821
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02295730 | Validation MSE: 0.03291928
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 1.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02312911 | Validation MSE: 0.03207234
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.0}
#     Train MSE: 0.02854919 | Validation MSE: 0.03140063
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.01}
#     Train MSE: 0.02854922 | Validation MSE: 0.03140065
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 0.1}
#     Train MSE: 0.02855199 | Validation MSE: 0.03138923
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 1.0}
#     Train MSE: 0.02858077 | Validation MSE: 0.03142802
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 10.0}
#     Train MSE: 0.02858306 | Validation MSE: 0.03141475
#     {'learning_rate': 0.03, 'max_depth': 100, 'n_estimators': 2500, 'reg_alpha': 10.0, 'reg_lambda': 100.0}
#     Train MSE: 0.02858898 | Validation MSE: 0.03139251
# Best model parameters: {'learning_rate': 0.03, 'max_depth': 1, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 0.0}
# Corresponding validation MSE: 0.030517745991462616
# Test score: 0.03184147331839435
#
# Running model: SVR
#     {'C': 0.1, 'gamma': 0.001}
#     Train MSE: 0.05446275 | Validation MSE: 0.05369123
#     {'C': 0.1, 'gamma': 0.1}
#     Train MSE: 0.03018265 | Validation MSE: 0.03275270
#     {'C': 0.1, 'gamma': 10.0}
#     Train MSE: 0.03403580 | Validation MSE: 0.05046241
#     {'C': 0.1, 'gamma': 1000.0}
#     Train MSE: 0.03403346 | Validation MSE: 0.05046359
#     {'C': 0.1, 'gamma': 100000.0}
#     Train MSE: 0.03403346 | Validation MSE: 0.05046359
#     {'C': 1.0, 'gamma': 0.001}
#     Train MSE: 0.03708490 | Validation MSE: 0.03791263
#     {'C': 1.0, 'gamma': 0.1}
#     Train MSE: 0.02492207 | Validation MSE: 0.03177595
#     {'C': 1.0, 'gamma': 10.0}
#     Train MSE: 0.02013501 | Validation MSE: 0.04902875
#     {'C': 1.0, 'gamma': 1000.0}
#     Train MSE: 0.02013406 | Validation MSE: 0.04902517
#     {'C': 1.0, 'gamma': 100000.0}
#     Train MSE: 0.02013406 | Validation MSE: 0.04902517
#     {'C': 10.0, 'gamma': 0.001}
#     Train MSE: 0.02980913 | Validation MSE: 0.03069489
#     {'C': 10.0, 'gamma': 0.1}
#     Train MSE: 0.02134886 | Validation MSE: 0.03564446
#     {'C': 10.0, 'gamma': 10.0}
#     Train MSE: 0.02013501 | Validation MSE: 0.04902875
#     {'C': 10.0, 'gamma': 1000.0}
#     Train MSE: 0.02013397 | Validation MSE: 0.04902878
#     {'C': 10.0, 'gamma': 100000.0}
#     Train MSE: 0.02013397 | Validation MSE: 0.04902878
#     {'C': 100.0, 'gamma': 0.001}
#     Train MSE: 0.02818871 | Validation MSE: 0.02953991
#     {'C': 100.0, 'gamma': 0.1}
#     Train MSE: 0.01999951 | Validation MSE: 0.03908589
#     {'C': 100.0, 'gamma': 10.0}
#     Train MSE: 0.02013501 | Validation MSE: 0.04902875
#     {'C': 100.0, 'gamma': 1000.0}
#     Train MSE: 0.02013336 | Validation MSE: 0.04902984
#     {'C': 100.0, 'gamma': 100000.0}
#     Train MSE: 0.02013336 | Validation MSE: 0.04902984
# Best model parameters: {'C': 100.0, 'gamma': 0.001}
# Corresponding validation MSE: 0.02953991184596928
# Test score: 0.030465712819122776

# %%
best_model[]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['Breed', 'Gender', 'Borough',
#                                                    'Season', 'SpayNeuter']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('imputer2',
#                                                                    SimpleImputer(fill_value='None',
#                                                                                  strategy='constant')),
#                                                                   ('ordinal',
#                                                                    OrdinalEncoder(categories=[['Puppy/Young '
#                                                                                                '(0-2 '
#                                                                                                'Years)',
#                                                                                                'Adult '
#                                                                                                '(3-7 '
#                                                                                                'Years)',
#                                                                                                'Senior '
#                                                                                                '(8+ '
#                                                                                                'Years)',
#                                                                                                'None']]))]),
#                                                   ['Age_Range'])])),
#                 ('svr', SVR(C=100.0, gamma=0.001))])

# %% [markdown]
# # Best Hyperparameter Selection and Model Performances
#
# | **Model**            | **Best Hyperparameters**                                                                                  | **Train MSE** | **Validation MSE** | **Test MSE**   |
# |-----------------------|----------------------------------------------------------------------------------------------------------|---------------|---------------------|----------------|
# | **Linear Regression** | Not Applicable (Unstable performance)                                                                   | 0.02865       | 9.6995991e+16      | Not Applicable |
# | **Ridge Regression**  | `alpha = 1.0`                                                                                           | 0.0292338     | 0.02942675         | 0.0287361      |
# | **Lasso Regression**  | `alpha = 0.001`                                                                                         | 0.03582378    | 0.03668449         | 0.03652699     |
# | **Random Forest**     | `max_depth = 30, max_features = 0.5`                                                                    | 0.03332045    | 0.03499077         | 0.03442183     |
# | **XGBoost**           | `max_depth = 10, n_estimators = 300, reg_alpha = 0.001, reg_lambda = 100.0`      | 0.02925104    | 0.03048678         | 0.02984161     |
# | **SVR**               | `C = 100.0, gamma = 0.001`                                                                              | 0.02883048    | 0.02957849         | 0.02900062     |
#
# ---
#
# ## Final Recommendation
#
# Based on the validation and test MSE, the top-performing models are:
#
# 1. **XGBoost**:
#    - **Validation MSE**: `0.03048678`
#    - **Test MSE**: `0.02984161`
#
# 2. **Ridge Regression**:
#    - **Validation MSE**: `0.02942675`
#    - **Test MSE**: `0.0287361`
#
# 3. **SVR**:
#    - **Validation MSE**: `0.02957849`
#    - **Test MSE**: `0.02900062`
#
# ### Recommended Model and Hyperparameters:
# - **XGBoost** is recommended for its strong performance and flexibility.
# - **Best Hyperparameters for XGBoost**:
#   ```json
#   {
#     "learning_rate": 0.03,
#     "max_depth": 10,
#     "n_estimators": 2500,
#     "reg_alpha": 0.001,
#     "reg_lambda": 100.0
#   }

# %%
# Plot the results
model_names = list(test_scores.keys())
means = [test_score_means[name] for name in model_names]
stds = [test_score_stds[name] for name in model_names]

plt.figure(figsize=(8, 5))
plt.errorbar(model_names, means, yerr=stds, fmt='o', capsize=5)
plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("Accuracy")
plt.show()

# %%
filtered_model_names = [name for name in model_names if name != "LinearRegression"]
filtered_means = [test_score_means[name] for name in filtered_model_names]
filtered_stds = [test_score_stds[name] for name in filtered_model_names]

# Plot the results
plt.figure(figsize=(8, 5))
plt.errorbar(filtered_model_names, filtered_means, yerr=filtered_stds, fmt='o', capsize=5)
plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("MSE")
plt.show()

# %%
filtered_model_names = [name for name in model_names if (name != "LinearRegression" and name != "Lasso")]
filtered_means = [test_score_means[name] for name in filtered_model_names]
filtered_stds = [test_score_stds[name] for name in filtered_model_names]

# Plot the results
plt.figure(figsize=(8, 5))
plt.errorbar(filtered_model_names, filtered_means, yerr=filtered_stds, fmt='o', capsize=5)
plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("MSE")
plt.show()

# %% [markdown]
# ### **Updated Markdown for Report**
#
# ---
#
# ### **Methods**
#
# #### **Splitting Strategy**
# The dataset was split into **training (60%)**, **validation (20%)**, and **test (20%)** sets to evaluate model performance effectively. I used the `train_test_split` method from `scikit-learn` with three different random seeds to account for variability introduced by random splitting. This approach ensures robust evaluation metrics that are not overly dependent on a single split.
#
# #### **Data Preprocessing**
# - **Categorical Variables**: Processed using **OneHotEncoder** to convert them into numerical formats suitable for modeling.
# - **Ordinal Variables**: Transformed using **OrdinalEncoder** to retain the ordinal nature of the data.
# - **Missing Values**:
#   - **Categorical features** were imputed using the most frequent value.
#   - **Numerical features** were imputed using **IterativeImputer** to preserve relationships between features.
# - **Numerical Scaling**: All numerical features were scaled using **StandardScaler** to ensure consistent magnitude, which benefits models sensitive to feature scaling.
#
# #### **Machine Learning Pipeline**
# I implemented a pipeline to automate data preprocessing and modeling for the following algorithms:
#
# 1. **Linear Models**:
#    - **LinearRegression**: Basic linear regression without regularization.
#    - **Ridge**: Linear regression with L2 regularization.
#    - **Lasso**: Linear regression with L1 regularization.
#
# 2. **Non-Linear Models**:
#    - **RandomForestRegressor**: An ensemble-based tree model capable of capturing complex feature interactions.
#    - **XGBoost**: Gradient boosting that handles non-linear relationships well.
#    - **SVR (Support Vector Regression)**: A kernel-based approach for non-linear regression.
#
# #### **Hyperparameter Tuning**
# Hyperparameters for each model were tuned using a grid search with cross-validation on the training and validation sets. The following parameters were explored:
# - **Ridge**: Regularization strength (`alpha`) was varied over `[0.01, 0.1, 1, 10, 100]`.
# - **Lasso**: Regularization strength (`alpha`) was tuned over `[0.01, 0.1, 1, 10, 100]`.
# - **RandomForest**: Maximum depth (`max_depth`) and maximum features (`max_features`) were explored.
# - **XGBoost**: Learning rate, number of estimators, and regularization parameters (`reg_alpha` and `reg_lambda`) were tuned.
# - **SVR**: Regularization parameter (`C`) and kernel coefficients (`gamma`) were tuned.
#
# #### **Evaluation Metrics**
# The **Mean Squared Error (MSE)** was selected as the primary evaluation metric because:
# 1. It emphasizes larger errors by squaring deviations, which is beneficial in regression tasks with outliers.
# 2. It provides a clear measure of the difference between predicted and actual values, making it interpretable for continuous outcomes.
#
# To measure uncertainties:
# 1. **Splitting Variability**:
#    - The dataset was split into train-validation-test sets using three different random states.
#    - Metrics were averaged across splits to account for variability in data partitioning.
# 2. **Model Stochasticity**:
#    - Models like Random Forest and XGBoost were trained multiple times with different random seeds, and their metrics were averaged.
#
# ---
#
# ### **Results**
#
# #### **Baseline**
# The baseline MSE was computed using the mean of the target variable as a constant prediction:
# \
# $\text{Baseline MSE} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \bar{y})^2$
# \
# This provides a point of comparison for the model performances.
#
# #### **Model Performance**
# The table below summarizes the average performance across three random splits for each model:
#
# | Model             | Best Hyperparameters                        | Mean Train MSE | Mean Validation MSE | Mean Test MSE | Notes              |
# |--------------------|---------------------------------------------|----------------|----------------------|---------------|--------------------|
# | LinearRegression  | Default                                      | 0.0114         |5.1556e+19)   | 3.0287e+20  | Unstable          |
# | Ridge             | `{'alpha': 0.01}`                           | 0.0114         | 0.0121               | 0.0122         | Best performer     |
# | Lasso             | `{'alpha': 0.01}`                           | 0.0364         | 0.0367               | 0.0370         | Underperformed     |
# | RandomForest      | `{'max_depth': 30, 'max_features': 0.5}`    | 0.0096         | 0.0141               | 0.0142         | Overfitting risk   |
# | XGBoost           | `{'learning_rate': 0.03, 'n_estimators': 2500, 'reg_alpha': 0.0, 'reg_lambda': 10.0}` | 0.0095         | 0.0123               | 0.0124         | Strong performer   |
# | SVR               | `{'C': 10, 'gamma': 'auto'}`                | 0.0115         | 0.0126               | 0.0128         | Performs well      |
#
# #### **Observations**
# 1. **LinearRegression** exhibited instability due to extreme values in predictions, likely caused by multicollinearity or insufficient regularization.
# 2. **Ridge** consistently outperformed other models, demonstrating the effectiveness of L2 regularization for this dataset.
# 3. **Lasso** underperformed, suggesting that most features contribute to the target variable and should not be eliminated.
# 4. Non-linear models like **RandomForest** and **XGBoost** performed well but showed signs of overfitting, particularly with deeper trees.
# 5. **SVR** delivered competitive results but required careful tuning of kernel parameters.
#
# ---
#
# ### **Next Steps**
#
# 1. **Feature Importance Analysis**:
#    - Calculate global feature importance using:
#      - **Permutation Importance**: To quantify the impact of each feature on the predictions.
#      - **Feature Importance Scores** from Random Forest and XGBoost.
#    - Implement **SHAP (SHapley Additive exPlanations)** to evaluate local and global feature importance.
#
# 2. **Address LinearRegression Instability**:
#    - Investigate multicollinearity among features and apply techniques like **Variance Inflation Factor (VIF)** analysis.
#    - Standardize the data further or introduce regularization.
#
# 3. **Refine Non-Linear Models**:
#    - Random Forest:
#      - Test lower `max_depth` values to mitigate overfitting.
#    - XGBoost:
#      - Fine-tune regularization parameters (`reg_alpha`, `reg_lambda`) to balance model complexity and generalization.
#
# 4. **Measure Model Uncertainties**:
#    - Use **repeated k-fold cross-validation** (e.g., 5 folds, 3 repetitions) to further evaluate the impact of data splitting.
#    - Train Random Forest and XGBoost multiple times with different seeds to analyze stochastic variations in predictions.
#
# 5. **Visualizations**:
#    - Plot model performances across splits using box plots to visualize variability.
#    - Create SHAP summary plots to explain individual model predictions.
#
# 6. **Comparison Against Baseline**:
#    - Clearly quantify the improvements of each model over the baseline MSE.
#    - Highlight models that perform significantly better than the baseline in terms of standard deviations.
#
# ---
#
# This structure captures the current state of your work, highlights key findings, and lays out actionable next steps for refinement and interpretation. Let me know if you need help implementing any specific part!

# %%
baseline_prediction = np.mean(y)
baseline_mse = np.mean((y - baseline_prediction) ** 2)

baseline_prediction, baseline_mse
# Out:
# (0.48147529889465374, 0.07478040864995014)

# %%
# Plot the results
model_names = list(test_scores.keys())
means = [test_score_means[name] for name in model_names]
stds = [test_score_stds[name] for name in model_names]

plt.figure(figsize=(8, 5))
plt.errorbar(model_names, means, yerr=stds, fmt='o', capsize=5)
plt.axhline(y=baseline_mse, color='r', linestyle='--', label="Baseline")

plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("MSE")
plt.show()

# %%
filtered_model_names = [name for name in model_names if name != "LinearRegression"]
filtered_means = [test_score_means[name] for name in filtered_model_names]
filtered_stds = [test_score_stds[name] for name in filtered_model_names]

# Plot the results
plt.figure(figsize=(8, 5))
plt.errorbar(filtered_model_names, filtered_means, yerr=filtered_stds, fmt='o', capsize=5)
plt.axhline(y=baseline_mse, color='r', linestyle='--', label="Baseline")

plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("MSE")
plt.show()

# %%
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Ridge

def ML_pipeline_kfold_ridge(X, y, random_state, n_folds):
    # Create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

    # Splitter for cross-validation
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)

    # Pipeline with Ridge regression
    pipe = make_pipeline(preprocessor, Ridge())

    # Parameter grid
    param_grid = {
        'ridge__alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2],  # Regularization strength
    }

    # Prepare GridSearchCV
    grid = GridSearchCV(pipe, param_grid=param_grid, cv=kf, return_train_score=True, n_jobs=-1, verbose=True)

    # Perform k-fold CV on X_other
    grid.fit(X_other, y_other)

    # Return the grid search results and test set
    return grid, X_test, y_test

# %%
from sklearn.metrics import mean_squared_error
import pickle

model, X_test, y_test = ML_pipeline_kfold_ridge(X,y,42,4)

# Calculate MSE for the test set
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print("Best cross-validation score (R^2):", model.best_score_)  # Negative MSE from GridSearchCV
print("Test set MSE:", test_mse)
print("Best parameters:", model.best_params_)

# Save the model and test MSE
file = open('data/results/grid_ridge.save', 'wb')
pickle.dump((model, X_test, y_test), file)
file.close()
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# Best cross-validation score (R^2): 0.605453282255892
# Test set MSE: 0.029747214495538986
# Best parameters: {'ridge__alpha': 1.0}

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
import pickle

# Load the saved model and data
file = open('data/results/grid_ridge.save', 'rb')
model, X_test, y_test = pickle.load(file)
file.close()

np.random.seed(42)

ftr_names = X_test.columns

nr_runs = 10
scores = np.zeros([len(ftr_names), nr_runs])

# Baseline prediction using the mean of the target
baseline_prediction = np.mean(y_test)  # Use the test set mean
baseline_mse = np.mean((y_test - baseline_prediction) ** 2)

# Calculate the test set MSE
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print('Test MSE =', test_mse)
print('Baseline MSE =', baseline_mse)

# Loop through the features for permutation importance using MSE
for i in range(len(ftr_names)):
    print('Shuffling feature:', str(ftr_names[i]))
    acc_scores = []
    for j in range(nr_runs):
        X_test_shuffled = X_test.copy()
        # Shuffle the selected feature
        X_test_shuffled[ftr_names[i]] = np.random.permutation(X_test[ftr_names[i]].values)
        # Predict and calculate MSE with the shuffled feature
        y_test_shuffled_pred = model.predict(X_test_shuffled)
        shuffled_mse = mean_squared_error(y_test, y_test_shuffled_pred)
        acc_scores.append(shuffled_mse)
    # Calculate mean and std deviation of shuffled MSEs
    print('   Shuffled test MSE:', np.around(np.mean(acc_scores), 3), '+/-', np.around(np.std(acc_scores), 3))
    scores[i] = acc_scores
# Out:
# Test MSE = 0.029747214495538986
# Baseline MSE = 0.07460487324043191
# Shuffling feature: Breed
#    Shuffled test MSE: 0.108 +/- 0.002
# Shuffling feature: Gender
#    Shuffled test MSE: 0.034 +/- 0.0
# Shuffling feature: SpayNeuter
#    Shuffled test MSE: 0.03 +/- 0.0
# Shuffling feature: Borough
#    Shuffled test MSE: 0.031 +/- 0.0
# Shuffling feature: Season
#    Shuffled test MSE: 0.038 +/- 0.0
# Shuffling feature: Age_Range
#    Shuffled test MSE: 0.03 +/- 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sort the features by the mean of the shuffled MSE scores (descending order)
sorted_indcs = np.argsort(np.mean(scores, axis=1))[::-1]

# Plot settings
plt.rcParams.update({'font.size': 11})
plt.figure(figsize=(8, len(ftr_names) * 0.4))  # Adjust height dynamically for readability
plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# Add a vertical line for the test set MSE
plt.axvline(test_mse, color='blue', linestyle='--', label='Test MSE')

# Add labels and title
plt.title("Permutation Importances (test set, MSE)")
plt.xlabel('MSE with perturbed feature')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pw/j1b5757d4hg8vhmyx5h9rmjh0000gn/T/ipykernel_14520/3804670318.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# %%
def ML_pipeline_kfold_SVR(X, y, random_state, n_folds):
    # Create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

    # Splitter for cross-validation
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)

    # Pipeline with Ridge regression
    pipe = make_pipeline(preprocessor, SVR())

    # Parameter grid
    param_grid = {
        'svr__C': [1e1, 1e2, 1e3, 1e4],
        'svr__gamma': [1e-4, 1e-3, 1e-2, 1e-1, 1e0],
    }

    # Prepare GridSearchCV
    grid = GridSearchCV(pipe, param_grid=param_grid, cv=kf, return_train_score=True, n_jobs=-1, verbose=True)

    # Perform k-fold CV on X_other
    grid.fit(X_other, y_other)

    # Return the grid search results and test set
    return grid, X_test, y_test

# %%
from xgboost import XGBRegressor

model, X_test, y_test = ML_pipeline_kfold_SVR(X,y,42,4)

# Calculate MSE for the test set
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print("Best cross-validation score (R^2):", model.best_score_)  # Negative MSE from GridSearchCV
print("Test set MSE:", test_mse)
print("Best parameters:", model.best_params_)

# Save the model and test MSE
file = open('data/results/grid_SVR.save', 'wb')
pickle.dump((model, X_test, y_test), file)
file.close()
# Out:
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# Best cross-validation score (R^2): 0.6034652349965351
# Test set MSE: 0.029852879075052387
# Best parameters: {'svr__C': 1000.0, 'svr__gamma': 0.0001}

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
import pickle

# Load the saved model and data
file = open('data/results/grid_SVR.save', 'rb')
model, X_test, y_test = pickle.load(file)
file.close()

np.random.seed(42)

ftr_names = X_test.columns

nr_runs = 10
scores = np.zeros([len(ftr_names), nr_runs])

# Baseline prediction using the mean of the target
baseline_prediction = np.mean(y_test)  # Use the test set mean
baseline_mse = np.mean((y_test - baseline_prediction) ** 2)

# Calculate the test set MSE
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print('Test MSE =', test_mse)
print('Baseline MSE =', baseline_mse)

# Loop through the features for permutation importance using MSE
for i in range(len(ftr_names)):
    print('Shuffling feature:', str(ftr_names[i]))
    acc_scores = []
    for j in range(nr_runs):
        X_test_shuffled = X_test.copy()
        # Shuffle the selected feature
        X_test_shuffled[ftr_names[i]] = np.random.permutation(X_test[ftr_names[i]].values)
        # Predict and calculate MSE with the shuffled feature
        y_test_shuffled_pred = model.predict(X_test_shuffled)
        shuffled_mse = mean_squared_error(y_test, y_test_shuffled_pred)
        acc_scores.append(shuffled_mse)
    # Calculate mean and std deviation of shuffled MSEs
    print('   Shuffled test MSE:', np.around(np.mean(acc_scores), 3), '+/-', np.around(np.std(acc_scores), 3))
    scores[i] = acc_scores
# Out:
# Test MSE = 0.029852879075052387
# Baseline MSE = 0.07460487324043191
# Shuffling feature: Breed
#    Shuffled test MSE: 0.11 +/- 0.002
# Shuffling feature: Gender
#    Shuffled test MSE: 0.035 +/- 0.0
# Shuffling feature: SpayNeuter
#    Shuffled test MSE: 0.03 +/- 0.0
# Shuffling feature: Borough
#    Shuffled test MSE: 0.031 +/- 0.0
# Shuffling feature: Season
#    Shuffled test MSE: 0.038 +/- 0.0
# Shuffling feature: Age_Range
#    Shuffled test MSE: 0.03 +/- 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sort the features by the mean of the shuffled MSE scores (descending order)
sorted_indcs = np.argsort(np.mean(scores, axis=1))[::-1]

# Plot settings
plt.rcParams.update({'font.size': 11})
plt.figure(figsize=(8, len(ftr_names) * 0.4))  # Adjust height dynamically for readability
plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# Add a vertical line for the test set MSE
plt.axvline(test_mse, color='blue', linestyle='--', label='Test MSE')

# Add labels and title
plt.title("Permutation Importances (test set, MSE)")
plt.xlabel('MSE with perturbed feature')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pw/j1b5757d4hg8vhmyx5h9rmjh0000gn/T/ipykernel_14520/3916736048.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# %%
def ML_pipeline_kfold_SVR(X, y, random_state, n_folds):
    # Create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

    # Splitter for cross-validation
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)

    # Pipeline with Ridge regression
    pipe = make_pipeline(preprocessor, SVR())

    # Parameter grid
    param_grid = {
        'svr__C': [1e4, 1e5, 1e6],
        'svr__gamma': [1e-6, 1e-5, 1e-4],
    }

    # Prepare GridSearchCV
    grid = GridSearchCV(pipe, param_grid=param_grid, cv=kf, return_train_score=True, n_jobs=-1, verbose=True)

    # Perform k-fold CV on X_other
    grid.fit(X_other, y_other)

    # Return the grid search results and test set
    return grid, X_test, y_test

# %%
from xgboost import XGBRegressor

model, X_test, y_test = ML_pipeline_kfold_SVR(X,y,42,4)

# Calculate MSE for the test set
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print("Best cross-validation score (R^2):", model.best_score_)  # Negative MSE from GridSearchCV
print("Test set MSE:", test_mse)
print("Best parameters:", model.best_params_)

# Save the model and test MSE
file = open('data/results/grid_SVR.save', 'wb')
pickle.dump((model, X_test, y_test), file)
file.close()
# Out:
# Fitting 4 folds for each of 9 candidates, totalling 36 fits
# Best cross-validation score (R^2): 0.6019811688729594
# Test set MSE: 0.029992660281554576
# Best parameters: {'svr__C': 10000.0, 'svr__gamma': 0.0001}

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
import pickle

# Load the saved model and data
file = open('data/results/grid_SVR.save', 'rb')
model, X_test, y_test = pickle.load(file)
file.close()

np.random.seed(42)

ftr_names = X_test.columns

nr_runs = 10
scores = np.zeros([len(ftr_names), nr_runs])

# Baseline prediction using the mean of the target
baseline_prediction = np.mean(y_test)  # Use the test set mean
baseline_mse = np.mean((y_test - baseline_prediction) ** 2)

# Calculate the test set MSE
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print('Test MSE =', test_mse)
print('Baseline MSE =', baseline_mse)

# Loop through the features for permutation importance using MSE
for i in range(len(ftr_names)):
    print('Shuffling feature:', str(ftr_names[i]))
    acc_scores = []
    for j in range(nr_runs):
        X_test_shuffled = X_test.copy()
        # Shuffle the selected feature
        X_test_shuffled[ftr_names[i]] = np.random.permutation(X_test[ftr_names[i]].values)
        # Predict and calculate MSE with the shuffled feature
        y_test_shuffled_pred = model.predict(X_test_shuffled)
        shuffled_mse = mean_squared_error(y_test, y_test_shuffled_pred)
        acc_scores.append(shuffled_mse)
    # Calculate mean and std deviation of shuffled MSEs
    print('   Shuffled test MSE:', np.around(np.mean(acc_scores), 3), '+/-', np.around(np.std(acc_scores), 3))
    scores[i] = acc_scores
# Out:
# Test MSE = 0.029992660281554576
# Baseline MSE = 0.07460487324043191
# Shuffling feature: Breed
#    Shuffled test MSE: 0.111 +/- 0.002
# Shuffling feature: Gender
#    Shuffled test MSE: 0.035 +/- 0.0
# Shuffling feature: SpayNeuter
#    Shuffled test MSE: 0.03 +/- 0.0
# Shuffling feature: Borough
#    Shuffled test MSE: 0.031 +/- 0.0
# Shuffling feature: Season
#    Shuffled test MSE: 0.038 +/- 0.0
# Shuffling feature: Age_Range
#    Shuffled test MSE: 0.03 +/- 0.0

# %%
# Sort the features by the mean of the shuffled MSE scores (descending order)
sorted_indcs = np.argsort(np.mean(scores, axis=1))[::-1]

# Plot settings
plt.rcParams.update({'font.size': 11})
plt.figure(figsize=(8, len(ftr_names) * 0.4))  # Adjust height dynamically for readability
plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# Add a vertical line for the test set MSE
plt.axvline(test_mse, color='blue', linestyle='--', label='Test MSE')

# Add labels and title
plt.title("Permutation Importances (test set, MSE)")
plt.xlabel('MSE with perturbed feature')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pw/j1b5757d4hg8vhmyx5h9rmjh0000gn/T/ipykernel_14520/2886995980.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# %%
import shap
import matplotlib.pyplot as plt

def generate_shap_explanation(grid, X_test, index):
    # Get the best estimator from GridSearchCV
    best_estimator = grid.best_estimator_

    # Use the pipeline to preprocess the test data
    X_test_prep = best_estimator[:-1].transform(X_test)  # Apply all pipeline steps except the final Ridge model

    # Initialize SHAP explainer for linear models
    explainer = shap.LinearExplainer(best_estimator.named_steps['ridge'], X_test_prep)

    # Calculate SHAP values
    shap_values = explainer.shap_values(X_test_prep)

    # Visualize the SHAP values
    shap.summary_plot(shap_values, X_test_prep, plot_type="bar", feature_names=grid.best_estimator_[:-1].get_feature_names_out())
    
    # Example force plot for a single instance
    # index = index  # Choose an instance to explain
    shap.force_plot(
        explainer.expected_value, 
        shap_values[index, :], 
        features=X_test_prep[index, :], 
        feature_names=grid.best_estimator_[:-1].get_feature_names_out()
    )

# Example usage
grid, X_test, y_test = ML_pipeline_kfold_ridge(X, y, random_state=42, n_folds=4)
generate_shap_explanation(grid, X_test, )
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits

# %%
generate_shap_explanation(grid, X_test, 60)

# %%
import shap
shap.initjs() # required for visualizations later on

grid, X_test, y_test = ML_pipeline_kfold_ridge(X, y, random_state=42, n_folds=4)

X_test_transformed = grid.best_estimator_[0].transform(X_test)

masker = shap.maskers.Independent(X_test_transformed)  # Use Independent masker
# create the explainer object with the random forest model
explainer = shap.LinearExplainer(grid.best_estimator_[1], masker=masker)

# calculate shap values on the first 1000 points in the test
shap_values = explainer.shap_values(X_test_transformed[:1000])
print(np.shape(shap_values))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# (1000, 181)

# %%
index = 1  # the index of the point to explain
print(explainer.expected_value)  # No indexing needed; it's a scalar

# Explain the prediction for the selected point
shap.force_plot(
    explainer.expected_value,  # Single expected value
    shap_values[index, :],     # SHAP values for the selected point
    features=X_test_transformed[index, :],  # Features for the selected point
    feature_names=grid.best_estimator_[:-1].get_feature_names_out()
)
# Out:
# 0.5095940276115719
# <div id='iP5A7N6NNT6F1VDYXQJWT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5095940276115719, "outValue": 0.34996079964697635, "link": "identity", "featureNames": ["cat__Breed_afghan hound", "cat__Breed_airedale terrier", "cat__Breed_akita", "cat__Breed_alaskan malamute", "cat__Breed_american bulldog", "cat__Breed_american english coonhound", "cat__Breed_american eskimo dog", "cat__Breed_american leopard hound", "cat__Breed_american staffordshire terrier", "cat__Breed_american water spaniel", "cat__Breed_anatolian shepherd dog", "cat__Breed_australian cattle dog", "cat__Breed_australian kelpie", "cat__Breed_australian shepherd", "cat__Breed_australian stumpy tail cattle dog", "cat__Breed_australian terrier", "cat__Breed_barbet", "cat__Breed_basenji", "cat__Breed_basset hound", "cat__Breed_bavarian mountain scent hound", "cat__Breed_beagle", "cat__Breed_bearded collie", "cat__Breed_beauceron", "cat__Breed_belgian malinois", "cat__Breed_belgian sheepdog", "cat__Breed_belgian tervuren", "cat__Breed_bernese mountain dog", "cat__Breed_bichon frise", "cat__Breed_biewer terrier", "cat__Breed_black and tan coonhound", "cat__Breed_black russian terrier", "cat__Breed_bloodhound", "cat__Breed_boerboel", "cat__Breed_bolognese", "cat__Breed_border collie", "cat__Breed_border terrier", "cat__Breed_borzoi", "cat__Breed_boston terrier", "cat__Breed_bouvier des flandres", "cat__Breed_boxer", "cat__Breed_boykin spaniel", "cat__Breed_brittany", "cat__Breed_brussels griffon", "cat__Breed_bull terrier", "cat__Breed_bulldog", "cat__Breed_bullmastiff", "cat__Breed_cairn terrier", "cat__Breed_canaan dog", "cat__Breed_cane corso", "cat__Breed_cardigan welsh corgi", "cat__Breed_carolina dog", "cat__Breed_catahoula leopard dog", "cat__Breed_cavalier king charles spaniel", "cat__Breed_central asian shepherd dog", "cat__Breed_cesky terrier", "cat__Breed_chesapeake bay retriever", "cat__Breed_chihuahua", "cat__Breed_chinese crested", "cat__Breed_chinese shar-pei", "cat__Breed_chow chow", "cat__Breed_clumber spaniel", "cat__Breed_cocker spaniel", "cat__Breed_collie", "cat__Breed_coton de tulear", "cat__Breed_curly-coated retriever", "cat__Breed_dachshund", "cat__Breed_dalmatian", "cat__Breed_dandie dinmont terrier", "cat__Breed_doberman pinscher", "cat__Breed_dogue de bordeaux", "cat__Breed_dutch shepherd", "cat__Breed_english cocker spaniel", "cat__Breed_english setter", "cat__Breed_english springer spaniel", "cat__Breed_english toy spaniel", "cat__Breed_finnish spitz", "cat__Breed_french bulldog", "cat__Breed_german longhaired pointer", "cat__Breed_german pinscher", "cat__Breed_german shepherd dog", "cat__Breed_german shorthaired pointer", "cat__Breed_german spitz", "cat__Breed_german wirehaired pointer", "cat__Breed_giant schnauzer", "cat__Breed_glen of imaal terrier", "cat__Breed_golden retriever", "cat__Breed_grand basset griffon vend\u00e9en", "cat__Breed_great dane", "cat__Breed_great pyrenees", "cat__Breed_greyhound", "cat__Breed_harrier", "cat__Breed_havanese", "cat__Breed_irish red and white setter", "cat__Breed_irish terrier", "cat__Breed_irish wolfhound", "cat__Breed_italian greyhound", "cat__Breed_japanese chin", "cat__Breed_japanese spitz", "cat__Breed_jindo", "cat__Breed_kai ken", "cat__Breed_kerry blue terrier", "cat__Breed_labrador retriever", "cat__Breed_lakeland terrier", "cat__Breed_lhasa apso", "cat__Breed_l\u00f6wchen", "cat__Breed_maltese", "cat__Breed_mastiff", "cat__Breed_miniature american shepherd", "cat__Breed_miniature bull terrier", "cat__Breed_miniature pinscher", "cat__Breed_miniature schnauzer", "cat__Breed_neapolitan mastiff", "cat__Breed_newfoundland", "cat__Breed_norfolk terrier", "cat__Breed_norwich terrier", "cat__Breed_nova scotia duck tolling retriever", "cat__Breed_old english sheepdog", "cat__Breed_papillon", "cat__Breed_parson russell terrier", "cat__Breed_pekingese", "cat__Breed_pembroke welsh corgi", "cat__Breed_petit basset griffon vend\u00e9en", "cat__Breed_pharaoh hound", "cat__Breed_plott ...

# %%
index = 80  # the index of the point to explain
print(explainer.expected_value)  # No indexing needed; it's a scalar

# Explain the prediction for the selected point
shap.force_plot(
    explainer.expected_value,  # Single expected value
    shap_values[index, :],     # SHAP values for the selected point
    features=X_test_transformed[index, :],  # Features for the selected point
    feature_names=grid.best_estimator_[:-1].get_feature_names_out()
)
# Out:
# 0.5095940276115719
# <div id='i6OB23VQUBG3QBGOXFKCE'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5095940276115719, "outValue": 0.7018953204922682, "link": "identity", "featureNames": ["cat__Breed_afghan hound", "cat__Breed_airedale terrier", "cat__Breed_akita", "cat__Breed_alaskan malamute", "cat__Breed_american bulldog", "cat__Breed_american english coonhound", "cat__Breed_american eskimo dog", "cat__Breed_american leopard hound", "cat__Breed_american staffordshire terrier", "cat__Breed_american water spaniel", "cat__Breed_anatolian shepherd dog", "cat__Breed_australian cattle dog", "cat__Breed_australian kelpie", "cat__Breed_australian shepherd", "cat__Breed_australian stumpy tail cattle dog", "cat__Breed_australian terrier", "cat__Breed_barbet", "cat__Breed_basenji", "cat__Breed_basset hound", "cat__Breed_bavarian mountain scent hound", "cat__Breed_beagle", "cat__Breed_bearded collie", "cat__Breed_beauceron", "cat__Breed_belgian malinois", "cat__Breed_belgian sheepdog", "cat__Breed_belgian tervuren", "cat__Breed_bernese mountain dog", "cat__Breed_bichon frise", "cat__Breed_biewer terrier", "cat__Breed_black and tan coonhound", "cat__Breed_black russian terrier", "cat__Breed_bloodhound", "cat__Breed_boerboel", "cat__Breed_bolognese", "cat__Breed_border collie", "cat__Breed_border terrier", "cat__Breed_borzoi", "cat__Breed_boston terrier", "cat__Breed_bouvier des flandres", "cat__Breed_boxer", "cat__Breed_boykin spaniel", "cat__Breed_brittany", "cat__Breed_brussels griffon", "cat__Breed_bull terrier", "cat__Breed_bulldog", "cat__Breed_bullmastiff", "cat__Breed_cairn terrier", "cat__Breed_canaan dog", "cat__Breed_cane corso", "cat__Breed_cardigan welsh corgi", "cat__Breed_carolina dog", "cat__Breed_catahoula leopard dog", "cat__Breed_cavalier king charles spaniel", "cat__Breed_central asian shepherd dog", "cat__Breed_cesky terrier", "cat__Breed_chesapeake bay retriever", "cat__Breed_chihuahua", "cat__Breed_chinese crested", "cat__Breed_chinese shar-pei", "cat__Breed_chow chow", "cat__Breed_clumber spaniel", "cat__Breed_cocker spaniel", "cat__Breed_collie", "cat__Breed_coton de tulear", "cat__Breed_curly-coated retriever", "cat__Breed_dachshund", "cat__Breed_dalmatian", "cat__Breed_dandie dinmont terrier", "cat__Breed_doberman pinscher", "cat__Breed_dogue de bordeaux", "cat__Breed_dutch shepherd", "cat__Breed_english cocker spaniel", "cat__Breed_english setter", "cat__Breed_english springer spaniel", "cat__Breed_english toy spaniel", "cat__Breed_finnish spitz", "cat__Breed_french bulldog", "cat__Breed_german longhaired pointer", "cat__Breed_german pinscher", "cat__Breed_german shepherd dog", "cat__Breed_german shorthaired pointer", "cat__Breed_german spitz", "cat__Breed_german wirehaired pointer", "cat__Breed_giant schnauzer", "cat__Breed_glen of imaal terrier", "cat__Breed_golden retriever", "cat__Breed_grand basset griffon vend\u00e9en", "cat__Breed_great dane", "cat__Breed_great pyrenees", "cat__Breed_greyhound", "cat__Breed_harrier", "cat__Breed_havanese", "cat__Breed_irish red and white setter", "cat__Breed_irish terrier", "cat__Breed_irish wolfhound", "cat__Breed_italian greyhound", "cat__Breed_japanese chin", "cat__Breed_japanese spitz", "cat__Breed_jindo", "cat__Breed_kai ken", "cat__Breed_kerry blue terrier", "cat__Breed_labrador retriever", "cat__Breed_lakeland terrier", "cat__Breed_lhasa apso", "cat__Breed_l\u00f6wchen", "cat__Breed_maltese", "cat__Breed_mastiff", "cat__Breed_miniature american shepherd", "cat__Breed_miniature bull terrier", "cat__Breed_miniature pinscher", "cat__Breed_miniature schnauzer", "cat__Breed_neapolitan mastiff", "cat__Breed_newfoundland", "cat__Breed_norfolk terrier", "cat__Breed_norwich terrier", "cat__Breed_nova scotia duck tolling retriever", "cat__Breed_old english sheepdog", "cat__Breed_papillon", "cat__Breed_parson russell terrier", "cat__Breed_pekingese", "cat__Breed_pembroke welsh corgi", "cat__Breed_petit basset griffon vend\u00e9en", "cat__Breed_pharaoh hound", "cat__Breed_plott  ...

# %%
import matplotlib.pyplot as plt

# Get predictions on the test set
y_pred = grid.predict(X_test)

# Scatter plot of true vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.6, edgecolors='k')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Scatter Plot of True vs Predicted Values in Regression")
plt.grid(True)
plt.show()

# %%
import shap
shap.initjs() # required for visualizations later on
# create the explainer object with the random forest model
masker = shap.maskers.Independent(X_test_transformed)  # Use Independent masker
# create the explainer object with the random forest model
explainer = shap.LinearExplainer(grid.best_estimator_[1], masker=masker)
# transform the test set 
X_test_transformed = grid.best_estimator_[0].transform(X_test)

print(np.shape(X_test_transformed))
# calculate shap values on the first 1000 points in the test
shap_values = explainer.shap_values(X_test_transformed[:1000])
print(np.shape(shap_values))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# (2660, 181)
# (1000, 181)

# %%
shap.summary_plot(shap_values, X_test_transformed[:1000], feature_names=grid.best_estimator_[:-1].get_feature_names_out()
, max_display=15)

# %%
shap_values
# Out:
# array([[-0.        , -0.0087096 ,  0.        , ..., -0.00055935,
#         -0.00055935,  0.0007211 ],
#        [-0.        , -0.0087096 ,  0.        , ..., -0.00055935,
#         -0.00055935,  0.0007211 ],
#        [-0.        , -0.0087096 ,  0.        , ..., -0.00055935,
#         -0.00055935, -0.00051155],
#        ...,
#        [-0.        , -0.0087096 ,  0.        , ...,  0.00113565,
#          0.00113565, -0.00051155],
#        [-0.        , -0.0087096 ,  0.        , ..., -0.00055935,
#         -0.00055935,  0.0007211 ],
#        [-0.        , -0.0087096 ,  0.        , ...,  0.00113565,
#          0.00113565, -0.00112787]])
