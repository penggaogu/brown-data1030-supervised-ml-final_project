# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data/dog_bites_df.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13299 entries, 0 to 13298
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   UniqueID            13299 non-null  int64
#  1   Species             13299 non-null  object
#  2   Breed               13299 non-null  object
#  3   Gender              13299 non-null  object
#  4   SpayNeuter          13299 non-null  bool
#  5   Borough             13299 non-null  object
#  6   ZipCode             10355 non-null  float64
#  7   Season              13299 non-null  object
#  8   trainability_value  13299 non-null  float64
#  9   group               13299 non-null  object
#  10  Age_Range           7261 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 1.0+ MB

# %%
df.head()
# Out:
#    UniqueID Species         Breed Gender  SpayNeuter   Borough  ZipCode  \
# 0         3     DOG  bull terrier      U       False  Brooklyn  11224.0
# 1         5     DOG  bull terrier      U       False  Brooklyn  11224.0
# 2         6     DOG       basenji      M       False  Brooklyn  11231.0
# 3         8     DOG  bull terrier      U       False  Brooklyn  11233.0
# 4        13     DOG    great dane      F        True  Brooklyn      NaN
#
#    Season  trainability_value          group          Age_Range
# 0  Winter                0.38  Terrier Group                NaN
# 1  Winter                0.69  Terrier Group                NaN
# 2  Winter                0.71    Hound Group  Adult (3-7 Years)
# 3  Winter                0.48  Terrier Group                NaN
# 4  Winter                0.87  Working Group  Adult (3-7 Years)

# %%
df = df.drop(columns=['UniqueID', 'Species', 'ZipCode'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13299 entries, 0 to 13298
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Breed               13299 non-null  object
#  1   Gender              13299 non-null  object
#  2   SpayNeuter          13299 non-null  bool
#  3   Borough             13299 non-null  object
#  4   Season              13299 non-null  object
#  5   trainability_value  13299 non-null  float64
#  6   group               13299 non-null  object
#  7   Age_Range           7261 non-null   object
# dtypes: bool(1), float64(1), object(6)
# memory usage: 740.4+ KB

# %%
df = df.drop(columns=['group'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13299 entries, 0 to 13298
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Breed               13299 non-null  object
#  1   Gender              13299 non-null  object
#  2   SpayNeuter          13299 non-null  bool
#  3   Borough             13299 non-null  object
#  4   Season              13299 non-null  object
#  5   trainability_value  13299 non-null  float64
#  6   Age_Range           7261 non-null   object
# dtypes: bool(1), float64(1), object(5)
# memory usage: 636.5+ KB

# %%
import os

# Define save path (Windows example: save to Desktop)
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 'trainability_value_distribution.png')

# Plot and save the image
plt.figure(figsize=(10, 5))

df['trainability_value'].plot.hist(bins=df['trainability_value'].nunique())  
plt.title('Trainability Value Distribution')
plt.xlabel('trainability_value')
plt.ylabel('count')

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Define save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 'season_bar_chart.png')

# Plot and save the image
plt.figure(figsize=(10, 5))
df['Season'].value_counts().plot.barh()
plt.title('Season Distribution')
plt.xlabel('Count')
plt.ylabel('Season')

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Define save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 'breed_distribution_bar_chart.png')

# Plot and save the image
plt.figure(figsize=(10, 5))
df['Breed'].value_counts().head(10).plot.barh()
plt.title('Top 10 Dog Breeds Involved in Bite Incidents')
plt.xlabel('count')
plt.ylabel('Breed')

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Define save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 'spayneuter_bar_chart.png')

# Plot and save the image
spay_neuter_counts = df['SpayNeuter'].value_counts()
plt.figure(figsize=(10, 5))
spay_neuter_counts.plot(kind='pie', startangle=90, autopct='%1.1f%%')
plt.title('Spaying/Neutering')
plt.ylabel('')  # Remove y-label

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Define save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 'gender_bar_chart.png')

# Plot and save the image
plt.figure(figsize=(10, 5))
df['Gender'].value_counts().plot.barh()
plt.title('Gender Distribution')
plt.xlabel('Count')
plt.ylabel('Gender')

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Define save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 'Borough_bar_chart.png')

# Plot and save the image
plt.figure(figsize=(10, 5))
df['Borough'].value_counts().plot.barh()
plt.title('Borough Distribution')
plt.xlabel('Count')
plt.ylabel('Borough')

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Define save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 'group_bar_chart.png')

# Plot and save the image
plt.figure(figsize=(10, 5))
df['group'].value_counts().plot.barh()
plt.title('group Distribution')
plt.xlabel('Count')
plt.ylabel('group')

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# preprocess with pipeline and columntransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

random_state = 42

# Define the feature and target variable
X = df.drop(columns=['trainability_value'])  # features
y = df['trainability_value']  # target

cat_ftrs = ['Breed','Gender','Borough','Season', 'SpayNeuter']
ordinal_ftrs = ['Age_Range']
ordinal_cats = [['Puppy/Young (0-2 Years)', 'Adult (3-7 Years)', 'Senior (8+ Years)', 'None']]

# one-hot encoder
# We need to replace the NaN with a string first!
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # 填充缺失值为出现频率最高的值
    ('onehot', OneHotEncoder(sparse_output=False,handle_unknown='ignore'))])

# ordinal encoder
# We need to replace the NaN with a string first!
ordinal_transformer = Pipeline(steps=[
    ('imputer2', SimpleImputer(strategy='constant',fill_value='None')),
    ('ordinal', OrdinalEncoder(categories = ordinal_cats))])

# collect the transformers
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, cat_ftrs),
        ('ord', ordinal_transformer, ordinal_ftrs)])

# %%
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
import numpy as np

models = {
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "RandomForest": RandomForestRegressor(),
    "XGBoost": XGBRegressor(),
    "SVR": SVR(),
}

param_grids = {
    "Ridge": {
        'alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2],
    },
    "Lasso": {
        'alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2],
    },
    "RandomForest": {
        'max_depth': [1, 3, 10, 30, 100],
        'max_features': [0.5, 0.75, 1.0],
    },
    "XGBoost": {
        'learning_rate': [0.03],
        'n_estimators': [100, 300],
        'reg_alpha': [0e0, 1e-3, 1e-2, 1e-1, 1e0],
        'reg_lambda': [0e0, 1e-1, 1e0, 1e1, 1e2],
        'max_depth': [1, 10, 100],
    },
    "SVR": {
        'C': [1e4, 1e5, 1e6],
        'gamma': [1e-6, 1e-5, 1e-4],
    },
}


# Initialize result storage
results = {}

# Loop through 5 random states
for random_state in range(5):
    print(f"\nRandom State {random_state + 1}:")

    # Split the dataset into test and other sets
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

    # Loop through each model
    for model_name, model in models.items():
        print(f"\nRunning pipeline for {model_name}...")

        # Create pipeline
        pipe = make_pipeline(preprocessor, model)

        # Get parameter grid for the model
        param_grid = param_grids.get(model_name, {})

        # Update parameter names for pipeline compatibility
        updated_param_grid = {f'{pipe.steps[-1][0]}__{key.split("__")[-1]}': value for key, value in param_grid.items()}

        # Create cross-validation object
        kf = KFold(n_splits=5, shuffle=True, random_state=random_state)

        # GridSearchCV for hyperparameter tuning
        grid_search = GridSearchCV(
            pipe,
            param_grid=updated_param_grid,
            cv=kf,
            scoring='neg_mean_squared_error',
            return_train_score=True,
            n_jobs=-1,
            verbose=1
        )

        # Fit the grid search on the "other" dataset
        grid_search.fit(X_other, y_other)

        # Get the best parameters and the corresponding model
        best_params = grid_search.best_params_
        best_model = grid_search.best_estimator_


        print(f"Best parameters for {model_name}: {best_params}")

        # Evaluate the model on the test set
        y_test_pred = best_model.predict(X_test)
        test_mse = mean_squared_error(y_test, y_test_pred)

        print(f"Test MSE for {model_name}: {test_mse:.8f}")

        # Save results
        if model_name not in results:
            results[model_name] = []
        results[model_name].append({
            'random_state': random_state,
            'best_params': best_params,
            'test_mse': test_mse
        })

# Print final results
print("\nFinal Results:")
for model_name, model_results in results.items():
    print(f"\nModel: {model_name}")
    for result in model_results:
        print(f"Random State: {result['random_state']}, Best Params: {result['best_params']}, Test MSE: {result['test_mse']:.8f}")
# Out:
# Random State 1:
#
# Running pipeline for Ridge...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters for Ridge: {'ridge__alpha': 1.0}
# Test MSE for Ridge: 0.02841981
#
# Running pipeline for Lasso...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters for Lasso: {'lasso__alpha': 0.001}
# Test MSE for Lasso: 0.03579883
#
# Running pipeline for RandomForest...
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Best parameters for RandomForest: {'randomforestregressor__max_depth': 30, 'randomforestregressor__max_features': 0.5}
# Test MSE for RandomForest: 0.03362138
#
# Running pipeline for XGBoost...
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# Best parameters for XGBoost: {'xgbregressor__learning_rate': 0.03, 'xgbregressor__max_depth': 100, 'xgbregressor__n_estimators': 300, 'xgbregressor__reg_alpha': 1.0, 'xgbregressor__reg_lambda': 100.0}
# Test MSE for XGBoost: 0.02982519
#
# ...

# %% [markdown]
# | Model              | Best Hyperparameters                                 |
# |--------------------|-----------------------------------------------------|
# | Ridge Regression   | alpha = 1.0                                         |
# | Lasso Regression   | alpha = 0.001                                       |
# | Random Forest      | max_depth = 30, max_features = 0.5                  |
# | XGBoost            | max_depth = 100, reg_alpha = 0.01, reg_lambda = 100.0 |
# | SVR                | C = 100.0, gamma = 0.001                            |

# %%
# Extract test scores from results
test_scores = {
    model_name: [result['test_mse'] for result in model_results]
    for model_name, model_results in results.items()
}

# Compute means and standard deviations for each model
test_score_means = {model_name: np.mean(scores) for model_name, scores in test_scores.items()}
test_score_stds = {model_name: np.std(scores) for model_name, scores in test_scores.items()}

# %%
baseline_prediction = np.mean(y)
baseline_mse = np.mean((y - baseline_prediction) ** 2)

baseline_prediction, baseline_mse
# Out:
# (0.48147529889465374, 0.07478040864995014)

# %%
# Define save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 
                         'model_performance_with_uncertainties.png')

# Plot the results
model_names = list(test_scores.keys())
means = [test_score_means[name] for name in model_names]
stds = [test_score_stds[name] for name in model_names]

plt.figure(figsize=(8, 5))
plt.errorbar(model_names, means, yerr=stds, fmt='o', capsize=5)
plt.axhline(y=baseline_mse, color='r', linestyle='--', label="Baseline")

plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("MSE")
plt.legend()

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
stds
# Out:
# [0.0006103467564366631,
#  0.0009000217900285165,
#  0.0008610282029612302,
#  0.000705240830217662,
#  0.0005871657174521069]

# %%
# Define save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot',
                         'model_performance_uncertainties.png')

# Prepare data
model_names = list(test_scores.keys())
means = [test_score_means[name] for name in model_names]
stds = [test_score_stds[name] for name in model_names]

# Plot the results
plt.figure(figsize=(8, 5))
plt.errorbar(model_names, means, yerr=stds, fmt='o', capsize=5)
plt.title("Model performance & uncertainties due to splitting")
plt.xlabel("Model algorithm")
plt.ylabel("MSE")

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Ridge

def ML_pipeline_kfold_ridge(X, y, random_state, n_folds):
    # Create a test set
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

    # Splitter for cross-validation
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)

    # Pipeline with Ridge regression
    pipe = make_pipeline(preprocessor, Ridge())

    # Parameter grid
    param_grid = {
        'ridge__alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2],  # Regularization strength
    }

    # Prepare GridSearchCV
    grid = GridSearchCV(pipe, param_grid=param_grid, cv=kf, return_train_score=True, n_jobs=-1, verbose=True)

    # Perform k-fold CV on X_other
    grid.fit(X_other, y_other)

    # Return the grid search results and test set
    return grid, X_test, y_test

# %%
from sklearn.metrics import mean_squared_error
import pickle

model, X_test, y_test = ML_pipeline_kfold_ridge(X,y,42,4)

# Calculate MSE for the test set
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print("Best cross-validation score (R^2):", model.best_score_)  # Negative MSE from GridSearchCV
print("Test set MSE:", test_mse)
print("Best parameters:", model.best_params_)

# Save the model and test MSE
file = open('data/results/grid_ridge.save', 'wb')
pickle.dump((model, X_test, y_test), file)
file.close()
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# Best cross-validation score (R^2): 0.605453282255892
# Test set MSE: 0.029747214495538986
# Best parameters: {'ridge__alpha': 1.0}

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
import pickle

# Load the saved model and data
file = open('data/results/grid_ridge.save', 'rb')
model, X_test, y_test = pickle.load(file)
file.close()

np.random.seed(42)

ftr_names = X_test.columns

nr_runs = 10
scores = np.zeros([len(ftr_names), nr_runs])

# Baseline prediction using the mean of the target
baseline_prediction = np.mean(y_test)  # Use the test set mean
baseline_mse = np.mean((y_test - baseline_prediction) ** 2)

# Calculate the test set MSE
y_test_pred = model.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred)
print('Test MSE =', test_mse)
print('Baseline MSE =', baseline_mse)

# Loop through the features for permutation importance using MSE
for i in range(len(ftr_names)):
    print('Shuffling feature:', str(ftr_names[i]))
    acc_scores = []
    for j in range(nr_runs):
        X_test_shuffled = X_test.copy()
        # Shuffle the selected feature
        X_test_shuffled[ftr_names[i]] = np.random.permutation(X_test[ftr_names[i]].values)
        # Predict and calculate MSE with the shuffled feature
        y_test_shuffled_pred = model.predict(X_test_shuffled)
        shuffled_mse = mean_squared_error(y_test, y_test_shuffled_pred)
        acc_scores.append(shuffled_mse)
    # Calculate mean and std deviation of shuffled MSEs
    print('   Shuffled test MSE:', np.around(np.mean(acc_scores), 3), '+/-', np.around(np.std(acc_scores), 3))
    scores[i] = acc_scores
# Out:
# Test MSE = 0.029747214495538986
# Baseline MSE = 0.07460487324043191
# Shuffling feature: Breed
#    Shuffled test MSE: 0.108 +/- 0.002
# Shuffling feature: Gender
#    Shuffled test MSE: 0.034 +/- 0.0
# Shuffling feature: SpayNeuter
#    Shuffled test MSE: 0.03 +/- 0.0
# Shuffling feature: Borough
#    Shuffled test MSE: 0.031 +/- 0.0
# Shuffling feature: Season
#    Shuffled test MSE: 0.038 +/- 0.0
# Shuffling feature: Age_Range
#    Shuffled test MSE: 0.03 +/- 0.0

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Define save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot',
                         'permutation_importances.png')

# Sort the features by the mean of the shuffled MSE scores (descending order)
sorted_indcs = np.argsort(np.mean(scores, axis=1))[::-1]

# Plot settings
plt.rcParams.update({'font.size': 11})
plt.figure(figsize=(8, len(ftr_names) * 0.4))  # Adjust height dynamically for readability
plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)

# Add a vertical line for the test set MSE
plt.axvline(test_mse, color='blue', linestyle='--', label='Test MSE')

# Add labels and title
plt.title("Permutation Importances (test set, MSE)")
plt.xlabel('MSE with perturbed feature')
plt.legend()
plt.tight_layout()

# Save the plot with 350 dpi
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

print(f"Plot saved to: {save_path}")
# Out:
# /var/folders/pw/j1b5757d4hg8vhmyx5h9rmjh0000gn/T/ipykernel_7093/2535877981.py:15: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(scores[sorted_indcs].T, labels=np.array(ftr_names)[sorted_indcs], vert=False)
# Plot saved to: /Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot/permutation_importances.png

# %%
import os
import shap
import numpy as np
import matplotlib.pyplot as plt

def generate_shap_explanation_with_bar(grid, X_test, index, save_path):
    # Get the best estimator from GridSearchCV
    best_estimator = grid.best_estimator_

    # Use the pipeline to preprocess the test data
    X_test_prep = best_estimator[:-1].transform(X_test)  # Apply all pipeline steps except the final Ridge model

    # Initialize SHAP explainer for linear models
    explainer = shap.LinearExplainer(best_estimator.named_steps['ridge'], X_test_prep)

    # Calculate SHAP values
    shap_values = explainer.shap_values(X_test_prep)  # Returns 2D array for regression or binary classification

    # Check dimensionality of shap_values and calculate shap_summary
    if len(shap_values.shape) == 2:  # Regression or binary classification
        shap_summary = np.mean(np.abs(shap_values), axis=0)  # Mean absolute SHAP values for each feature
    else:
        raise ValueError("Unexpected SHAP values shape. Check the model type and SHAP explainer.")

    # Get feature names from the pipeline
    feature_names = best_estimator[:-1].get_feature_names_out()

    # Check if shap_summary and feature_names have the same length
    if len(shap_summary) != len(feature_names):
        raise ValueError("Mismatch between SHAP summary values and feature names. Check your pipeline.")

    # Get indices of the top 10 features
    indcs = np.argsort(shap_summary)

    # Visualize the top 10 features with the highest mean(|SHAP value|)
    plt.figure(figsize=(5, 3))
    plt.barh(feature_names[indcs[-10:]], shap_summary[indcs[-10:]])
    plt.xlabel('mean(|SHAP value|)')
    plt.title('Top 10 Features by SHAP Importance')

    # Save the bar chart
    bar_chart_path = os.path.join(save_path, 'shap_top10_features_bar.png')
    plt.savefig(bar_chart_path, dpi=350, bbox_inches='tight')
    plt.show()

    print(f"Top 10 features bar chart saved to: {bar_chart_path}")

    # Visualize the SHAP summary plot as a bar chart
    summary_bar_path = os.path.join(save_path, 'shap_summary_bar.png')
    shap.summary_plot(shap_values, X_test_prep, plot_type="bar", feature_names=feature_names, show=False)
    plt.savefig(summary_bar_path, dpi=350, bbox_inches='tight')
    plt.show()

    print(f"SHAP summary bar plot saved to: {summary_bar_path}")

    # Visualize a SHAP force plot for a single instance
    force_plot_path = os.path.join(save_path, 'shap_force_plot.html')
    shap.save_html(force_plot_path, shap.force_plot(
        explainer.expected_value,
        shap_values[index, :],
        features=X_test_prep[index, :],
        feature_names=feature_names
    ))

    print(f"SHAP force plot saved to: {force_plot_path}")

# Example usage
save_path = '/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot'  # Define your save directory
os.makedirs(save_path, exist_ok=True)  # Ensure the directory exists

grid, X_test, y_test = ML_pipeline_kfold_ridge(X, y, random_state=42, n_folds=4)
generate_shap_explanation_with_bar(grid, X_test, 1, save_path)
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# Top 10 features bar chart saved to: /Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot/shap_top10_features_bar.png
# SHAP summary bar plot saved to: /Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot/shap_summary_bar.png
# SHAP force plot saved to: /Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot/shap_force_plot.html

# %%
import shap
shap.initjs() # required for visualizations later on

grid, X_test, y_test = ML_pipeline_kfold_ridge(X, y, random_state=42, n_folds=4)

X_test_transformed = grid.best_estimator_[0].transform(X_test)

masker = shap.maskers.Independent(X_test_transformed)  # Use Independent masker
# create the explainer object with the random forest model
explainer = shap.LinearExplainer(grid.best_estimator_[1], masker=masker)

# calculate shap values on the first 1000 points in the test
shap_values = explainer.shap_values(X_test_transformed[:1000])
print(np.shape(shap_values))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
import shap
import numpy as np

def generate_shap_force_plot(grid, X_test, index, save_path):
    # Get the best estimator from GridSearchCV
    best_estimator = grid.best_estimator_

    # Use the pipeline to preprocess the test data
    X_test_transformed = best_estimator[:-1].transform(X_test)  # Apply all pipeline steps except the final Ridge model

    # Initialize SHAP explainer for linear models
    explainer = shap.LinearExplainer(best_estimator.named_steps['ridge'], X_test_transformed)

    # Calculate SHAP values
    shap_values = explainer.shap_values(X_test_transformed)  # SHAP values for the test set

    # Generate the SHAP force plot
    force_plot = shap.force_plot(
        explainer.expected_value,  # Single expected value
        shap_values[index, :],     # SHAP values for the selected point
        features=X_test_transformed[index, :],  # Features for the selected point
        feature_names=best_estimator[:-1].get_feature_names_out()
    )

    # Save the force plot as an HTML file
    force_plot_path = os.path.join(save_path, f'shap_force_plot_index_{index}.html')
    shap.save_html(force_plot_path, force_plot)

    print(f"SHAP force plot saved to: {force_plot_path}")

    # Return the force plot object (if needed for further analysis)
    return force_plot

# Example usage
save_path = '/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot'  # Define your save directory
os.makedirs(save_path, exist_ok=True)  # Ensure the directory exists

grid, X_test, y_test = ML_pipeline_kfold_ridge(X, y, random_state=42, n_folds=4)
index = 1  # Index of the instance to explain
generate_shap_force_plot(grid, X_test, index, save_path)
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# SHAP force plot saved to: /Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot/shap_force_plot_index_1.html
# <div id='iCWERJJE6OFSREMVW6AQS'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
index = 80  # the index of the point to explain

grid, X_test, y_test = ML_pipeline_kfold_ridge(X, y, random_state=42, n_folds=4)
generate_shap_force_plot(grid, X_test, index, save_path)
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# SHAP force plot saved to: /Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot/shap_force_plot_index_80.html
# <div id='iD6GHXW63NUDIJFIHK5ZE'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
import matplotlib.pyplot as plt
import os

# Define the save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 'scatter_true_vs_predicted.png')

# Get predictions on the test set
y_pred = grid.predict(X_test)

# Scatter plot of true vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.6, edgecolors='k')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Scatter Plot of True vs Predicted Values in Regression")
plt.grid(True)

# Save the plot
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import shap
shap.initjs() # required for visualizations later on
# create the explainer object with the random forest model
masker = shap.maskers.Independent(X_test_transformed)  # Use Independent masker
# create the explainer object with the random forest model
explainer = shap.LinearExplainer(grid.best_estimator_[1], masker=masker)
# transform the test set 
X_test_transformed = grid.best_estimator_[0].transform(X_test)

print(np.shape(X_test_transformed))
# calculate shap values on the first 1000 points in the test
shap_values = explainer.shap_values(X_test_transformed[:1000])
print(np.shape(shap_values))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
import shap
import matplotlib.pyplot as plt
import os

# Define the save path
save_path = os.path.join('/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot', 'shap_summary_plot.png')

# Generate the SHAP summary plot
plt.figure(figsize=(10, 6))  # Adjust the size as needed
shap.summary_plot(
    shap_values,
    X_test_transformed[:1000],
    feature_names=grid.best_estimator_[:-1].get_feature_names_out(),
    max_display=15,
    show=False  # Prevents automatic display so we can save the plot
)

# Save the plot
plt.savefig(save_path, dpi=350, bbox_inches='tight')

# Show the plot
plt.show()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Ridge
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
import numpy as np

# Define categorical and ordinal features
cat_ftrs = ['Breed', 'Gender', 'Borough', 'Season', 'SpayNeuter']
ordinal_ftrs = ['Age_Range']
ordinal_cats = [['Puppy/Young (0-2 Years)', 'Adult (3-7 Years)', 'Senior (8+ Years)', 'None']]

# One-hot encoder for categorical features
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Handle missing values
    ('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))  # One-hot encode
])

# Ordinal encoder for ordinal features
ordinal_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='None')),  # Handle missing values
    ('ordinal', OrdinalEncoder(categories=ordinal_cats))  # Ordinal encode
])

# Combine transformers into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, cat_ftrs),  # Categorical features
        ('ord', ordinal_transformer, ordinal_ftrs)  # Ordinal features
    ],
    remainder='passthrough'  # Pass through other features (numerical)
)

# Full pipeline: Preprocessing -> Scaling -> Ridge Regression
ridge_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),  # Apply preprocessor to encode features
    ('scaler', StandardScaler()),    # Standardize all features
    ('ridge', Ridge())               # Ridge regression
])

# Function to fit the model and ensure proper standardization
def ML_pipeline_kfold_ridge_std(X, y, random_state, n_folds):
    # Split the dataset into training and testing sets
    X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

    # Define cross-validation strategy
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)

    # Parameter grid for Ridge regression
    param_grid = {
        'ridge__alpha': [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2]
    }

    # Perform GridSearchCV to find the best hyperparameters
    grid = GridSearchCV(ridge_pipeline, param_grid=param_grid, cv=kf, return_train_score=True, n_jobs=-1, verbose=True)
    grid.fit(X_other, y_other)

    # Extract the fitted scaler and transformed data
    preprocessor_fitted = grid.best_estimator_.named_steps['preprocessor']
    scaler = grid.best_estimator_.named_steps['scaler']

    # Transform X_other to verify standardization
    X_other_transformed = scaler.transform(preprocessor_fitted.transform(X_other))

    # Verify mean and standard deviation of the transformed features
    feature_means = np.mean(X_other_transformed, axis=0)
    feature_stds = np.std(X_other_transformed, axis=0)
    print("Feature Means (should be close to 0):", feature_means)
    print("Feature Standard Deviations (should be close to 1):", feature_stds)

    # Return the trained grid, test set, and transformed data
    return grid, X_test, y_test

# %%
model, X_test, y_test = ML_pipeline_kfold_ridge_std(X,y,42,4)
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# Feature Means (should be close to 0): [-9.08910966e-16  2.68223893e-16  2.40024812e-16 -1.22655825e-15
#  -4.87930966e-16  8.19231681e-16 -1.50605108e-16  7.95244592e-16
#  -4.51003450e-15  1.10873696e-15 -6.17600038e-16  5.16761389e-17
#   7.48768547e-16 -1.21489016e-16 -8.29243150e-16  7.56430745e-16
#   1.04027970e-15 -2.36158494e-16  5.62931546e-16  8.94395966e-16
#  -2.98812682e-16 -2.05603946e-16  8.08598653e-16  5.03066221e-16
#   3.08271726e-16  1.12757939e-15  5.41935506e-16 -1.94109019e-16
#   1.08458095e-15  4.12607541e-16 -1.20118065e-17  1.55268431e-16
#   1.01026519e-15  9.02036641e-16 -7.14825427e-18 -2.28351309e-15
#   1.63167709e-16  6.85825429e-16  1.96530033e-16 -1.02217427e-16
#   1.18584940e-15  9.37058522e-16 -9.18551978e-16 -5.85781176e-16
#  -7.43314090e-16 -1.02128726e-16 -6.15793408e-16  1.13789707e-15
#   3.81881136e-16 -1.86167673e-17  1.17387771e-15 -2.73472251e-16
# ...

# %%
from itertools import chain

# Extract the best Ridge model
best_ridge = model.best_estimator_.named_steps['ridge']
coefficients = best_ridge.coef_

# Dynamically find the preprocessor step
for step_name, step in model.best_estimator_.named_steps.items():
    if isinstance(step, ColumnTransformer):
        preprocessor = step
        break
else:
    raise ValueError("Preprocessor not found in the pipeline!")

# Extract feature names
feature_names = []
for name, transformer, columns in preprocessor.transformers_:
    if hasattr(transformer, 'get_feature_names_out'):  # For OneHotEncoder
        feature_names.extend(transformer.get_feature_names_out(columns))
    else:
        feature_names.extend(columns)  # For numeric or ordinal features

# Combine feature names with coefficients
feature_importance = list(zip(feature_names, coefficients))

# Sort by absolute coefficient values
feature_importance_sorted = sorted(feature_importance, key=lambda x: abs(x[1]), reverse=True)

# Print top features
print("Top features by importance:")
for name, coef in feature_importance_sorted[:10]:
    print(f"{name}: {coef}")
# Out:
# Top features by importance:
# Breed_bull terrier: -0.07399084485197169
# Breed_german shepherd dog: 0.07134672878500387
# Breed_yorkshire terrier: -0.059806938925737935
# Breed_labrador retriever: 0.05033028910854199
# Season_Summer: -0.04633744028867223
# Breed_poodle (standard): 0.04453289704112016
# Breed_airedale terrier: 0.03982003638154105
# Breed_cocker spaniel: 0.03884110370656578
# Gender_F: 0.037473538332863515
# Breed_golden retriever: 0.03318167810066707

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data
features = [
    "Breed_bull terrier",
    "Breed_german shepherd dog",
    "Breed_yorkshire terrier",
    "Breed_labrador retriever",
    "Season_Summer",
    "Breed_poodle (standard)",
    "Breed_airedale terrier",
    "Breed_cocker spaniel",
    "Gender_F",
    "Breed_golden retriever",
]
importance = [
    -0.07399084485197169,
    0.07134672878500387,
    -0.059806938925737935,
    0.05033028910854199,
    -0.04633744028867223,
    0.04453289704112016,
    0.03982003638154105,
    0.03884110370656578,
    0.037473538332863515,
    0.03318167810066707,
]

# Create a dataframe for better visualization
data = pd.DataFrame({"Feature": features, "Importance": importance})

# Sort the dataframe by absolute importance values for better visibility
data_sorted = data.reindex(data['Importance'].abs().sort_values(ascending=False).index)

# Adjusting the save path to ensure it works
save_path = "/Users/gupenggao/Dropbox/jupyternotebook/1030/project/plot/ridge_coefficients.png"

# Recreating the plot and saving it
plt.figure(figsize=(8, 6))
plt.barh(data_sorted["Feature"], data_sorted["Importance"], color="skyblue")
plt.xlabel("Coefficient Value")
plt.ylabel("Features")
plt.title("Top Features by Ridge Coefficient Importance")
plt.tight_layout()
plt.savefig(save_path, dpi=350)

# Display the plot and table to the user
plt.show()
